# %% [markdown]
# In this notebook, I'm going to plot the relation between training & testing dataset costs against epochs.
#
# Notes:
# * I have to reinitialise the model every time I am about to feed it data, otherwise the model is retraining.
# * In retraining.ipynb, my aim was to see if I could produce an accurate mean model with an extremely small dataset. Since my aim in this notebook is different, I'll use regular-sized dataset for simplicity.

# %%
#importing libraries
import numpy as np
from sklearn import datasets
import torch
import torch.nn as nn
import torch.optim as optim
import torchbnn as bnn
import matplotlib.pyplot as plt
import pandas as pd

# %%
# transferring as much data as I can to my GPU for faster processing
#! note: this'll only work for NVIDIA GPUs
is_available = torch.cuda.is_available()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
x_train = torch.rand(500)*4-2
y_train = x_train.pow(5) - 10 * x_train.pow(1) + 2*torch.rand(x_train.size())

plt.scatter(x_train.data.numpy(), y_train.data.numpy())
plt.show()

x_train = torch.unsqueeze(x_train, dim=1).to(device)
y_train = torch.unsqueeze(y_train, dim=1).to(device)

# %%
def clean_target(x):
    return x.pow(5) - 10 * x.pow(1)+1


def target(x):
    return x.pow(5) - 10 * x.pow(1) + 2*torch.rand(x.size())

# %%
def intialise_model(no_of_neurones: int, lr: float):
    model = nn.Sequential(
        bnn.BayesLinear(prior_mu=0, prior_sigma=0.1, in_features=1,
                        out_features=no_of_neurones),
        nn.ReLU(),
        bnn.BayesLinear(prior_mu=0, prior_sigma=0.1,
                        in_features=no_of_neurones, out_features=1),
    ).to(device)

    mse_loss = nn.MSELoss().to(device)
    kl_loss = bnn.BKLLoss(reduction='mean', last_layer_only=False).to(device)
    kl_weight = 0.01

    optimizer = optim.Adam(model.parameters(), lr=lr)

    return model, mse_loss, kl_loss, kl_weight, optimizer

# %%
def train_and_test(model_attributes, x_train: torch.Tensor, y_train: torch.Tensor, epochs: int):
    assert x_train.device == y_train.device == device, "Keep everything on the GPU for speed"

    model, mse_loss, kl_loss, kl_weight, optimizer = model_attributes

    for _ in range(epochs):
        predictions = model(x_train)
        mse = mse_loss(predictions, y_train)
        kl = kl_loss(model)
        cost = mse + kl_weight * kl

        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

    cost_train = cost.item()
    print(f'- With {epochs} epochs, MSE : {mse.item():2.2f}, KL : {kl.item():2.2f}, Cost: {cost.item():2.2f}')


    x_test = torch.rand(1000)*4-2
    y_test = target(x_test)

    x_test = torch.unsqueeze(x_test, dim=1).to(device)
    y_test = torch.unsqueeze(y_test, dim=1).to(device)

    predictions = model(x_test)
    mse = mse_loss(predictions, y_test)
    kl = kl_loss(model)
    cost = mse + kl_weight * kl

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    cost_test = cost.item()

    print(f'- With {epochs} epochs, MSE : {mse.item():2.2f}, KL : {kl.item():2.2f}, Cost: {cost.item():2.2f}')

    return cost_train, cost_test

# %% [markdown]
# Okay, everything I need is ready.
#
# I'm testing for a range of epochs, so I'll need to call the above function quite a lot.

# %% [markdown]
# Mind's a little glitchy rn. Need to convert the for loop above into a function.

# %%
def generate_data(lr: float):
    no_of_neurones = 2000
    df = pd.DataFrame(columns=[f"cost_train_{lr}", f"cost_test_{lr}"])
    no_of_epochs = [epochs for epochs in range(100, 1501, 100)]

    for epochs in no_of_epochs:
        model_attributes = intialise_model(no_of_neurones, lr)
        cost_train, cost_test = train_and_test(model_attributes, x_train, y_train, epochs)

        df = pd.concat([df, pd.DataFrame([[epochs, cost_train, cost_test]], columns=["epochs", f"cost_train_{lr}", f"cost_test_{lr}"])], ignore_index=True)

    return df

# %%
# df1 = pd.DataFrame({"epochs":no_of_epochs}) #df for storing train and test costs vs epochs for a fixed lr: 0.01 in this case
# df for storing test costs against epochs for multiple lrs
# df2 = pd.DataFrame({"epochs": no_of_epochs})

lr_rates = np.array([0.1, 0.01, 0.001, 0.0001])

#generating data for df1
df1 = generate_data(lr=0.01)
# Out:
# - With 100 epochs, MSE : 10.01, KL : 10.40, Cost: 10.12
# - With 100 epochs, MSE : 51.03, KL : 10.39, Cost: 51.14
# - With 200 epochs, MSE : 12.25, KL : 9.96, Cost: 12.35
# - With 200 epochs, MSE : 9.45, KL : 9.96, Cost: 9.55
# - With 300 epochs, MSE : 13.87, KL : 10.10, Cost: 13.97
# - With 300 epochs, MSE : 7.77, KL : 10.10, Cost: 7.87
# - With 400 epochs, MSE : 10.01, KL : 9.62, Cost: 10.11
# - With 400 epochs, MSE : 3.49, KL : 9.62, Cost: 3.58
# - With 500 epochs, MSE : 18.08, KL : 9.65, Cost: 18.18
# - With 500 epochs, MSE : 4.89, KL : 9.65, Cost: 4.98
# - With 600 epochs, MSE : 3.41, KL : 9.34, Cost: 3.51
# - With 600 epochs, MSE : 12.66, KL : 9.35, Cost: 12.75
# - With 700 epochs, MSE : 1.10, KL : 8.99, Cost: 1.19
# - With 700 epochs, MSE : 3.19, KL : 8.98, Cost: 3.28
# - With 800 epochs, MSE : 2.92, KL : 8.96, Cost: 3.01
# - With 800 epochs, MSE : 4.86, KL : 8.96, Cost: 4.95
# - With 900 epochs, MSE : 18.07, KL : 8.91, Cost: 18.16
# - With 900 epochs, MSE : 16.73, KL : 8.92, Cost: 16.82
# - With 1000 epochs, MSE : 1.60, KL : 9.07, Cost: 1.69
# - With 1000 epochs, MSE : 9.88, KL : 9.07, Cost: 9.97
# - With 1100 epochs, MSE : 2.81, KL : 8.76, Cost: 2.90
# - With 1100 epochs, MSE : 5.29, KL : 8.76, Cost: 5.38
# - With 1200 epochs, MSE : 4.04, KL : 8.90, Cost: 4.13
# - With 1200 epochs, MSE : 10.58, KL : 8.90, Cost: 10.67
# - With 1300 epochs, MSE : 1.19, KL : 8.98, Cost: 1.28
# - With 1300 epochs, MSE : 3.14, KL : 8.98, Cost: 3.23
# - With 1400 epochs, MSE : 1.24, KL : 9.04, Cost: 1.33
# - With 1400 epochs, MSE : 3.53, KL : 9.04, Cost: 3.62
# - With 1500 epochs, MSE : 1.10, KL : 8.85, Cost: 1.18
# - With 1500 epochs, MSE : 1.52, KL : 8.85, Cost: 1.61
# - With 1600 epochs, MSE : 1.64, KL : 8.64, Cost: 1.72
# - With 1600 epochs, MSE : 1.50, KL : 8.64, Cost: 1.58
# - With 1700 epochs, MSE : 1.53, KL : 8.94, Cost: 1.62
# - With 1700 epochs, MSE : 2.11, KL : 8.94, Cost: 2.20
# - With 1800 epochs, MSE : 1.00, KL : 8.59, Cost: 1.09
# - With 1800 epochs, MSE : 1.24, KL : 8.59, Cost: 1.32
# - With 1900 epochs, MSE : 1.31, KL : 8.75, Cost: 1.40
# - With 1900 epochs, MSE : 1.04, KL : 8.75, Cost: 1.13
# - With 2000 epochs, MSE : 1.43, KL : 8.63, Cost: 1.51
# - With 2000 epochs, MSE : 1.37, KL : 8.63, Cost: 1.46
# - With 2100 epochs, MSE : 2.14, KL : 8.60, Cost: 2.23
# - With 2100 epochs, MSE : 1.72, KL : 8.60, Cost: 1.80
# - With 2200 epochs, MSE : 4.50, KL : 8.73, Cost: 4.59
# - With 2200 epochs, MSE : 3.93, KL : 8.73, Cost: 4.02
# - With 2300 epochs, MSE : 1.21, KL : 8.57, Cost: 1.30
# - With 2300 epochs, MSE : 4.19, KL : 8.57, Cost: 4.28
# - With 2400 epochs, MSE : 2.66, KL : 8.72, Cost: 2.75
# - With 2400 epochs, MSE : 1.41, KL : 8.72, Cost: 1.49
# - With 2500 epochs, MSE : 0.99, KL : 8.75, Cost: 1.08
# - With 2500 epochs, MSE : 0.78, KL : 8.75, Cost: 0.87
#     cost_train_0.01  cost_test_0.01  epochs
# 0         10.117093       51.137634   100.0
# 1         12.347646        9.547413   200.0
# 2         13.974672        7.872366   300.0
# 3         10.107518        3.584288   400.0
# 4         18.181030        4.983852   500.0
# 5          3.506490       12.751767   600.0
# 6          1.186049        3.275773   700.0
# 7          3.007474        4.950253   800.0
# 8         18.160999       16.821724   900.0
# 9          1.694608        9.967265  1000.0
# 10         2.898839        5.375224  1100.0
# 11         4.133585       10.673746  1200.0
# 12         1.281725        3.233927  1300.0
# 13         1.327402        3.624177  1400.0
# 14         1.184936        1.610193  1500.0
# 15         1.724791        1.583266  1600.0
# 16         1.620240        2.201125  1700.0
# 17         1.088825        1.322130  1800.0
# 18         1.397225        1.125506  1900.0
# 19         1.511605        1.455420  2000.0
# 20         2.228695        1.801519  2100.0
# 21         4.587991        4.017515  2200.0
# 22         1.299822        4.277695  2300.0
# 23         2.747612        1.492489  2400.0
# 24         1.078350        0.871259  2500.0

# %%
#generating data for df2
df2 = pd.DataFrame({"epochs": [epochs for epochs in range(100, 1501, 100)]})
for lr in lr_rates:
    print(f"lr: {lr}")
    df2 = pd.merge(df2, generate_data(lr), on="epochs")

df2

#todo: increase the range of epochs: done
#todo: instead of storing cost values in arrays, store them in a csv file: done
#todo: convert this cell into a function: done
#todo: once you've figured out multi-dimensiionality, come back to this to find the effect of the learning rate on the cost
# Out:
# lr: 0.1
# - With 100 epochs, MSE : 67.46, KL : 17.96, Cost: 67.64
# - With 100 epochs, MSE : 84.34, KL : 18.03, Cost: 84.52
# - With 200 epochs, MSE : 45.27, KL : 22.11, Cost: 45.49
# - With 200 epochs, MSE : 27.49, KL : 22.12, Cost: 27.71
# - With 300 epochs, MSE : 10.27, KL : 22.17, Cost: 10.49
# - With 300 epochs, MSE : 11.08, KL : 22.17, Cost: 11.30
# - With 400 epochs, MSE : 6.23, KL : 23.26, Cost: 6.46
# - With 400 epochs, MSE : 1.47, KL : 23.26, Cost: 1.70
# - With 500 epochs, MSE : 3.02, KL : 23.81, Cost: 3.26
# - With 500 epochs, MSE : 2.21, KL : 23.81, Cost: 2.45
# - With 600 epochs, MSE : 1.06, KL : 24.36, Cost: 1.31
# - With 600 epochs, MSE : 2.61, KL : 24.36, Cost: 2.86
# - With 700 epochs, MSE : 2.10, KL : 21.98, Cost: 2.32
# - With 700 epochs, MSE : 1.73, KL : 21.98, Cost: 1.95
# - With 800 epochs, MSE : 0.66, KL : 23.92, Cost: 0.89
# - With 800 epochs, MSE : 1.22, KL : 23.91, Cost: 1.46
# - With 900 epochs, MSE : 2.41, KL : 26.55, Cost: 2.68
# - With 900 epochs, MSE : 5.65, KL : 26.55, Cost: 5.92
# - With 1000 epochs, MSE : 0.93, KL : 22.81, Cost: 1.16
# - With 1000 epochs, MSE : 2.33, KL : 22.81, Cost: 2.56
# - With 1100 epochs, MSE : 0.83, KL : 25.06, Cost: 1.08
# - With 1100 epochs, MSE : 0.73, KL : 25.07, Cost: 0.98
# - With 1200 epochs, MSE : 6.34, KL : 26.32, Cost: 6.60
# - With 1200 epochs, MSE : 7.22, KL : 26.34, Cost: 7.49
# - With 1300 epochs, MSE : 3.45, KL : 23.93, Cost: 3.69
# - With 1300 epochs, MSE : 1.04, KL : 23.94, Cost: 1.28
# - With 1400 epochs, MSE : 0.73, KL : 26.75, Cost: 1.00
# - With 1400 epochs, MSE : 0.50, KL : 26.75, Cost: 0.77
# - With 1500 epochs, MSE : 0.79, KL : 23.80, Cost: 1.03
# - With 1500 epochs, MSE : 0.63, KL : 23.80, Cost: 0.87
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\resul\OneDrive\Physics\Final Year\PH30036\project_script\src\week4\datasets_vs_epochs.ipynb Cell 12 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/resul/OneDrive/Physics/Final%20Year/PH30036/project_script/src/week4/datasets_vs_epochs.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> for lr in lr_rates:
#       <a href='vscode-notebook-cell:/c%3A/Users/resul/OneDrive/Physics/Final%20Year/PH30036/project_script/src/week4/datasets_vs_epochs.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a>     print(f"lr: {lr}")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/resul/OneDrive/Physics/Final%20Year/PH30036/project_script/src/week4/datasets_vs_epochs.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a>     df2 = pd.merge(df2, generate_data(lr), on="epochs")
#       <a href='vscode-notebook-cell:/c%3A/Users/resul/OneDrive/Physics/Final%20Year/PH30036/project_script/src/week4/datasets_vs_epochs.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a> df2
#       <a href='vscode-notebook-cell:/c%3A/Users/resul/OneDrive/Physics/Final%20Year/PH30036/project_script/src/week4/datasets_vs_epochs.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a> #todo: increase the range of epochs: done
#       <a href='vscode-notebook-cell:/c%3A/Users/resul/OneDrive/Physics/Final%20Year/PH30036/project_script/src/week4/datasets_vs_epochs.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a> #todo: instead of storing cost values in arrays, store them in a csv file: done
#      <a href='vscode-notebook-cell:/c%3A/Users/resul/OneDrive/Physics/Final%20Year/PH30036/project_script/src/week4/datasets_vs_epochs.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a> #todo: convert this cell into a function: done
#      <a href='vscode-notebook-cell:/c%3A/Users/resul/OneDrive/Physics/Final%20Year/PH30036/project_script/src/week4/datasets_vs_epochs.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a> #todo: once you've figured out multi-dimensiionality, come back to this to find the effect of the learning rate on the cost
#
# File c:\Users\resul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File c:\Users\resul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File c:\Users\resul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:1179, in _MergeOperation._get_merge_keys(self)
#    1175 if lk is not None:
#    1176     # Then we're either Hashable or a wrong-length arraylike,
#    1177     #  the latter of which will raise
#    1178     lk = cast(Hashable, lk)
# -> 1179     left_keys.append(left._get_label_or_level_values(lk))
#    1180     join_names.append(lk)
#    1181 else:
#    1182     # work-around for merge_asof(left_index=True)
#
# File c:\Users\resul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'epochs'

# %% [markdown]
# Okay, I've got the data as a .csv file. Now, I'm going to write a function that'll plot both the train and test costs against epochs.

# %%
# Plotting the results
plt.figure(figsize=(10, 7))
# plt.plot(
#     df1["epochs"], 
#     df1["cost_train_0.01"], 
#     color='blue',
#     marker='o',
#     markersize=7,
#     linestyle='None',
#     label='Train Cost'
# )

plt.plot(
    df1["epochs"], 
    df1["cost_test_0.01"], 
    color='red',
    marker='o',
    markersize=3,
    linestyle='--',
    label='Test Cost'
)

plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Cost')
plt.tight_layout()

plt.savefig('../../plots/cost_vs_epochs.pdf')
