# %%
import radiative_transfer_bnn as rt

import torch

import numpy as np

import matplotlib.pyplot as plt

import plotter as pltr

import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6e5c0fb3b725> in <module>
# ----> 1 import radiative_transfer_bnn as rt
#       2
#       3 import torch
#       4
#       5 import numpy as np
#
# ~\OneDrive\Desktop\Physics_Year_3\Final_year_project\Github\project_script\src\semester2\week6\radiative_transfer_bnn.py in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import torch
#       4 import torch.nn as nn
#       5 import torchbnn as bnn
#
# ModuleNotFoundError: No module named 'torch'

# %%
# model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux')
# model.preprocess_data()
# model.train_model(250, 200)
# wavelength = model.wavelength
# mean_pred_results, std_pred_results = model.test_model()
# x_test = model.X_test
# y_test = model.y_test

# %%
# model.save_model("testmodel")
# model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux', saved_model_filename= "testmodel")

# %%
# cost_vs_epoch_df = model.cost_vs_epoch()

# %%
# plotter = pltr.Plotter(cost_vs_epoch_df['epoch'],cost_vs_epoch_df['cost'])
# plotter.cost_vs_epochs()

# %%
# star_mass = torch.linspace(3.5, 15.5, 20)
# dust_mass = torch.linspace(7, 7, 20)
# theta = torch.linspace(90, 90, 20)
# x_pred = model.create_predict_tensor(star_mass, dust_mass, theta)
# print(x_pred.shape)
# mean_pred_results, std_pred_results = model.predict(x_pred)

# %%
# plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test,"f")
# plotter.plot_same_ax(0,20,1)

#it's not changing enough for angle
# you can only notice a change by going outside the range of values
#is this to do with normalisation when training the model?
# most likely
#is it worth seeing how SKIRT changes with angle?
#maybe create a function that groups SKIRT data over a range, no we need to generate more for fixed values
#see if the sub-runs are any different, for, like, 3-4 runs; if no conclusive difference, then yeah

# %%
# np.savez('data_file.npz', wavelength=wavelength, mean_pred_results=mean_pred_results,
#         std_pred_results=std_pred_results, x_test=x_test, y_test=y_test)

# %%
# loaded_data = np.load('data_file.npz')
# wavelength = loaded_data['wavelength']
# mean_pred_results = loaded_data['mean_pred_results']
# std_pred_results = loaded_data['std_pred_results']
# x_test = loaded_data['x_test']
# y_test = loaded_data['y_test']

# %%
# print(mean_pred_results)

# %%
# plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test, output = "f")

# #plotter.plot_single(150, "grey", "salmon")
# #plotter.plot_group_same(0, 40, "grey", "salmon")
# plotter.plot_same_ax(1,200,50,'cool')
# #plotter.save_figure("test.png")

# %%
#write prdeict function on saved model
#linear interpolation of extremes
#can only predict within the range of the training data
#what about extrapolation?
#comapare for extraploation can use predict function
#what is the uncertainty of the prediction
#Produce SED

# %%
#plotter function add std deviation
#change labels
#cost_vs_epochs plot
#ask steven about datd
#generate data for fixed values

# %%
model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux')
model.preprocess_data()
model.train_model(500, 200)
wavelength = model.wavelength
mean_pred_results, std_pred_results = model.test_model()
x_test = model.X_test
y_test = model.y_test
# Out:
# c:\Users\joshu\OneDrive\Desktop\Physics_Year_3\Final_year_project\Github\project_script\src\semester2\week6\radiative_transfer_bnn.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([
# Index(['log_mstar', 'log_mdust_over_mstar', 'theta'], dtype='object')
# Training the model...
# - epoch 1/500 - cost: 24.508, kl:                 0.056
# - epoch 2/500 - cost: 16.957, kl:                 0.085
# - epoch 3/500 - cost: 15.142, kl:                 0.111
# - epoch 4/500 - cost: 8.771, kl:                 0.137
# - epoch 5/500 - cost: 8.027, kl:                 0.159
# - epoch 6/500 - cost: 6.352, kl:                 0.174
# - epoch 7/500 - cost: 5.762, kl:                 0.184
# - epoch 8/500 - cost: 5.269, kl:                 0.193
# - epoch 9/500 - cost: 4.862, kl:                 0.200
# - epoch 10/500 - cost: 4.597, kl:                 0.205
# - epoch 11/500 - cost: 4.146, kl:                 0.209
# - epoch 12/500 - cost: 3.775, kl:                 0.212
# - epoch 13/500 - cost: 3.307, kl:                 0.216
# - epoch 14/500 - cost: 3.214, kl:                 0.218
# - epoch 15/500 - cost: 3.166, kl:                 0.221
# - epoch 16/500 - cost: 2.820, kl:                 0.223
# - epoch 17/500 - cost: 2.453, kl:                 0.226
# - epoch 18/500 - cost: 2.718, kl:                 0.228
# - epoch 19/500 - cost: 2.584, kl:                 0.231
# - epoch 20/500 - cost: 2.634, kl:                 0.233
# - epoch 21/500 - cost: 2.403, kl:                 0.236
# - epoch 22/500 - cost: 2.208, kl:                 0.239
# - epoch 23/500 - cost: 2.296, kl:                 0.241
# - epoch 24/500 - cost: 2.249, kl:                 0.244
# - epoch 25/500 - cost: 2.315, kl:                 0.247
# - epoch 26/500 - cost: 2.532, kl:                 0.250
# - epoch 27/500 - cost: 2.340, kl:                 0.253
# - epoch 28/500 - cost: 1.826, kl:                 0.257
# - epoch 29/500 - cost: 2.153, kl:                 0.261
# - epoch 30/500 - cost: 2.012, kl:                 0.264
# - epoch 31/500 - cost: 1.843, kl:                 0.267
# - epoch 32/500 - cost: 1.756, kl:                 0.271
# - epoch 33/500 - cost: 2.023, kl:                 0.274
# - epoch 34/500 - cost: 1.750, kl:                 0.277
# - epoch 35/500 - cost: 1.747, kl:                 0.280
# - epoch 36/500 - cost: 1.857, kl:                 0.282
# - epoch 37/500 - cost: 1.635, kl:                 0.285
# - epoch 38/500 - cost: 1.825, kl:                 0.288
# - epoch 39/500 - cost: 1.801, kl:                 0.291
# - epoch 40/500 - cost: 2.001, kl:                 0.295
# - epoch 41/500 - cost: 1.290, kl:                 0.299
# - epoch 42/500 - cost: 1.831, kl:                 0.302
# - epoch 43/500 - cost: 1.688, kl:                 0.306
# - epoch 44/500 - cost: 1.829, kl:                 0.309
# - epoch 45/500 - cost: 2.030, kl:                 0.313
# - epoch 46/500 - cost: 1.693, kl:                 0.316
# - epoch 47/500 - cost: 1.422, kl:                 0.319
# - epoch 48/500 - cost: 1.708, kl:                 0.322
# - epoch 49/500 - cost: 1.522, kl:                 0.325
# - epoch 50/500 - cost: 1.611, kl:                 0.328
# - epoch 51/500 - cost: 1.323, kl:                 0.331
# - epoch 52/500 - cost: 1.691, kl:                 0.335
# - epoch 53/500 - cost: 1.533, kl:                 0.338
# - epoch 54/500 - cost: 1.642, kl:                 0.341
# - epoch 55/500 - cost: 1.755, kl:                 0.344
# - epoch 56/500 - cost: 1.495, kl:                 0.346
# - epoch 57/500 - cost: 1.193, kl:                 0.349
# - epoch 58/500 - cost: 1.268, kl:                 0.352
# - epoch 59/500 - cost: 1.222, kl:                 0.354
# - epoch 60/500 - cost: 1.061, kl:                 0.357
# - epoch 61/500 - cost: 1.160, kl:                 0.359
# - epoch 62/500 - cost: 1.804, kl:                 0.362
# - epoch 63/500 - cost: 1.319, kl:                 0.364
# - epoch 64/500 - cost: 1.387, kl:                 0.367
# - epoch 65/500 - cost: 1.558, kl:                 0.370
# - epoch 66/500 - cost: 1.029, kl:                 0.373
# - epoch 67/500 - cost: 2.051, kl:                 0.376
# - epoch 68/500 - cost: 1.282, kl:                 0.378
# - epoch 69/500 - cost: 1.325, kl:                 0.381
# - epoch 70/500 - cost: 1.038, kl:                 0.384
# - epoch 71/500 - cost: 0.999, kl:                 0.387
# - epoch 72/500 - cost: 1.130, kl:                 0.389
# - epoch 73/500 - cost: 1.269, kl:                 0.391
# - epoch 74/500 - cost: 1.190, kl:                 0.393
# - epoch 75/500 - cost: 1.777, kl:                 0.395
# - epoch 76/500 - cost: 1.224, kl:                 0.398
# - epoch 77/500 - cost: 1.068, kl:                 0.400
# - epoch 78/500 - cost: 1.494, kl:                 0.402
# - epoch 79/500 - cost: 1.877, kl:                 0.404
# - epoch 80/500 - cost: 0.987, kl:                 0.407
# - epoch 81/500 - cost: 3.020, kl:                 0.410
# - epoch 82/500 - cost: 1.434, kl:                 0.412
# - epoch 83/500 - cost: 1.968, kl:                 0.415
# - epoch 84/500 - cost: 1.124, kl:                 0.417
# - epoch 85/500 - cost: 0.923, kl:                 0.421
# - epoch 86/500 - cost: 1.636, kl:                 0.423
# - epoch 87/500 - cost: 1.213, kl:                 0.425
# - epoch 88/500 - cost: 0.991, kl:                 0.428
# - epoch 89/500 - cost: 1.109, kl:                 0.430
# - epoch 90/500 - cost: 1.430, kl:                 0.433
# - epoch 91/500 - cost: 0.919, kl:                 0.435
# - epoch 92/500 - cost: 0.912, kl:                 0.437
# - epoch 93/500 - cost: 1.053, kl:                 0.439
# - epoch 94/500 - cost: 0.985, kl:                 0.441
# - epoch 95/500 - cost: 2.944, kl:                 0.443
# - epoch 96/500 - cost: 1.509, kl:                 0.444
# - epoch 97/500 - cost: 0.837, kl:                 0.447
# - epoch 98/500 - cost: 1.369, kl:                 0.449
# - epoch 99/500 - cost: 2.214, kl:                 0.452
# - epoch 100/500 - cost: 0.910, kl:                 0.454
# - epoch 101/500 - cost: 1.202, kl:                 0.458
# - epoch 102/500 - cost: 0.935, kl:                 0.460
# - epoch 103/500 - cost: 0.809, kl:                 0.462
# - epoch 104/500 - cost: 1.539, kl:                 0.464
# - epoch 105/500 - cost: 0.896, kl:                 0.465
# - epoch 106/500 - cost: 0.914, kl:                 0.468
# - epoch 107/500 - cost: 1.152, kl:                 0.469
# - epoch 108/500 - cost: 1.100, kl:                 0.471
# - epoch 109/500 - cost: 1.014, kl:                 0.473
# - epoch 110/500 - cost: 1.682, kl:                 0.475
# - epoch 111/500 - cost: 0.906, kl:                 0.477
# - epoch 112/500 - cost: 1.112, kl:                 0.478
# - epoch 113/500 - cost: 0.971, kl:                 0.480
# - epoch 114/500 - cost: 0.917, kl:                 0.482
# - epoch 115/500 - cost: 1.217, kl:                 0.483
# - epoch 116/500 - cost: 1.144, kl:                 0.486
# - epoch 117/500 - cost: 0.767, kl:                 0.487
# - epoch 118/500 - cost: 1.260, kl:                 0.490
# - epoch 119/500 - cost: 0.790, kl:                 0.491
# - epoch 120/500 - cost: 1.061, kl:                 0.494
# - epoch 121/500 - cost: 0.702, kl:                 0.496
# - epoch 122/500 - cost: 0.904, kl:                 0.498
# - epoch 123/500 - cost: 0.788, kl:                 0.499
# - epoch 124/500 - cost: 1.210, kl:                 0.501
# - epoch 125/500 - cost: 0.929, kl:                 0.503
# - epoch 126/500 - cost: 0.943, kl:                 0.505
# - epoch 127/500 - cost: 0.844, kl:                 0.507
# - epoch 128/500 - cost: 1.074, kl:                 0.508
# - epoch 129/500 - cost: 1.086, kl:                 0.510
# - epoch 130/500 - cost: 1.099, kl:                 0.512
# - epoch 131/500 - cost: 1.025, kl:                 0.514
# - epoch 132/500 - cost: 1.183, kl:                 0.516
# - epoch 133/500 - cost: 0.679, kl:                 0.518
# - epoch 134/500 - cost: 1.132, kl:                 0.521
# - epoch 135/500 - cost: 0.824, kl:                 0.523
# - epoch 136/500 - cost: 0.790, kl:                 0.525
# - epoch 137/500 - cost: 1.012, kl:                 0.526
# - epoch 138/500 - cost: 0.789, kl:                 0.528
# - epoch 139/500 - cost: 0.859, kl:                 0.530
# - epoch 140/500 - cost: 0.723, kl:                 0.531
# - epoch 141/500 - cost: 1.241, kl:                 0.533
# - epoch 142/500 - cost: 0.819, kl:                 0.535
# - epoch 143/500 - cost: 0.640, kl:                 0.537
# - epoch 144/500 - cost: 1.144, kl:                 0.538
# - epoch 145/500 - cost: 0.784, kl:                 0.540
# - epoch 146/500 - cost: 0.777, kl:                 0.541
# - epoch 147/500 - cost: 1.101, kl:                 0.543
# - epoch 148/500 - cost: 0.941, kl:                 0.544
# - epoch 149/500 - cost: 1.291, kl:                 0.546
# - epoch 150/500 - cost: 0.998, kl:                 0.548
# - epoch 151/500 - cost: 0.805, kl:                 0.549
# - epoch 152/500 - cost: 0.998, kl:                 0.551
# - epoch 153/500 - cost: 0.978, kl:                 0.553
# - epoch 154/500 - cost: 0.856, kl:                 0.554
# - epoch 155/500 - cost: 0.889, kl:                 0.556
# - epoch 156/500 - cost: 0.951, kl:                 0.557
# - epoch 157/500 - cost: 0.771, kl:                 0.559
# - epoch 158/500 - cost: 0.944, kl:                 0.560
# - epoch 159/500 - cost: 0.712, kl:                 0.562
# - epoch 160/500 - cost: 0.710, kl:                 0.563
# - epoch 161/500 - cost: 0.753, kl:                 0.565
# - epoch 162/500 - cost: 0.841, kl:                 0.566
# - epoch 163/500 - cost: 0.591, kl:                 0.568
# - epoch 164/500 - cost: 0.796, kl:                 0.569
# - epoch 165/500 - cost: 0.561, kl:                 0.570
# - epoch 166/500 - cost: 0.825, kl:                 0.571
# - epoch 167/500 - cost: 0.712, kl:                 0.572
# - epoch 168/500 - cost: 0.698, kl:                 0.573
# - epoch 169/500 - cost: 0.758, kl:                 0.574
# - epoch 170/500 - cost: 1.280, kl:                 0.576
# - epoch 171/500 - cost: 0.669, kl:                 0.578
# - epoch 172/500 - cost: 0.784, kl:                 0.579
# - epoch 173/500 - cost: 0.676, kl:                 0.581
# - epoch 174/500 - cost: 1.079, kl:                 0.582
# - epoch 175/500 - cost: 1.232, kl:                 0.584
# - epoch 176/500 - cost: 0.682, kl:                 0.585
# - epoch 177/500 - cost: 0.729, kl:                 0.587
# - epoch 178/500 - cost: 0.710, kl:                 0.589
# - epoch 179/500 - cost: 0.675, kl:                 0.591
# - epoch 180/500 - cost: 0.855, kl:                 0.593
# - epoch 181/500 - cost: 0.801, kl:                 0.594
# - epoch 182/500 - cost: 0.593, kl:                 0.596
# - epoch 183/500 - cost: 0.757, kl:                 0.597
# - epoch 184/500 - cost: 0.658, kl:                 0.599
# - epoch 185/500 - cost: 0.717, kl:                 0.600
# - epoch 186/500 - cost: 0.836, kl:                 0.601
# - epoch 187/500 - cost: 0.696, kl:                 0.603
# - epoch 188/500 - cost: 0.655, kl:                 0.604
# - epoch 189/500 - cost: 0.672, kl:                 0.605
# - epoch 190/500 - cost: 0.532, kl:                 0.605
# - epoch 191/500 - cost: 0.508, kl:                 0.606
# - epoch 192/500 - cost: 0.896, kl:                 0.607
# - epoch 193/500 - cost: 0.622, kl:                 0.608
# - epoch 194/500 - cost: 0.712, kl:                 0.609
# - epoch 195/500 - cost: 0.925, kl:                 0.610
# - epoch 196/500 - cost: 0.701, kl:                 0.611
# - epoch 197/500 - cost: 0.658, kl:                 0.612
# - epoch 198/500 - cost: 0.925, kl:                 0.615
# - epoch 199/500 - cost: 0.700, kl:                 0.617
# - epoch 200/500 - cost: 0.904, kl:                 0.619
# - epoch 201/500 - cost: 0.537, kl:                 0.621
# - epoch 202/500 - cost: 1.056, kl:                 0.622
# - epoch 203/500 - cost: 0.532, kl:                 0.623
# - epoch 204/500 - cost: 0.846, kl:                 0.625
# - epoch 205/500 - cost: 0.538, kl:                 0.626
# - epoch 206/500 - cost: 0.669, kl:                 0.627
# - epoch 207/500 - cost: 0.623, kl:                 0.628
# - epoch 208/500 - cost: 0.681, kl:                 0.630
# - epoch 209/500 - cost: 0.610, kl:                 0.631
# - epoch 210/500 - cost: 0.570, kl:                 0.633
# - epoch 211/500 - cost: 0.588, kl:                 0.634
# - epoch 212/500 - cost: 0.704, kl:                 0.635
# - epoch 213/500 - cost: 0.470, kl:                 0.636
# - epoch 214/500 - cost: 0.586, kl:                 0.637
# - epoch 215/500 - cost: 0.668, kl:                 0.637
# - epoch 216/500 - cost: 0.500, kl:                 0.638
# - epoch 217/500 - cost: 0.526, kl:                 0.638
# - epoch 218/500 - cost: 0.634, kl:                 0.638
# - epoch 219/500 - cost: 0.603, kl:                 0.639
# - epoch 220/500 - cost: 0.625, kl:                 0.640
# - epoch 221/500 - cost: 0.534, kl:                 0.641
# - epoch 222/500 - cost: 0.607, kl:                 0.641
# - epoch 223/500 - cost: 0.626, kl:                 0.642
# - epoch 224/500 - cost: 0.570, kl:                 0.642
# - epoch 225/500 - cost: 0.518, kl:                 0.643
# - epoch 226/500 - cost: 0.541, kl:                 0.643
# - epoch 227/500 - cost: 0.559, kl:                 0.643
# - epoch 228/500 - cost: 0.687, kl:                 0.644
# - epoch 229/500 - cost: 0.532, kl:                 0.644
# - epoch 230/500 - cost: 0.473, kl:                 0.645
# - epoch 231/500 - cost: 0.568, kl:                 0.645
# - epoch 232/500 - cost: 1.007, kl:                 0.646
# - epoch 233/500 - cost: 0.597, kl:                 0.646
# - epoch 234/500 - cost: 0.687, kl:                 0.647
# - epoch 235/500 - cost: 0.518, kl:                 0.648
# - epoch 236/500 - cost: 0.596, kl:                 0.650
# - epoch 237/500 - cost: 0.633, kl:                 0.651
# - epoch 238/500 - cost: 0.912, kl:                 0.652
# - epoch 239/500 - cost: 0.651, kl:                 0.653
# - epoch 240/500 - cost: 0.464, kl:                 0.654
# - epoch 241/500 - cost: 0.516, kl:                 0.654
# - epoch 242/500 - cost: 0.644, kl:                 0.655
# - epoch 243/500 - cost: 0.436, kl:                 0.656
# - epoch 244/500 - cost: 0.495, kl:                 0.656
# - epoch 245/500 - cost: 0.542, kl:                 0.656
# - epoch 246/500 - cost: 0.595, kl:                 0.657
# - epoch 247/500 - cost: 0.666, kl:                 0.657
# - epoch 248/500 - cost: 0.512, kl:                 0.657
# - epoch 249/500 - cost: 0.596, kl:                 0.657
# - epoch 250/500 - cost: 0.459, kl:                 0.657
# - epoch 251/500 - cost: 0.654, kl:                 0.657
# - epoch 252/500 - cost: 0.729, kl:                 0.657
# - epoch 253/500 - cost: 0.622, kl:                 0.658
# - epoch 254/500 - cost: 0.502, kl:                 0.658
# - epoch 255/500 - cost: 0.661, kl:                 0.658
# - epoch 256/500 - cost: 0.461, kl:                 0.658
# - epoch 257/500 - cost: 0.572, kl:                 0.658
# - epoch 258/500 - cost: 0.480, kl:                 0.658
# - epoch 259/500 - cost: 0.438, kl:                 0.658
# - epoch 260/500 - cost: 0.427, kl:                 0.658
# - epoch 261/500 - cost: 0.621, kl:                 0.658
# - epoch 262/500 - cost: 0.955, kl:                 0.658
# - epoch 263/500 - cost: 0.497, kl:                 0.659
# - epoch 264/500 - cost: 0.415, kl:                 0.659
# - epoch 265/500 - cost: 0.492, kl:                 0.659
# - epoch 266/500 - cost: 0.513, kl:                 0.660
# - epoch 267/500 - cost: 0.503, kl:                 0.660
# - epoch 268/500 - cost: 0.462, kl:                 0.660
# - epoch 269/500 - cost: 0.656, kl:                 0.660
# - epoch 270/500 - cost: 0.441, kl:                 0.661
# - epoch 271/500 - cost: 0.541, kl:                 0.661
# - epoch 272/500 - cost: 0.449, kl:                 0.661
# - epoch 273/500 - cost: 0.428, kl:                 0.661
# - epoch 274/500 - cost: 0.780, kl:                 0.661
# - epoch 275/500 - cost: 0.576, kl:                 0.661
# - epoch 276/500 - cost: 0.411, kl:                 0.662
# - epoch 277/500 - cost: 0.541, kl:                 0.662
# - epoch 278/500 - cost: 0.625, kl:                 0.662
# - epoch 279/500 - cost: 0.655, kl:                 0.662
# - epoch 280/500 - cost: 0.547, kl:                 0.663
# - epoch 281/500 - cost: 0.477, kl:                 0.662
# - epoch 282/500 - cost: 0.461, kl:                 0.663
# - epoch 283/500 - cost: 0.822, kl:                 0.663
# - epoch 284/500 - cost: 0.492, kl:                 0.663
# - epoch 285/500 - cost: 0.413, kl:                 0.663
# - epoch 286/500 - cost: 0.482, kl:                 0.664
# - epoch 287/500 - cost: 0.453, kl:                 0.664
# - epoch 288/500 - cost: 0.456, kl:                 0.664
# - epoch 289/500 - cost: 0.447, kl:                 0.664
# - epoch 290/500 - cost: 0.432, kl:                 0.664
# - epoch 291/500 - cost: 0.501, kl:                 0.664
# - epoch 292/500 - cost: 0.467, kl:                 0.664
# - epoch 293/500 - cost: 0.426, kl:                 0.665
# - epoch 294/500 - cost: 0.420, kl:                 0.665
# - epoch 295/500 - cost: 0.601, kl:                 0.665
# - epoch 296/500 - cost: 0.635, kl:                 0.665
# - epoch 297/500 - cost: 0.493, kl:                 0.665
# - epoch 298/500 - cost: 0.453, kl:                 0.666
# - epoch 299/500 - cost: 0.460, kl:                 0.667
# - epoch 300/500 - cost: 0.503, kl:                 0.668
# - epoch 301/500 - cost: 0.724, kl:                 0.668
# - epoch 302/500 - cost: 0.549, kl:                 0.668
# - epoch 303/500 - cost: 0.518, kl:                 0.669
# - epoch 304/500 - cost: 0.468, kl:                 0.669
# - epoch 305/500 - cost: 0.571, kl:                 0.670
# - epoch 306/500 - cost: 0.523, kl:                 0.669
# - epoch 307/500 - cost: 0.510, kl:                 0.670
# - epoch 308/500 - cost: 0.518, kl:                 0.669
# - epoch 309/500 - cost: 0.404, kl:                 0.669
# - epoch 310/500 - cost: 0.474, kl:                 0.669
# - epoch 311/500 - cost: 0.629, kl:                 0.669
# - epoch 312/500 - cost: 0.524, kl:                 0.669
# - epoch 313/500 - cost: 0.390, kl:                 0.669
# - epoch 314/500 - cost: 0.658, kl:                 0.669
# - epoch 315/500 - cost: 0.383, kl:                 0.669
# - epoch 316/500 - cost: 0.471, kl:                 0.668
# - epoch 317/500 - cost: 0.492, kl:                 0.668
# - epoch 318/500 - cost: 0.563, kl:                 0.668
# - epoch 319/500 - cost: 0.477, kl:                 0.668
# - epoch 320/500 - cost: 0.411, kl:                 0.668
# - epoch 321/500 - cost: 0.514, kl:                 0.669
# - epoch 322/500 - cost: 0.461, kl:                 0.668
# - epoch 323/500 - cost: 0.613, kl:                 0.668
# - epoch 324/500 - cost: 0.565, kl:                 0.668
# - epoch 325/500 - cost: 0.682, kl:                 0.668
# - epoch 326/500 - cost: 0.344, kl:                 0.668
# - epoch 327/500 - cost: 0.416, kl:                 0.667
# - epoch 328/500 - cost: 0.408, kl:                 0.668
# - epoch 329/500 - cost: 0.527, kl:                 0.667
# - epoch 330/500 - cost: 0.405, kl:                 0.667
# - epoch 331/500 - cost: 0.499, kl:                 0.667
# - epoch 332/500 - cost: 0.550, kl:                 0.667
# - epoch 333/500 - cost: 0.374, kl:                 0.667
# - epoch 334/500 - cost: 0.418, kl:                 0.667
# - epoch 335/500 - cost: 0.397, kl:                 0.667
# - epoch 336/500 - cost: 0.591, kl:                 0.667
# - epoch 337/500 - cost: 0.523, kl:                 0.667
# - epoch 338/500 - cost: 0.395, kl:                 0.667
# - epoch 339/500 - cost: 0.414, kl:                 0.667
# - epoch 340/500 - cost: 0.347, kl:                 0.667
# - epoch 341/500 - cost: 0.382, kl:                 0.666
# - epoch 342/500 - cost: 0.350, kl:                 0.666
# - epoch 343/500 - cost: 0.352, kl:                 0.666
# - epoch 344/500 - cost: 0.347, kl:                 0.665
# - epoch 345/500 - cost: 0.354, kl:                 0.665
# - epoch 346/500 - cost: 0.358, kl:                 0.664
# - epoch 347/500 - cost: 0.517, kl:                 0.664
# - epoch 348/500 - cost: 0.381, kl:                 0.664
# - epoch 349/500 - cost: 0.437, kl:                 0.664
# - epoch 350/500 - cost: 0.495, kl:                 0.664
# - epoch 351/500 - cost: 0.320, kl:                 0.664
# - epoch 352/500 - cost: 0.435, kl:                 0.663
# - epoch 353/500 - cost: 0.437, kl:                 0.663
# - epoch 354/500 - cost: 0.483, kl:                 0.663
# - epoch 355/500 - cost: 0.467, kl:                 0.663
# - epoch 356/500 - cost: 0.353, kl:                 0.663
# - epoch 357/500 - cost: 0.439, kl:                 0.663
# - epoch 358/500 - cost: 0.557, kl:                 0.663
# - epoch 359/500 - cost: 0.325, kl:                 0.662
# - epoch 360/500 - cost: 0.529, kl:                 0.662
# - epoch 361/500 - cost: 0.485, kl:                 0.662
# - epoch 362/500 - cost: 1.145, kl:                 0.662
# - epoch 363/500 - cost: 0.478, kl:                 0.661
# - epoch 364/500 - cost: 0.404, kl:                 0.661
# - epoch 365/500 - cost: 0.447, kl:                 0.661
# - epoch 366/500 - cost: 0.697, kl:                 0.661
# - epoch 367/500 - cost: 0.393, kl:                 0.662
# - epoch 368/500 - cost: 0.332, kl:                 0.661
# - epoch 369/500 - cost: 0.564, kl:                 0.662
# - epoch 370/500 - cost: 0.341, kl:                 0.661
# - epoch 371/500 - cost: 0.378, kl:                 0.661
# - epoch 372/500 - cost: 0.337, kl:                 0.661
# - epoch 373/500 - cost: 0.301, kl:                 0.661
# - epoch 374/500 - cost: 0.382, kl:                 0.660
# - epoch 375/500 - cost: 0.450, kl:                 0.659
# - epoch 376/500 - cost: 0.377, kl:                 0.659
# - epoch 377/500 - cost: 0.441, kl:                 0.658
# - epoch 378/500 - cost: 0.382, kl:                 0.658
# - epoch 379/500 - cost: 0.401, kl:                 0.657
# - epoch 380/500 - cost: 0.386, kl:                 0.656
# - epoch 381/500 - cost: 0.306, kl:                 0.656
# - epoch 382/500 - cost: 0.335, kl:                 0.655
# - epoch 383/500 - cost: 0.328, kl:                 0.654
# - epoch 384/500 - cost: 0.347, kl:                 0.654
# - epoch 385/500 - cost: 0.330, kl:                 0.653
# - epoch 386/500 - cost: 0.320, kl:                 0.652
# - epoch 387/500 - cost: 0.454, kl:                 0.651
# - epoch 388/500 - cost: 0.657, kl:                 0.651
# - epoch 389/500 - cost: 0.323, kl:                 0.650
# - epoch 390/500 - cost: 0.442, kl:                 0.650
# - epoch 391/500 - cost: 0.320, kl:                 0.649
# - epoch 392/500 - cost: 0.284, kl:                 0.649
# - epoch 393/500 - cost: 0.340, kl:                 0.648
# - epoch 394/500 - cost: 0.327, kl:                 0.648
# - epoch 395/500 - cost: 0.328, kl:                 0.647
# - epoch 396/500 - cost: 0.288, kl:                 0.647
# - epoch 397/500 - cost: 0.333, kl:                 0.646
# - epoch 398/500 - cost: 0.370, kl:                 0.645
# - epoch 399/500 - cost: 0.433, kl:                 0.644
# - epoch 400/500 - cost: 0.362, kl:                 0.644
# - epoch 401/500 - cost: 0.362, kl:                 0.643
# - epoch 402/500 - cost: 0.348, kl:                 0.642
# - epoch 403/500 - cost: 0.329, kl:                 0.642
# - epoch 404/500 - cost: 0.399, kl:                 0.641
# - epoch 405/500 - cost: 0.355, kl:                 0.641
# - epoch 406/500 - cost: 0.280, kl:                 0.640
# - epoch 407/500 - cost: 0.370, kl:                 0.640
# - epoch 408/500 - cost: 0.318, kl:                 0.639
# - epoch 409/500 - cost: 0.357, kl:                 0.638
# - epoch 410/500 - cost: 0.312, kl:                 0.638
# - epoch 411/500 - cost: 0.304, kl:                 0.637
# - epoch 412/500 - cost: 0.479, kl:                 0.637
# - epoch 413/500 - cost: 0.348, kl:                 0.636
# - epoch 414/500 - cost: 0.369, kl:                 0.636
# - epoch 415/500 - cost: 0.536, kl:                 0.635
# - epoch 416/500 - cost: 0.324, kl:                 0.635
# - epoch 417/500 - cost: 0.409, kl:                 0.634
# - epoch 418/500 - cost: 0.362, kl:                 0.634
# - epoch 419/500 - cost: 0.335, kl:                 0.633
# - epoch 420/500 - cost: 0.335, kl:                 0.632
# - epoch 421/500 - cost: 0.350, kl:                 0.632
# - epoch 422/500 - cost: 0.526, kl:                 0.631
# - epoch 423/500 - cost: 0.314, kl:                 0.631
# - epoch 424/500 - cost: 0.354, kl:                 0.630
# - epoch 425/500 - cost: 0.330, kl:                 0.630
# - epoch 426/500 - cost: 0.348, kl:                 0.629
# - epoch 427/500 - cost: 0.332, kl:                 0.629
# - epoch 428/500 - cost: 0.307, kl:                 0.628
# - epoch 429/500 - cost: 0.327, kl:                 0.628
# - epoch 430/500 - cost: 0.335, kl:                 0.627
# - epoch 431/500 - cost: 0.327, kl:                 0.627
# - epoch 432/500 - cost: 0.249, kl:                 0.627
# - epoch 433/500 - cost: 0.290, kl:                 0.626
# - epoch 434/500 - cost: 0.350, kl:                 0.625
# - epoch 435/500 - cost: 0.330, kl:                 0.625
# - epoch 436/500 - cost: 0.323, kl:                 0.624
# - epoch 437/500 - cost: 0.370, kl:                 0.623
# - epoch 438/500 - cost: 0.360, kl:                 0.622
# - epoch 439/500 - cost: 0.281, kl:                 0.622
# - epoch 440/500 - cost: 0.340, kl:                 0.621
# - epoch 441/500 - cost: 0.273, kl:                 0.620
# - epoch 442/500 - cost: 0.364, kl:                 0.619
# - epoch 443/500 - cost: 0.285, kl:                 0.618
# - epoch 444/500 - cost: 0.315, kl:                 0.618
# - epoch 445/500 - cost: 0.384, kl:                 0.617
# - epoch 446/500 - cost: 0.284, kl:                 0.616
# - epoch 447/500 - cost: 0.478, kl:                 0.615
# - epoch 448/500 - cost: 0.276, kl:                 0.614
# - epoch 449/500 - cost: 0.336, kl:                 0.613
# - epoch 450/500 - cost: 0.365, kl:                 0.613
# - epoch 451/500 - cost: 0.350, kl:                 0.612
# - epoch 452/500 - cost: 0.270, kl:                 0.611
# - epoch 453/500 - cost: 0.301, kl:                 0.610
# - epoch 454/500 - cost: 0.365, kl:                 0.609
# - epoch 455/500 - cost: 0.274, kl:                 0.609
# - epoch 456/500 - cost: 0.311, kl:                 0.608
# - epoch 457/500 - cost: 0.267, kl:                 0.607
# - epoch 458/500 - cost: 0.262, kl:                 0.606
# - epoch 459/500 - cost: 0.235, kl:                 0.605
# - epoch 460/500 - cost: 0.284, kl:                 0.604
# - epoch 461/500 - cost: 0.356, kl:                 0.604
# - epoch 462/500 - cost: 0.330, kl:                 0.603
# - epoch 463/500 - cost: 0.282, kl:                 0.602
# - epoch 464/500 - cost: 0.372, kl:                 0.601
# - epoch 465/500 - cost: 0.308, kl:                 0.600
# - epoch 466/500 - cost: 0.282, kl:                 0.599
# - epoch 467/500 - cost: 0.460, kl:                 0.599
# - epoch 468/500 - cost: 0.312, kl:                 0.597
# - epoch 469/500 - cost: 0.305, kl:                 0.597
# - epoch 470/500 - cost: 0.362, kl:                 0.596
# - epoch 471/500 - cost: 0.379, kl:                 0.595
# - epoch 472/500 - cost: 0.279, kl:                 0.594
# - epoch 473/500 - cost: 0.329, kl:                 0.594
# - epoch 474/500 - cost: 0.301, kl:                 0.592
# - epoch 475/500 - cost: 0.338, kl:                 0.592
# - epoch 476/500 - cost: 0.327, kl:                 0.591
# - epoch 477/500 - cost: 0.332, kl:                 0.590
# - epoch 478/500 - cost: 0.315, kl:                 0.589
# - epoch 479/500 - cost: 0.273, kl:                 0.588
# - epoch 480/500 - cost: 0.317, kl:                 0.588
# - epoch 481/500 - cost: 0.318, kl:                 0.587
# - epoch 482/500 - cost: 0.348, kl:                 0.586
# - epoch 483/500 - cost: 0.253, kl:                 0.585
# - epoch 484/500 - cost: 0.266, kl:                 0.585
# - epoch 485/500 - cost: 0.268, kl:                 0.584
# - epoch 486/500 - cost: 0.313, kl:                 0.583
# - epoch 487/500 - cost: 0.316, kl:                 0.582
# - epoch 488/500 - cost: 0.267, kl:                 0.581
# - epoch 489/500 - cost: 0.332, kl:                 0.580
# - epoch 490/500 - cost: 0.293, kl:                 0.580
# - epoch 491/500 - cost: 0.260, kl:                 0.578
# - epoch 492/500 - cost: 0.225, kl:                 0.578
# - epoch 493/500 - cost: 0.268, kl:                 0.577
# - epoch 494/500 - cost: 0.263, kl:                 0.576
# - epoch 495/500 - cost: 0.276, kl:                 0.575
# - epoch 496/500 - cost: 0.270, kl:                 0.574
# - epoch 497/500 - cost: 0.304, kl:                 0.573
# - epoch 498/500 - cost: 0.263, kl:                 0.573
# - epoch 499/500 - cost: 0.288, kl:                 0.572
# - epoch 500/500 - cost: 0.270, kl:                 0.571
# - this took 356.39 seconds
# Testing the model...
# (500, 230, 113)
# - cost: 0.153
# - this took 22.08 seconds

# %%
star_mass = torch.linspace(10.5, 11.5, 20)
dust_mass = torch.linspace(7, 7, 20)
theta = torch.linspace(45, 45, 20)
x_pred = model.create_predict_tensor(star_mass, dust_mass, theta)
print(x_pred.shape)
mean_pred_results, std_pred_results, inputs = model.predict(x_pred)
# Out:
# torch.Size([20, 3])
# torch.Size([20, 3])
# torch.Size([3, 20])

# %%
plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test, output = "f")

#plotter.plot_single(150, "grey", "salmon")
#plotter.plot_group_same(0, 40, "grey", "salmon")
plotter.plot_same_ax(1,20,5,'cool')
#plotter.save_figure("test.png")
