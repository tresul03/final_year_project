# %%
import radiative_transfer_bnn as rt

import torch

import numpy as np

import matplotlib.pyplot as plt

import plotter as pltr

import pandas as pd

# %%
# model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux')
# model.preprocess_data()
# model.train_model(250, 200)
# wavelength = model.wavelength
# mean_pred_results, std_pred_results = model.test_model()
# x_test = model.X_test
# y_test = model.y_test

# %%
# model.save_model("testmodel")
# model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux', saved_model_filename= "testmodel")

# %%
# cost_vs_epoch_df = model.cost_vs_epoch()

# %%
# plotter = pltr.Plotter(cost_vs_epoch_df['epoch'],cost_vs_epoch_df['cost'])
# plotter.cost_vs_epochs()

# %%
# star_mass = torch.linspace(3.5, 15.5, 20)
# dust_mass = torch.linspace(7, 7, 20)
# theta = torch.linspace(90, 90, 20)
# x_pred = model.create_predict_tensor(star_mass, dust_mass, theta)
# print(x_pred.shape)
# mean_pred_results, std_pred_results = model.predict(x_pred)

# %%
# plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test,"f")
# plotter.plot_same_ax(0,20,1)

#it's not changing enough for angle
# you can only notice a change by going outside the range of values
#is this to do with normalisation when training the model?
# most likely
#is it worth seeing how SKIRT changes with angle?
#maybe create a function that groups SKIRT data over a range, no we need to generate more for fixed values
#see if the sub-runs are any different, for, like, 3-4 runs; if no conclusive difference, then yeah

# %%
# np.savez('data_file.npz', wavelength=wavelength, mean_pred_results=mean_pred_results,
#         std_pred_results=std_pred_results, x_test=x_test, y_test=y_test)

# %%
# loaded_data = np.load('data_file.npz')
# wavelength = loaded_data['wavelength']
# mean_pred_results = loaded_data['mean_pred_results']
# std_pred_results = loaded_data['std_pred_results']
# x_test = loaded_data['x_test']
# y_test = loaded_data['y_test']

# %%
# print(mean_pred_results)

# %%
# plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test, output = "f")

# #plotter.plot_single(150, "grey", "salmon")
# #plotter.plot_group_same(0, 40, "grey", "salmon")
# plotter.plot_same_ax(1,200,50,'cool')
# #plotter.save_figure("test.png")

# %%
#write prdeict function on saved model
#linear interpolation of extremes
#can only predict within the range of the training data
#what about extrapolation?
#comapare for extraploation can use predict function
#what is the uncertainty of the prediction
#Produce SED

# %%
#plotter function add std deviation
#change labels
#cost_vs_epochs plot
#ask steven about datd
#generate data for fixed values

# %%
model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux')
model.preprocess_data()
model.train_model(250, 200)
wavelength = model.wavelength
mean_pred_results, std_pred_results = model.test_model()
x_test = model.X_test
y_test = model.y_test
# Out:
# c:\Users\joshu\OneDrive\Desktop\Physics_Year_3\Final_year_project\Github\project_script\src\semester2\week4\radiative_transfer_bnn.py:297: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([
# Index(['log_mstar', 'log_mdust_over_mstar', 'theta'], dtype='object')
# Training the model...
# - epoch 1/250 - cost: 10.024, kl:                 0.053
# - epoch 2/250 - cost: 6.406, kl:                 0.091
# - epoch 3/250 - cost: 4.313, kl:                 0.127
# - epoch 4/250 - cost: 3.025, kl:                 0.157
# - epoch 5/250 - cost: 1.840, kl:                 0.182
# - epoch 6/250 - cost: 1.535, kl:                 0.200
# - epoch 7/250 - cost: 0.885, kl:                 0.213
# - epoch 8/250 - cost: 0.635, kl:                 0.223
# - epoch 9/250 - cost: 0.472, kl:                 0.230
# - epoch 10/250 - cost: 0.382, kl:                 0.234
# - epoch 11/250 - cost: 0.334, kl:                 0.237
# - epoch 12/250 - cost: 0.311, kl:                 0.239
# - epoch 13/250 - cost: 0.246, kl:                 0.240
# - epoch 14/250 - cost: 0.239, kl:                 0.241
# - epoch 15/250 - cost: 0.205, kl:                 0.241
# - epoch 16/250 - cost: 0.185, kl:                 0.242
# - epoch 17/250 - cost: 0.193, kl:                 0.242
# - epoch 18/250 - cost: 0.168, kl:                 0.242
# - epoch 19/250 - cost: 0.628, kl:                 0.242
# - epoch 20/250 - cost: 0.153, kl:                 0.242
# - epoch 21/250 - cost: 0.174, kl:                 0.242
# - epoch 22/250 - cost: 0.150, kl:                 0.242
# - epoch 23/250 - cost: 0.182, kl:                 0.242
# - epoch 24/250 - cost: 0.470, kl:                 0.242
# - epoch 25/250 - cost: 0.136, kl:                 0.242
# - epoch 26/250 - cost: 0.145, kl:                 0.242
# - epoch 27/250 - cost: 0.301, kl:                 0.241
# - epoch 28/250 - cost: 0.155, kl:                 0.241
# - epoch 29/250 - cost: 0.145, kl:                 0.241
# - epoch 30/250 - cost: 0.220, kl:                 0.241
# - epoch 31/250 - cost: 0.150, kl:                 0.241
# - epoch 32/250 - cost: 0.153, kl:                 0.241
# - epoch 33/250 - cost: 0.141, kl:                 0.240
# - epoch 34/250 - cost: 0.129, kl:                 0.240
# - epoch 35/250 - cost: 0.124, kl:                 0.240
# - epoch 36/250 - cost: 0.117, kl:                 0.240
# - epoch 37/250 - cost: 0.100, kl:                 0.240
# - epoch 38/250 - cost: 0.125, kl:                 0.239
# - epoch 39/250 - cost: 0.136, kl:                 0.239
# - epoch 40/250 - cost: 0.103, kl:                 0.239
# - epoch 41/250 - cost: 0.151, kl:                 0.239
# - epoch 42/250 - cost: 0.148, kl:                 0.238
# - epoch 43/250 - cost: 0.095, kl:                 0.238
# - epoch 44/250 - cost: 0.250, kl:                 0.238
# - epoch 45/250 - cost: 0.252, kl:                 0.237
# - epoch 46/250 - cost: 0.160, kl:                 0.237
# - epoch 47/250 - cost: 0.105, kl:                 0.237
# - epoch 48/250 - cost: 0.118, kl:                 0.236
# - epoch 49/250 - cost: 0.126, kl:                 0.236
# - epoch 50/250 - cost: 0.094, kl:                 0.236
# - epoch 51/250 - cost: 0.111, kl:                 0.236
# - epoch 52/250 - cost: 0.076, kl:                 0.235
# - epoch 53/250 - cost: 0.133, kl:                 0.235
# - epoch 54/250 - cost: 0.144, kl:                 0.234
# - epoch 55/250 - cost: 0.089, kl:                 0.234
# - epoch 56/250 - cost: 0.079, kl:                 0.234
# - epoch 57/250 - cost: 0.137, kl:                 0.233
# - epoch 58/250 - cost: 0.105, kl:                 0.233
# - epoch 59/250 - cost: 0.082, kl:                 0.232
# - epoch 60/250 - cost: 0.076, kl:                 0.232
# - epoch 61/250 - cost: 0.083, kl:                 0.232
# - epoch 62/250 - cost: 0.106, kl:                 0.231
# - epoch 63/250 - cost: 0.089, kl:                 0.231
# - epoch 64/250 - cost: 0.080, kl:                 0.230
# - epoch 65/250 - cost: 0.081, kl:                 0.230
# - epoch 66/250 - cost: 0.085, kl:                 0.229
# - epoch 67/250 - cost: 0.089, kl:                 0.229
# - epoch 68/250 - cost: 0.087, kl:                 0.228
# - epoch 69/250 - cost: 0.079, kl:                 0.228
# - epoch 70/250 - cost: 0.077, kl:                 0.228
# - epoch 71/250 - cost: 0.095, kl:                 0.227
# - epoch 72/250 - cost: 0.094, kl:                 0.226
# - epoch 73/250 - cost: 0.067, kl:                 0.226
# - epoch 74/250 - cost: 0.065, kl:                 0.225
# - epoch 75/250 - cost: 0.096, kl:                 0.225
# - epoch 76/250 - cost: 0.125, kl:                 0.224
# - epoch 77/250 - cost: 0.069, kl:                 0.224
# - epoch 78/250 - cost: 0.114, kl:                 0.223
# - epoch 79/250 - cost: 0.116, kl:                 0.223
# - epoch 80/250 - cost: 0.079, kl:                 0.223
# - epoch 81/250 - cost: 0.079, kl:                 0.222
# - epoch 82/250 - cost: 0.166, kl:                 0.221
# - epoch 83/250 - cost: 0.059, kl:                 0.221
# - epoch 84/250 - cost: 0.064, kl:                 0.221
# - epoch 85/250 - cost: 0.061, kl:                 0.220
# - epoch 86/250 - cost: 0.064, kl:                 0.219
# - epoch 87/250 - cost: 0.056, kl:                 0.219
# - epoch 88/250 - cost: 0.054, kl:                 0.218
# - epoch 89/250 - cost: 0.057, kl:                 0.218
# - epoch 90/250 - cost: 0.072, kl:                 0.217
# - epoch 91/250 - cost: 0.058, kl:                 0.216
# - epoch 92/250 - cost: 0.058, kl:                 0.216
# - epoch 93/250 - cost: 0.062, kl:                 0.215
# - epoch 94/250 - cost: 0.056, kl:                 0.215
# - epoch 95/250 - cost: 0.064, kl:                 0.214
# - epoch 96/250 - cost: 0.060, kl:                 0.213
# - epoch 97/250 - cost: 0.064, kl:                 0.213
# - epoch 98/250 - cost: 0.058, kl:                 0.212
# - epoch 99/250 - cost: 0.048, kl:                 0.211
# - epoch 100/250 - cost: 0.080, kl:                 0.211
# - epoch 101/250 - cost: 0.048, kl:                 0.210
# - epoch 102/250 - cost: 0.058, kl:                 0.209
# - epoch 103/250 - cost: 0.065, kl:                 0.209
# - epoch 104/250 - cost: 0.066, kl:                 0.208
# - epoch 105/250 - cost: 0.064, kl:                 0.207
# - epoch 106/250 - cost: 0.053, kl:                 0.207
# - epoch 107/250 - cost: 0.048, kl:                 0.206
# - epoch 108/250 - cost: 0.048, kl:                 0.205
# - epoch 109/250 - cost: 0.057, kl:                 0.205
# - epoch 110/250 - cost: 0.048, kl:                 0.204
# - epoch 111/250 - cost: 0.049, kl:                 0.203
# - epoch 112/250 - cost: 0.048, kl:                 0.203
# - epoch 113/250 - cost: 0.053, kl:                 0.202
# - epoch 114/250 - cost: 0.048, kl:                 0.201
# - epoch 115/250 - cost: 0.045, kl:                 0.201
# - epoch 116/250 - cost: 0.045, kl:                 0.200
# - epoch 117/250 - cost: 0.086, kl:                 0.199
# - epoch 118/250 - cost: 0.048, kl:                 0.199
# - epoch 119/250 - cost: 0.046, kl:                 0.198
# - epoch 120/250 - cost: 0.063, kl:                 0.197
# - epoch 121/250 - cost: 0.120, kl:                 0.197
# - epoch 122/250 - cost: 0.063, kl:                 0.196
# - epoch 123/250 - cost: 0.055, kl:                 0.196
# - epoch 124/250 - cost: 0.048, kl:                 0.195
# - epoch 125/250 - cost: 0.044, kl:                 0.194
# - epoch 126/250 - cost: 0.059, kl:                 0.194
# - epoch 127/250 - cost: 0.052, kl:                 0.193
# - epoch 128/250 - cost: 0.048, kl:                 0.192
# - epoch 129/250 - cost: 0.041, kl:                 0.192
# - epoch 130/250 - cost: 0.045, kl:                 0.191
# - epoch 131/250 - cost: 0.059, kl:                 0.190
# - epoch 132/250 - cost: 0.044, kl:                 0.190
# - epoch 133/250 - cost: 0.041, kl:                 0.189
# - epoch 134/250 - cost: 0.047, kl:                 0.188
# - epoch 135/250 - cost: 0.041, kl:                 0.188
# - epoch 136/250 - cost: 0.060, kl:                 0.187
# - epoch 137/250 - cost: 0.044, kl:                 0.186
# - epoch 138/250 - cost: 0.039, kl:                 0.185
# - epoch 139/250 - cost: 0.043, kl:                 0.185
# - epoch 140/250 - cost: 0.048, kl:                 0.184
# - epoch 141/250 - cost: 0.041, kl:                 0.183
# - epoch 142/250 - cost: 0.041, kl:                 0.183
# - epoch 143/250 - cost: 0.039, kl:                 0.182
# - epoch 144/250 - cost: 0.040, kl:                 0.181
# - epoch 145/250 - cost: 0.037, kl:                 0.180
# - epoch 146/250 - cost: 0.047, kl:                 0.180
# - epoch 147/250 - cost: 0.063, kl:                 0.179
# - epoch 148/250 - cost: 0.064, kl:                 0.178
# - epoch 149/250 - cost: 0.041, kl:                 0.178
# - epoch 150/250 - cost: 0.042, kl:                 0.177
# - epoch 151/250 - cost: 0.040, kl:                 0.176
# - epoch 152/250 - cost: 0.039, kl:                 0.176
# - epoch 153/250 - cost: 0.036, kl:                 0.175
# - epoch 154/250 - cost: 0.040, kl:                 0.174
# - epoch 155/250 - cost: 0.049, kl:                 0.173
# - epoch 156/250 - cost: 0.052, kl:                 0.173
# - epoch 157/250 - cost: 0.056, kl:                 0.172
# - epoch 158/250 - cost: 0.045, kl:                 0.171
# - epoch 159/250 - cost: 0.046, kl:                 0.171
# - epoch 160/250 - cost: 0.037, kl:                 0.170
# - epoch 161/250 - cost: 0.040, kl:                 0.169
# - epoch 162/250 - cost: 0.040, kl:                 0.169
# - epoch 163/250 - cost: 0.039, kl:                 0.168
# - epoch 164/250 - cost: 0.036, kl:                 0.167
# - epoch 165/250 - cost: 0.050, kl:                 0.167
# - epoch 166/250 - cost: 0.039, kl:                 0.166
# - epoch 167/250 - cost: 0.035, kl:                 0.165
# - epoch 168/250 - cost: 0.032, kl:                 0.164
# - epoch 169/250 - cost: 0.035, kl:                 0.164
# - epoch 170/250 - cost: 0.035, kl:                 0.163
# - epoch 171/250 - cost: 0.035, kl:                 0.162
# - epoch 172/250 - cost: 0.032, kl:                 0.162
# - epoch 173/250 - cost: 0.039, kl:                 0.161
# - epoch 174/250 - cost: 0.042, kl:                 0.160
# - epoch 175/250 - cost: 0.032, kl:                 0.160
# - epoch 176/250 - cost: 0.038, kl:                 0.159
# - epoch 177/250 - cost: 0.031, kl:                 0.158
# - epoch 178/250 - cost: 0.036, kl:                 0.158
# - epoch 179/250 - cost: 0.035, kl:                 0.157
# - epoch 180/250 - cost: 0.035, kl:                 0.156
# - epoch 181/250 - cost: 0.030, kl:                 0.155
# - epoch 182/250 - cost: 0.031, kl:                 0.155
# - epoch 183/250 - cost: 0.035, kl:                 0.154
# - epoch 184/250 - cost: 0.035, kl:                 0.153
# - epoch 185/250 - cost: 0.040, kl:                 0.153
# - epoch 186/250 - cost: 0.034, kl:                 0.152
# - epoch 187/250 - cost: 0.036, kl:                 0.151
# - epoch 188/250 - cost: 0.031, kl:                 0.151
# - epoch 189/250 - cost: 0.033, kl:                 0.150
# - epoch 190/250 - cost: 0.040, kl:                 0.149
# - epoch 191/250 - cost: 0.032, kl:                 0.149
# - epoch 192/250 - cost: 0.028, kl:                 0.148
# - epoch 193/250 - cost: 0.030, kl:                 0.147
# - epoch 194/250 - cost: 0.032, kl:                 0.147
# - epoch 195/250 - cost: 0.036, kl:                 0.146
# - epoch 196/250 - cost: 0.032, kl:                 0.145
# - epoch 197/250 - cost: 0.028, kl:                 0.145
# - epoch 198/250 - cost: 0.032, kl:                 0.144
# - epoch 199/250 - cost: 0.030, kl:                 0.143
# - epoch 200/250 - cost: 0.033, kl:                 0.143
# - epoch 201/250 - cost: 0.029, kl:                 0.142
# - epoch 202/250 - cost: 0.027, kl:                 0.141
# - epoch 203/250 - cost: 0.029, kl:                 0.141
# - epoch 204/250 - cost: 0.026, kl:                 0.140
# - epoch 205/250 - cost: 0.031, kl:                 0.139
# - epoch 206/250 - cost: 0.029, kl:                 0.139
# - epoch 207/250 - cost: 0.027, kl:                 0.138
# - epoch 208/250 - cost: 0.028, kl:                 0.137
# - epoch 209/250 - cost: 0.028, kl:                 0.137
# - epoch 210/250 - cost: 0.029, kl:                 0.136
# - epoch 211/250 - cost: 0.028, kl:                 0.136
# - epoch 212/250 - cost: 0.028, kl:                 0.135
# - epoch 213/250 - cost: 0.033, kl:                 0.134
# - epoch 214/250 - cost: 0.034, kl:                 0.134
# - epoch 215/250 - cost: 0.026, kl:                 0.133
# - epoch 216/250 - cost: 0.030, kl:                 0.132
# - epoch 217/250 - cost: 0.026, kl:                 0.132
# - epoch 218/250 - cost: 0.030, kl:                 0.131
# - epoch 219/250 - cost: 0.028, kl:                 0.130
# - epoch 220/250 - cost: 0.029, kl:                 0.130
# - epoch 221/250 - cost: 0.026, kl:                 0.129
# - epoch 222/250 - cost: 0.029, kl:                 0.129
# - epoch 223/250 - cost: 0.025, kl:                 0.128
# - epoch 224/250 - cost: 0.024, kl:                 0.127
# - epoch 225/250 - cost: 0.026, kl:                 0.127
# - epoch 226/250 - cost: 0.026, kl:                 0.126
# - epoch 227/250 - cost: 0.024, kl:                 0.125
# - epoch 228/250 - cost: 0.031, kl:                 0.125
# - epoch 229/250 - cost: 0.025, kl:                 0.124
# - epoch 230/250 - cost: 0.027, kl:                 0.124
# - epoch 231/250 - cost: 0.024, kl:                 0.123
# - epoch 232/250 - cost: 0.026, kl:                 0.122
# - epoch 233/250 - cost: 0.030, kl:                 0.122
# - epoch 234/250 - cost: 0.025, kl:                 0.121
# - epoch 235/250 - cost: 0.026, kl:                 0.121
# - epoch 236/250 - cost: 0.028, kl:                 0.120
# - epoch 237/250 - cost: 0.023, kl:                 0.119
# - epoch 238/250 - cost: 0.026, kl:                 0.119
# - epoch 239/250 - cost: 0.027, kl:                 0.118
# - epoch 240/250 - cost: 0.026, kl:                 0.118
# - epoch 241/250 - cost: 0.034, kl:                 0.117
# - epoch 242/250 - cost: 0.026, kl:                 0.117
# - epoch 243/250 - cost: 0.030, kl:                 0.116
# - epoch 244/250 - cost: 0.032, kl:                 0.116
# - epoch 245/250 - cost: 0.023, kl:                 0.115
# - epoch 246/250 - cost: 0.026, kl:                 0.114
# - epoch 247/250 - cost: 0.026, kl:                 0.114
# - epoch 248/250 - cost: 0.027, kl:                 0.113
# - epoch 249/250 - cost: 0.028, kl:                 0.113
# - epoch 250/250 - cost: 0.022, kl:                 0.112
# - this took 191.13 seconds
# Testing the model...
# (500, 230, 113)
# - cost: 0.018
# - this took 24.17 seconds

# %%
star_mass = torch.linspace(10.5, 11.5, 20)
dust_mass = torch.linspace(7, 7, 20)
theta = torch.linspace(45, 45, 20)
x_pred = model.create_predict_tensor(star_mass, dust_mass, theta)
print(x_pred.shape)
mean_pred_results, std_pred_results = model.predict(x_pred)
# Out:
# torch.Size([20, 3])
# torch.Size([20, 3])
# torch.Size([3, 20])

# %%
plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test, output = "f")

#plotter.plot_single(150, "grey", "salmon")
#plotter.plot_group_same(0, 40, "grey", "salmon")
plotter.plot_same_ax(1,20,1,'cool')
#plotter.save_figure("test.png")
