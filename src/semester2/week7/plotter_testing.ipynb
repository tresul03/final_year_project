# %%
import radiative_transfer_bnn as rt

import torch

import numpy as np

import matplotlib.pyplot as plt

import plotter as pltr

import pandas as pd

# %%
# model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux')
# model.preprocess_data()
# model.train_model(250, 200)
# wavelength = model.wavelength
# mean_pred_results, std_pred_results = model.test_model()
# x_test = model.X_test
# y_test = model.y_test
# Out:
# c:\Users\joshu\OneDrive\Desktop\Physics_Year_3\Final_year_project\Github\project_script\src\semester2\week7\radiative_transfer_bnn.py:299: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([
# Training the model...
# - epoch 1/250 - cost: 7.691, kl:                 0.077
# - epoch 2/250 - cost: 2.815, kl:                 0.136
# - epoch 3/250 - cost: 1.723, kl:                 0.180
# - epoch 4/250 - cost: 1.013, kl:                 0.207
# - epoch 5/250 - cost: 0.722, kl:                 0.223
# - epoch 6/250 - cost: 0.687, kl:                 0.231
# - epoch 7/250 - cost: 0.458, kl:                 0.236
# - epoch 8/250 - cost: 0.472, kl:                 0.238
# - epoch 9/250 - cost: 0.443, kl:                 0.239
# - epoch 10/250 - cost: 0.437, kl:                 0.239
# - epoch 11/250 - cost: 0.416, kl:                 0.240
# - epoch 12/250 - cost: 0.400, kl:                 0.240
# - epoch 13/250 - cost: 0.540, kl:                 0.240
# - epoch 14/250 - cost: 0.371, kl:                 0.240
# - epoch 15/250 - cost: 0.463, kl:                 0.240
# - epoch 16/250 - cost: 0.482, kl:                 0.240
# - epoch 17/250 - cost: 0.398, kl:                 0.240
# - epoch 18/250 - cost: 0.484, kl:                 0.241
# - epoch 19/250 - cost: 0.416, kl:                 0.241
# - epoch 20/250 - cost: 0.400, kl:                 0.241
# - epoch 21/250 - cost: 0.410, kl:                 0.241
# - epoch 22/250 - cost: 0.472, kl:                 0.241
# - epoch 23/250 - cost: 0.379, kl:                 0.241
# - epoch 24/250 - cost: 0.396, kl:                 0.241
# - epoch 25/250 - cost: 0.354, kl:                 0.241
# - epoch 26/250 - cost: 0.403, kl:                 0.242
# - epoch 27/250 - cost: 0.411, kl:                 0.242
# - epoch 28/250 - cost: 0.414, kl:                 0.242
# - epoch 29/250 - cost: 0.367, kl:                 0.242
# - epoch 30/250 - cost: 0.366, kl:                 0.242
# - epoch 31/250 - cost: 0.303, kl:                 0.242
# - epoch 32/250 - cost: 0.352, kl:                 0.242
# - epoch 33/250 - cost: 0.344, kl:                 0.243
# - epoch 34/250 - cost: 0.358, kl:                 0.243
# - epoch 35/250 - cost: 0.413, kl:                 0.243
# - epoch 36/250 - cost: 0.379, kl:                 0.243
# - epoch 37/250 - cost: 0.332, kl:                 0.243
# - epoch 38/250 - cost: 0.367, kl:                 0.244
# - epoch 39/250 - cost: 0.357, kl:                 0.244
# - epoch 40/250 - cost: 0.357, kl:                 0.244
# - epoch 41/250 - cost: 0.342, kl:                 0.245
# - epoch 42/250 - cost: 0.353, kl:                 0.245
# - epoch 43/250 - cost: 0.313, kl:                 0.245
# - epoch 44/250 - cost: 0.389, kl:                 0.245
# - epoch 45/250 - cost: 0.304, kl:                 0.246
# - epoch 46/250 - cost: 0.310, kl:                 0.246
# - epoch 47/250 - cost: 0.337, kl:                 0.246
# - epoch 48/250 - cost: 0.362, kl:                 0.246
# - epoch 49/250 - cost: 0.295, kl:                 0.246
# - epoch 50/250 - cost: 0.311, kl:                 0.246
# - epoch 51/250 - cost: 0.354, kl:                 0.246
# - epoch 52/250 - cost: 0.423, kl:                 0.246
# - epoch 53/250 - cost: 0.372, kl:                 0.246
# - epoch 54/250 - cost: 0.323, kl:                 0.246
# - epoch 55/250 - cost: 0.290, kl:                 0.246
# - epoch 56/250 - cost: 0.264, kl:                 0.246
# - epoch 57/250 - cost: 0.325, kl:                 0.246
# - epoch 58/250 - cost: 0.219, kl:                 0.247
# - epoch 59/250 - cost: 0.411, kl:                 0.247
# - epoch 60/250 - cost: 0.296, kl:                 0.247
# - epoch 61/250 - cost: 0.278, kl:                 0.247
# - epoch 62/250 - cost: 0.385, kl:                 0.247
# - epoch 63/250 - cost: 0.305, kl:                 0.247
# - epoch 64/250 - cost: 0.283, kl:                 0.247
# - epoch 65/250 - cost: 0.351, kl:                 0.248
# - epoch 66/250 - cost: 0.297, kl:                 0.248
# - epoch 67/250 - cost: 0.300, kl:                 0.248
# - epoch 68/250 - cost: 0.284, kl:                 0.248
# - epoch 69/250 - cost: 0.322, kl:                 0.249
# - epoch 70/250 - cost: 0.344, kl:                 0.249
# - epoch 71/250 - cost: 0.345, kl:                 0.249
# - epoch 72/250 - cost: 0.259, kl:                 0.249
# - epoch 73/250 - cost: 0.315, kl:                 0.249
# - epoch 74/250 - cost: 0.307, kl:                 0.249
# - epoch 75/250 - cost: 0.277, kl:                 0.249
# - epoch 76/250 - cost: 0.265, kl:                 0.249
# - epoch 77/250 - cost: 0.390, kl:                 0.249
# - epoch 78/250 - cost: 0.292, kl:                 0.250
# - epoch 79/250 - cost: 0.334, kl:                 0.250
# - epoch 80/250 - cost: 0.311, kl:                 0.250
# - epoch 81/250 - cost: 0.261, kl:                 0.250
# - epoch 82/250 - cost: 0.240, kl:                 0.250
# - epoch 83/250 - cost: 0.321, kl:                 0.250
# - epoch 84/250 - cost: 0.278, kl:                 0.250
# - epoch 85/250 - cost: 0.319, kl:                 0.250
# - epoch 86/250 - cost: 0.389, kl:                 0.251
# - epoch 87/250 - cost: 0.267, kl:                 0.251
# - epoch 88/250 - cost: 0.297, kl:                 0.251
# - epoch 89/250 - cost: 0.280, kl:                 0.251
# - epoch 90/250 - cost: 0.263, kl:                 0.252
# - epoch 91/250 - cost: 0.339, kl:                 0.252
# - epoch 92/250 - cost: 0.243, kl:                 0.252
# - epoch 93/250 - cost: 0.344, kl:                 0.252
# - epoch 94/250 - cost: 0.312, kl:                 0.252
# - epoch 95/250 - cost: 0.374, kl:                 0.252
# - epoch 96/250 - cost: 0.333, kl:                 0.253
# - epoch 97/250 - cost: 0.294, kl:                 0.253
# - epoch 98/250 - cost: 0.265, kl:                 0.253
# - epoch 99/250 - cost: 0.266, kl:                 0.253
# - epoch 100/250 - cost: 0.270, kl:                 0.253
# - epoch 101/250 - cost: 0.297, kl:                 0.253
# - epoch 102/250 - cost: 0.264, kl:                 0.253
# - epoch 103/250 - cost: 0.330, kl:                 0.253
# - epoch 104/250 - cost: 0.308, kl:                 0.254
# - epoch 105/250 - cost: 0.259, kl:                 0.254
# - epoch 106/250 - cost: 0.239, kl:                 0.254
# - epoch 107/250 - cost: 0.278, kl:                 0.254
# - epoch 108/250 - cost: 0.246, kl:                 0.254
# - epoch 109/250 - cost: 0.343, kl:                 0.254
# - epoch 110/250 - cost: 0.323, kl:                 0.254
# - epoch 111/250 - cost: 0.278, kl:                 0.254
# - epoch 112/250 - cost: 0.272, kl:                 0.254
# - epoch 113/250 - cost: 0.333, kl:                 0.254
# - epoch 114/250 - cost: 0.356, kl:                 0.254
# - epoch 115/250 - cost: 0.272, kl:                 0.254
# - epoch 116/250 - cost: 0.261, kl:                 0.254
# - epoch 117/250 - cost: 0.250, kl:                 0.254
# - epoch 118/250 - cost: 0.212, kl:                 0.254
# - epoch 119/250 - cost: 0.296, kl:                 0.254
# - epoch 120/250 - cost: 0.285, kl:                 0.254
# - epoch 121/250 - cost: 0.369, kl:                 0.254
# - epoch 122/250 - cost: 0.386, kl:                 0.254
# - epoch 123/250 - cost: 0.292, kl:                 0.255
# - epoch 124/250 - cost: 0.287, kl:                 0.256
# - epoch 125/250 - cost: 0.372, kl:                 0.256
# - epoch 126/250 - cost: 0.317, kl:                 0.256
# - epoch 127/250 - cost: 0.354, kl:                 0.256
# - epoch 128/250 - cost: 0.224, kl:                 0.256
# - epoch 129/250 - cost: 0.391, kl:                 0.257
# - epoch 130/250 - cost: 0.301, kl:                 0.257
# - epoch 131/250 - cost: 0.312, kl:                 0.258
# - epoch 132/250 - cost: 0.277, kl:                 0.258
# - epoch 133/250 - cost: 0.275, kl:                 0.258
# - epoch 134/250 - cost: 0.252, kl:                 0.258
# - epoch 135/250 - cost: 0.297, kl:                 0.258
# - epoch 136/250 - cost: 0.303, kl:                 0.258
# - epoch 137/250 - cost: 0.260, kl:                 0.258
# - epoch 138/250 - cost: 0.358, kl:                 0.258
# - epoch 139/250 - cost: 0.277, kl:                 0.258
# - epoch 140/250 - cost: 0.306, kl:                 0.259
# - epoch 141/250 - cost: 0.168, kl:                 0.259
# - epoch 142/250 - cost: 0.286, kl:                 0.259
# - epoch 143/250 - cost: 0.296, kl:                 0.259
# - epoch 144/250 - cost: 0.285, kl:                 0.259
# - epoch 145/250 - cost: 0.315, kl:                 0.259
# - epoch 146/250 - cost: 0.278, kl:                 0.259
# - epoch 147/250 - cost: 0.209, kl:                 0.259
# - epoch 148/250 - cost: 0.209, kl:                 0.258
# - epoch 149/250 - cost: 0.332, kl:                 0.258
# - epoch 150/250 - cost: 0.303, kl:                 0.258
# - epoch 151/250 - cost: 0.282, kl:                 0.258
# - epoch 152/250 - cost: 0.301, kl:                 0.258
# - epoch 153/250 - cost: 0.185, kl:                 0.259
# - epoch 154/250 - cost: 0.300, kl:                 0.259
# - epoch 155/250 - cost: 0.284, kl:                 0.259
# - epoch 156/250 - cost: 0.266, kl:                 0.260
# - epoch 157/250 - cost: 0.303, kl:                 0.260
# - epoch 158/250 - cost: 0.317, kl:                 0.260
# - epoch 159/250 - cost: 0.238, kl:                 0.260
# - epoch 160/250 - cost: 0.262, kl:                 0.260
# - epoch 161/250 - cost: 0.257, kl:                 0.260
# - epoch 162/250 - cost: 0.314, kl:                 0.260
# - epoch 163/250 - cost: 0.293, kl:                 0.261
# - epoch 164/250 - cost: 0.292, kl:                 0.261
# - epoch 165/250 - cost: 0.274, kl:                 0.261
# - epoch 166/250 - cost: 0.253, kl:                 0.261
# - epoch 167/250 - cost: 0.243, kl:                 0.261
# - epoch 168/250 - cost: 0.264, kl:                 0.261
# - epoch 169/250 - cost: 0.261, kl:                 0.261
# - epoch 170/250 - cost: 0.257, kl:                 0.262
# - epoch 171/250 - cost: 0.282, kl:                 0.263
# - epoch 172/250 - cost: 0.298, kl:                 0.264
# - epoch 173/250 - cost: 0.245, kl:                 0.264
# - epoch 174/250 - cost: 0.306, kl:                 0.265
# - epoch 175/250 - cost: 0.234, kl:                 0.266
# - epoch 176/250 - cost: 0.202, kl:                 0.266
# - epoch 177/250 - cost: 0.253, kl:                 0.266
# - epoch 178/250 - cost: 0.275, kl:                 0.267
# - epoch 179/250 - cost: 0.281, kl:                 0.267
# - epoch 180/250 - cost: 0.420, kl:                 0.267
# - epoch 181/250 - cost: 0.357, kl:                 0.268
# - epoch 182/250 - cost: 0.311, kl:                 0.270
# - epoch 183/250 - cost: 0.241, kl:                 0.271
# - epoch 184/250 - cost: 0.285, kl:                 0.272
# - epoch 185/250 - cost: 0.274, kl:                 0.272
# - epoch 186/250 - cost: 0.325, kl:                 0.272
# - epoch 187/250 - cost: 0.292, kl:                 0.273
# - epoch 188/250 - cost: 0.327, kl:                 0.273
# - epoch 189/250 - cost: 0.198, kl:                 0.273
# - epoch 190/250 - cost: 0.268, kl:                 0.273
# - epoch 191/250 - cost: 0.259, kl:                 0.272
# - epoch 192/250 - cost: 0.222, kl:                 0.272
# - epoch 193/250 - cost: 0.272, kl:                 0.272
# - epoch 194/250 - cost: 0.295, kl:                 0.273
# - epoch 195/250 - cost: 0.316, kl:                 0.274
# - epoch 196/250 - cost: 0.345, kl:                 0.274
# - epoch 197/250 - cost: 0.273, kl:                 0.275
# - epoch 198/250 - cost: 0.319, kl:                 0.276
# - epoch 199/250 - cost: 0.301, kl:                 0.278
# - epoch 200/250 - cost: 0.189, kl:                 0.279
# - epoch 201/250 - cost: 0.305, kl:                 0.280
# - epoch 202/250 - cost: 0.267, kl:                 0.281
# - epoch 203/250 - cost: 0.248, kl:                 0.282
# - epoch 204/250 - cost: 0.248, kl:                 0.282
# - epoch 205/250 - cost: 0.239, kl:                 0.284
# - epoch 206/250 - cost: 0.237, kl:                 0.284
# - epoch 207/250 - cost: 0.245, kl:                 0.285
# - epoch 208/250 - cost: 0.197, kl:                 0.286
# - epoch 209/250 - cost: 0.273, kl:                 0.286
# - epoch 210/250 - cost: 0.280, kl:                 0.287
# - epoch 211/250 - cost: 0.244, kl:                 0.289
# - epoch 212/250 - cost: 0.241, kl:                 0.290
# - epoch 213/250 - cost: 0.241, kl:                 0.290
# - epoch 214/250 - cost: 0.226, kl:                 0.290
# - epoch 215/250 - cost: 0.205, kl:                 0.290
# - epoch 216/250 - cost: 0.250, kl:                 0.290
# - epoch 217/250 - cost: 0.344, kl:                 0.289
# - epoch 218/250 - cost: 0.339, kl:                 0.289
# - epoch 219/250 - cost: 0.226, kl:                 0.290
# - epoch 220/250 - cost: 0.241, kl:                 0.291
# - epoch 221/250 - cost: 0.248, kl:                 0.292
# - epoch 222/250 - cost: 0.386, kl:                 0.293
# - epoch 223/250 - cost: 0.288, kl:                 0.294
# - epoch 224/250 - cost: 0.384, kl:                 0.296
# - epoch 225/250 - cost: 0.311, kl:                 0.297
# - epoch 226/250 - cost: 0.353, kl:                 0.298
# - epoch 227/250 - cost: 0.264, kl:                 0.299
# - epoch 228/250 - cost: 0.281, kl:                 0.300
# - epoch 229/250 - cost: 0.331, kl:                 0.301
# - epoch 230/250 - cost: 0.310, kl:                 0.302
# - epoch 231/250 - cost: 0.342, kl:                 0.303
# - epoch 232/250 - cost: 0.297, kl:                 0.304
# - epoch 233/250 - cost: 0.184, kl:                 0.305
# - epoch 234/250 - cost: 0.319, kl:                 0.305
# - epoch 235/250 - cost: 0.180, kl:                 0.305
# - epoch 236/250 - cost: 0.254, kl:                 0.305
# - epoch 237/250 - cost: 0.206, kl:                 0.305
# - epoch 238/250 - cost: 0.260, kl:                 0.305
# - epoch 239/250 - cost: 0.241, kl:                 0.305
# - epoch 240/250 - cost: 0.272, kl:                 0.305
# - epoch 241/250 - cost: 0.274, kl:                 0.307
# - epoch 242/250 - cost: 0.266, kl:                 0.308
# - epoch 243/250 - cost: 0.238, kl:                 0.310
# - epoch 244/250 - cost: 0.252, kl:                 0.311
# - epoch 245/250 - cost: 0.233, kl:                 0.312
# - epoch 246/250 - cost: 0.251, kl:                 0.312
# - epoch 247/250 - cost: 0.331, kl:                 0.312
# - epoch 248/250 - cost: 0.270, kl:                 0.313
# - epoch 249/250 - cost: 0.206, kl:                 0.313
# - epoch 250/250 - cost: 0.237, kl:                 0.313
# - this took 288.75 seconds
# Testing the model...
# - cost: 0.247
# - this took 23.08 seconds

# %%
# model.save_model("testmodel")
# model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux', saved_model_filename= "testmodel")

# %%
# cost_vs_epoch_df = model.cost_vs_epoch()

# %%
# plotter = pltr.Plotter(cost_vs_epoch_df['epoch'],cost_vs_epoch_df['cost'])
# plotter.cost_vs_epochs()

# %%
# star_mass = torch.linspace(3.5, 15.5, 20)
# dust_mass = torch.linspace(7, 7, 20)
# theta = torch.linspace(90, 90, 20)
# x_pred = model.create_predict_tensor(star_mass, dust_mass, theta)
# print(x_pred.shape)
# mean_pred_results, std_pred_results = model.predict(x_pred)

# %%
# plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test,"f")
# plotter.plot_same_ax(0,20,1)

#it's not changing enough for angle
# you can only notice a change by going outside the range of values
#is this to do with normalisation when training the model?
# most likely
#is it worth seeing how SKIRT changes with angle?
#maybe create a function that groups SKIRT data over a range, no we need to generate more for fixed values
#see if the sub-runs are any different, for, like, 3-4 runs; if no conclusive difference, then yeah

# %%
# np.savez('data_file.npz', wavelength=wavelength, mean_pred_results=mean_pred_results,
#         std_pred_results=std_pred_results, x_test=x_test, y_test=y_test)

# %%
# loaded_data = np.load('data_file.npz')
# wavelength = loaded_data['wavelength']
# mean_pred_results = loaded_data['mean_pred_results']
# std_pred_results = loaded_data['std_pred_results']
# x_test = loaded_data['x_test']
# y_test = loaded_data['y_test']

# %%
# print(mean_pred_results)

# %%
# plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test, output = "f")

# #plotter.plot_single(150, "grey", "salmon")
# #plotter.plot_group_same(0, 40, "grey", "salmon")
# plotter.plot_same_ax(1,200,50,'cool')
# #plotter.save_figure("test.png")

# %%
#write prdeict function on saved model
#linear interpolation of extremes
#can only predict within the range of the training data
#what about extrapolation?
#comapare for extraploation can use predict function
#what is the uncertainty of the prediction
#Produce SED

# %%
#plotter function add std deviation
#change labels
#cost_vs_epochs plot
#ask steven about datd
#generate data for fixed values

# %%
model = rt.RadiativeTransferBNN(1000, 0.3, 0.01, 'flux')
model.preprocess_data()
model.train_model(250, 200)
wavelength = model.wavelength
mean_pred_results, std_pred_results = model.test_model()
x_test = model.X_test
y_test = model.y_test
# Out:
# c:\Users\joshu\OneDrive\Desktop\Physics_Year_3\Final_year_project\Github\project_script\src\semester2\week7\radiative_transfer_bnn.py:299: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([
# Training the model...
# - epoch 1/250 - cost: 6.288, kl:                 0.077
# - epoch 2/250 - cost: 2.889, kl:                 0.138
# - epoch 3/250 - cost: 1.312, kl:                 0.182
# - epoch 4/250 - cost: 0.967, kl:                 0.208
# - epoch 5/250 - cost: 0.675, kl:                 0.223
# - epoch 6/250 - cost: 0.588, kl:                 0.231
# - epoch 7/250 - cost: 0.475, kl:                 0.235
# - epoch 8/250 - cost: 0.531, kl:                 0.237
# - epoch 9/250 - cost: 0.499, kl:                 0.238
# - epoch 10/250 - cost: 0.447, kl:                 0.238
# - epoch 11/250 - cost: 0.424, kl:                 0.239
# - epoch 12/250 - cost: 0.476, kl:                 0.239
# - epoch 13/250 - cost: 0.495, kl:                 0.239
# - epoch 14/250 - cost: 0.356, kl:                 0.239
# - epoch 15/250 - cost: 0.634, kl:                 0.239
# - epoch 16/250 - cost: 0.397, kl:                 0.239
# - epoch 17/250 - cost: 0.469, kl:                 0.239
# - epoch 18/250 - cost: 0.327, kl:                 0.239
# - epoch 19/250 - cost: 0.415, kl:                 0.239
# - epoch 20/250 - cost: 0.553, kl:                 0.239
# - epoch 21/250 - cost: 0.379, kl:                 0.239
# - epoch 22/250 - cost: 0.377, kl:                 0.239
# - epoch 23/250 - cost: 0.417, kl:                 0.239
# - epoch 24/250 - cost: 0.342, kl:                 0.239
# - epoch 25/250 - cost: 0.363, kl:                 0.240
# - epoch 26/250 - cost: 0.439, kl:                 0.240
# - epoch 27/250 - cost: 0.451, kl:                 0.240
# - epoch 28/250 - cost: 0.366, kl:                 0.240
# - epoch 29/250 - cost: 0.465, kl:                 0.240
# - epoch 30/250 - cost: 0.341, kl:                 0.240
# - epoch 31/250 - cost: 0.404, kl:                 0.240
# - epoch 32/250 - cost: 0.360, kl:                 0.240
# - epoch 33/250 - cost: 0.351, kl:                 0.240
# - epoch 34/250 - cost: 0.355, kl:                 0.240
# - epoch 35/250 - cost: 0.436, kl:                 0.240
# - epoch 36/250 - cost: 0.385, kl:                 0.241
# - epoch 37/250 - cost: 0.295, kl:                 0.241
# - epoch 38/250 - cost: 0.289, kl:                 0.241
# - epoch 39/250 - cost: 0.327, kl:                 0.241
# - epoch 40/250 - cost: 0.389, kl:                 0.241
# - epoch 41/250 - cost: 0.346, kl:                 0.241
# - epoch 42/250 - cost: 0.241, kl:                 0.241
# - epoch 43/250 - cost: 0.303, kl:                 0.241
# - epoch 44/250 - cost: 0.226, kl:                 0.241
# - epoch 45/250 - cost: 0.469, kl:                 0.241
# - epoch 46/250 - cost: 0.340, kl:                 0.241
# - epoch 47/250 - cost: 0.271, kl:                 0.241
# - epoch 48/250 - cost: 0.309, kl:                 0.241
# - epoch 49/250 - cost: 0.339, kl:                 0.242
# - epoch 50/250 - cost: 0.416, kl:                 0.242
# - epoch 51/250 - cost: 0.286, kl:                 0.242
# - epoch 52/250 - cost: 0.243, kl:                 0.242
# - epoch 53/250 - cost: 0.336, kl:                 0.242
# - epoch 54/250 - cost: 0.383, kl:                 0.242
# - epoch 55/250 - cost: 0.298, kl:                 0.242
# - epoch 56/250 - cost: 0.292, kl:                 0.242
# - epoch 57/250 - cost: 0.297, kl:                 0.242
# - epoch 58/250 - cost: 0.306, kl:                 0.242
# - epoch 59/250 - cost: 0.315, kl:                 0.242
# - epoch 60/250 - cost: 0.353, kl:                 0.242
# - epoch 61/250 - cost: 0.300, kl:                 0.242
# - epoch 62/250 - cost: 0.280, kl:                 0.242
# - epoch 63/250 - cost: 0.343, kl:                 0.242
# - epoch 64/250 - cost: 0.297, kl:                 0.243
# - epoch 65/250 - cost: 0.342, kl:                 0.243
# - epoch 66/250 - cost: 0.401, kl:                 0.244
# - epoch 67/250 - cost: 0.290, kl:                 0.244
# - epoch 68/250 - cost: 0.369, kl:                 0.244
# - epoch 69/250 - cost: 0.314, kl:                 0.244
# - epoch 70/250 - cost: 0.386, kl:                 0.244
# - epoch 71/250 - cost: 0.353, kl:                 0.245
# - epoch 72/250 - cost: 0.253, kl:                 0.245
# - epoch 73/250 - cost: 0.345, kl:                 0.245
# - epoch 74/250 - cost: 0.327, kl:                 0.246
# - epoch 75/250 - cost: 0.293, kl:                 0.246
# - epoch 76/250 - cost: 0.279, kl:                 0.245
# - epoch 77/250 - cost: 0.323, kl:                 0.245
# - epoch 78/250 - cost: 0.348, kl:                 0.245
# - epoch 79/250 - cost: 0.285, kl:                 0.245
# - epoch 80/250 - cost: 0.255, kl:                 0.245
# - epoch 81/250 - cost: 0.338, kl:                 0.245
# - epoch 82/250 - cost: 0.356, kl:                 0.245
# - epoch 83/250 - cost: 0.418, kl:                 0.245
# - epoch 84/250 - cost: 0.280, kl:                 0.246
# - epoch 85/250 - cost: 0.367, kl:                 0.246
# - epoch 86/250 - cost: 0.264, kl:                 0.246
# - epoch 87/250 - cost: 0.360, kl:                 0.246
# - epoch 88/250 - cost: 0.360, kl:                 0.246
# - epoch 89/250 - cost: 0.305, kl:                 0.246
# - epoch 90/250 - cost: 0.222, kl:                 0.246
# - epoch 91/250 - cost: 0.272, kl:                 0.246
# - epoch 92/250 - cost: 0.306, kl:                 0.246
# - epoch 93/250 - cost: 0.294, kl:                 0.246
# - epoch 94/250 - cost: 0.281, kl:                 0.246
# - epoch 95/250 - cost: 0.370, kl:                 0.246
# - epoch 96/250 - cost: 0.226, kl:                 0.246
# - epoch 97/250 - cost: 0.281, kl:                 0.247
# - epoch 98/250 - cost: 0.249, kl:                 0.247
# - epoch 99/250 - cost: 0.289, kl:                 0.247
# - epoch 100/250 - cost: 0.431, kl:                 0.247
# - epoch 101/250 - cost: 0.303, kl:                 0.247
# - epoch 102/250 - cost: 0.318, kl:                 0.248
# - epoch 103/250 - cost: 0.263, kl:                 0.248
# - epoch 104/250 - cost: 0.260, kl:                 0.248
# - epoch 105/250 - cost: 0.279, kl:                 0.247
# - epoch 106/250 - cost: 0.391, kl:                 0.248
# - epoch 107/250 - cost: 0.241, kl:                 0.248
# - epoch 108/250 - cost: 0.274, kl:                 0.248
# - epoch 109/250 - cost: 0.306, kl:                 0.247
# - epoch 110/250 - cost: 0.259, kl:                 0.247
# - epoch 111/250 - cost: 0.306, kl:                 0.248
# - epoch 112/250 - cost: 0.282, kl:                 0.249
# - epoch 113/250 - cost: 0.264, kl:                 0.250
# - epoch 114/250 - cost: 0.288, kl:                 0.251
# - epoch 115/250 - cost: 0.301, kl:                 0.251
# - epoch 116/250 - cost: 0.314, kl:                 0.251
# - epoch 117/250 - cost: 0.315, kl:                 0.252
# - epoch 118/250 - cost: 0.259, kl:                 0.252
# - epoch 119/250 - cost: 0.221, kl:                 0.252
# - epoch 120/250 - cost: 0.266, kl:                 0.252
# - epoch 121/250 - cost: 0.368, kl:                 0.251
# - epoch 122/250 - cost: 0.322, kl:                 0.251
# - epoch 123/250 - cost: 0.266, kl:                 0.251
# - epoch 124/250 - cost: 0.259, kl:                 0.250
# - epoch 125/250 - cost: 0.403, kl:                 0.250
# - epoch 126/250 - cost: 0.244, kl:                 0.250
# - epoch 127/250 - cost: 0.382, kl:                 0.250
# - epoch 128/250 - cost: 0.284, kl:                 0.251
# - epoch 129/250 - cost: 0.220, kl:                 0.251
# - epoch 130/250 - cost: 0.264, kl:                 0.251
# - epoch 131/250 - cost: 0.318, kl:                 0.251
# - epoch 132/250 - cost: 0.269, kl:                 0.251
# - epoch 133/250 - cost: 0.318, kl:                 0.250
# - epoch 134/250 - cost: 0.234, kl:                 0.250
# - epoch 135/250 - cost: 0.285, kl:                 0.250
# - epoch 136/250 - cost: 0.289, kl:                 0.250
# - epoch 137/250 - cost: 0.279, kl:                 0.249
# - epoch 138/250 - cost: 0.264, kl:                 0.249
# - epoch 139/250 - cost: 0.443, kl:                 0.249
# - epoch 140/250 - cost: 0.255, kl:                 0.249
# - epoch 141/250 - cost: 0.317, kl:                 0.249
# - epoch 142/250 - cost: 0.270, kl:                 0.250
# - epoch 143/250 - cost: 0.313, kl:                 0.251
# - epoch 144/250 - cost: 0.314, kl:                 0.252
# - epoch 145/250 - cost: 0.238, kl:                 0.252
# - epoch 146/250 - cost: 0.295, kl:                 0.252
# - epoch 147/250 - cost: 0.269, kl:                 0.252
# - epoch 148/250 - cost: 0.288, kl:                 0.252
# - epoch 149/250 - cost: 0.310, kl:                 0.252
# - epoch 150/250 - cost: 0.253, kl:                 0.252
# - epoch 151/250 - cost: 0.270, kl:                 0.252
# - epoch 152/250 - cost: 0.236, kl:                 0.252
# - epoch 153/250 - cost: 0.245, kl:                 0.253
# - epoch 154/250 - cost: 0.257, kl:                 0.253
# - epoch 155/250 - cost: 0.287, kl:                 0.253
# - epoch 156/250 - cost: 0.293, kl:                 0.253
# - epoch 157/250 - cost: 0.309, kl:                 0.253
# - epoch 158/250 - cost: 0.339, kl:                 0.252
# - epoch 159/250 - cost: 0.288, kl:                 0.252
# - epoch 160/250 - cost: 0.307, kl:                 0.252
# - epoch 161/250 - cost: 0.400, kl:                 0.253
# - epoch 162/250 - cost: 0.309, kl:                 0.254
# - epoch 163/250 - cost: 0.344, kl:                 0.255
# - epoch 164/250 - cost: 0.318, kl:                 0.256
# - epoch 165/250 - cost: 0.287, kl:                 0.256
# - epoch 166/250 - cost: 0.333, kl:                 0.256
# - epoch 167/250 - cost: 0.295, kl:                 0.257
# - epoch 168/250 - cost: 0.329, kl:                 0.258
# - epoch 169/250 - cost: 0.323, kl:                 0.258
# - epoch 170/250 - cost: 0.236, kl:                 0.259
# - epoch 171/250 - cost: 0.246, kl:                 0.259
# - epoch 172/250 - cost: 0.345, kl:                 0.259
# - epoch 173/250 - cost: 0.232, kl:                 0.259
# - epoch 174/250 - cost: 0.351, kl:                 0.259
# - epoch 175/250 - cost: 0.338, kl:                 0.259
# - epoch 176/250 - cost: 0.295, kl:                 0.259
# - epoch 177/250 - cost: 0.292, kl:                 0.259
# - epoch 178/250 - cost: 0.304, kl:                 0.259
# - epoch 179/250 - cost: 0.361, kl:                 0.259
# - epoch 180/250 - cost: 0.270, kl:                 0.260
# - epoch 181/250 - cost: 0.255, kl:                 0.262
# - epoch 182/250 - cost: 0.323, kl:                 0.263
# - epoch 183/250 - cost: 0.282, kl:                 0.265
# - epoch 184/250 - cost: 0.188, kl:                 0.266
# - epoch 185/250 - cost: 0.232, kl:                 0.266
# - epoch 186/250 - cost: 0.250, kl:                 0.267
# - epoch 187/250 - cost: 0.250, kl:                 0.267
# - epoch 188/250 - cost: 0.360, kl:                 0.267
# - epoch 189/250 - cost: 0.299, kl:                 0.268
# - epoch 190/250 - cost: 0.329, kl:                 0.268
# - epoch 191/250 - cost: 0.280, kl:                 0.269
# - epoch 192/250 - cost: 0.207, kl:                 0.269
# - epoch 193/250 - cost: 0.361, kl:                 0.270
# - epoch 194/250 - cost: 0.195, kl:                 0.270
# - epoch 195/250 - cost: 0.250, kl:                 0.270
# - epoch 196/250 - cost: 0.285, kl:                 0.270
# - epoch 197/250 - cost: 0.353, kl:                 0.270
# - epoch 198/250 - cost: 0.238, kl:                 0.271
# - epoch 199/250 - cost: 0.484, kl:                 0.271
# - epoch 200/250 - cost: 0.300, kl:                 0.272
# - epoch 201/250 - cost: 0.331, kl:                 0.273
# - epoch 202/250 - cost: 0.300, kl:                 0.273
# - epoch 203/250 - cost: 0.246, kl:                 0.273
# - epoch 204/250 - cost: 0.226, kl:                 0.272
# - epoch 205/250 - cost: 0.299, kl:                 0.272
# - epoch 206/250 - cost: 0.274, kl:                 0.272
# - epoch 207/250 - cost: 0.222, kl:                 0.273
# - epoch 208/250 - cost: 0.277, kl:                 0.273
# - epoch 209/250 - cost: 0.186, kl:                 0.274
# - epoch 210/250 - cost: 0.277, kl:                 0.275
# - epoch 211/250 - cost: 0.347, kl:                 0.276
# - epoch 212/250 - cost: 0.298, kl:                 0.278
# - epoch 213/250 - cost: 0.317, kl:                 0.280
# - epoch 214/250 - cost: 0.264, kl:                 0.283
# - epoch 215/250 - cost: 0.246, kl:                 0.285
# - epoch 216/250 - cost: 0.258, kl:                 0.286
# - epoch 217/250 - cost: 0.288, kl:                 0.287
# - epoch 218/250 - cost: 0.259, kl:                 0.287
# - epoch 219/250 - cost: 0.366, kl:                 0.288
# - epoch 220/250 - cost: 0.305, kl:                 0.289
# - epoch 221/250 - cost: 0.243, kl:                 0.290
# - epoch 222/250 - cost: 0.351, kl:                 0.291
# - epoch 223/250 - cost: 0.424, kl:                 0.292
# - epoch 224/250 - cost: 0.239, kl:                 0.292
# - epoch 225/250 - cost: 0.321, kl:                 0.292
# - epoch 226/250 - cost: 0.274, kl:                 0.292
# - epoch 227/250 - cost: 0.272, kl:                 0.293
# - epoch 228/250 - cost: 0.299, kl:                 0.293
# - epoch 229/250 - cost: 0.241, kl:                 0.293
# - epoch 230/250 - cost: 0.255, kl:                 0.293
# - epoch 231/250 - cost: 0.253, kl:                 0.293
# - epoch 232/250 - cost: 0.317, kl:                 0.293
# - epoch 233/250 - cost: 0.280, kl:                 0.293
# - epoch 234/250 - cost: 0.259, kl:                 0.294
# - epoch 235/250 - cost: 0.263, kl:                 0.295
# - epoch 236/250 - cost: 0.318, kl:                 0.296
# - epoch 237/250 - cost: 0.245, kl:                 0.296
# - epoch 238/250 - cost: 0.267, kl:                 0.296
# - epoch 239/250 - cost: 0.279, kl:                 0.296
# - epoch 240/250 - cost: 0.303, kl:                 0.296
# - epoch 241/250 - cost: 0.235, kl:                 0.296
# - epoch 242/250 - cost: 0.387, kl:                 0.296
# - epoch 243/250 - cost: 0.215, kl:                 0.297
# - epoch 244/250 - cost: 0.236, kl:                 0.298
# - epoch 245/250 - cost: 0.219, kl:                 0.299
# - epoch 246/250 - cost: 0.211, kl:                 0.300
# - epoch 247/250 - cost: 0.277, kl:                 0.300
# - epoch 248/250 - cost: 0.255, kl:                 0.302
# - epoch 249/250 - cost: 0.242, kl:                 0.303
# - epoch 250/250 - cost: 0.339, kl:                 0.303
# - this took 296.17 seconds
# Testing the model...
# - cost: 0.241
# - this took 25.53 seconds

# %%
star_mass = torch.linspace(10.5, 10.5, 20)
dust_mass = torch.linspace(4, 9, 20)
theta = torch.linspace(45, 45, 20)
x_pred = model.create_predict_tensor(star_mass, dust_mass, theta)
print(x_pred.shape)
mean_pred_results, std_pred_results = model.predict(x_pred)
# Out:
# torch.Size([20, 3])

# %%
plotter = pltr.Plotter(wavelength, mean_pred_results, x_test, y_test, output = "f")

#plotter.plot_single(150, "grey", "salmon")
#plotter.plot_group_same(0, 40, "grey", "salmon")
plotter.plot_same_ax(1,20,1,'cool')
#plotter.save_figure("test.png")
