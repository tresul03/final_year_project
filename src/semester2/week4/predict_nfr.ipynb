# %% [markdown]
# # Corrections to Last Week's Notebook
# This notebook'll do things a little differently. I made quite a few mistakes in the last one; I'll address them all.
#
# To begin, I was normalising my output arrays alone, and not my inputs, which may be one of the reasons why the model's accuracy suffered.
#
# Further, I was normalising my output arrays with respect to the inclination parameter; as in, I normalised each sub-run of a SKIRT output file individually. What I should have done was generate the entire dataset, and *then* normalise it. Dimensionally, for each output type ($n, f$, or $r$), I'd normalise 1,000 arrays at a time, instead of 1.
#
# Secondly, I'm going to use separate models to predict each output array, as opposed to using one model to predict all three simultaneously. The reason for this is that in the compact model, since the backwarded cost is the sum of the costs of all three outputs, the cost of one output affects the cost of another, independent output, which is sub-optimal. We need costs to be independent of each other, since their outputs are independent.
#
# I'm going to use logarithmic scales to display my output arrays. I can't remember the reasoning behind this, but I'll do it anyway.
#
# Since I'm using separate models for all three outputs, the question of whether or not normalisation is necessary remains. I won't implement it in the library that stores the model.
#
# From here onwards, I'm no longer going to define the model every time I make a new notebook; I'll just have a separate python script that stores the model class for me: makes debugging a *lot* easier.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from plotter import Plotter
from radiative_transfer_bnn import RadiativeTransferBNN

# %%
model = RadiativeTransferBNN(1000, 0.3, 0.01, "flux")
# model.preprocess_data()
model.train_model(1000, 200)
# Out:
# c:\Users\resul\OneDrive\Physics\Final Year\PH30036\project_script\src\semester2\week4\radiative_transfer_bnn.py:299: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([
# Training the model...
# - epoch 1/1000 - cost: 9.511, kl:                 0.053
# - epoch 2/1000 - cost: 7.273, kl:                 0.092
# - epoch 3/1000 - cost: 6.176, kl:                 0.128
# - epoch 4/1000 - cost: 2.970, kl:                 0.157
# - epoch 5/1000 - cost: 2.898, kl:                 0.181
# - epoch 6/1000 - cost: 1.960, kl:                 0.198
# - epoch 7/1000 - cost: 1.047, kl:                 0.211
# - epoch 8/1000 - cost: 1.007, kl:                 0.221
# - epoch 9/1000 - cost: 0.705, kl:                 0.227
# - epoch 10/1000 - cost: 0.490, kl:                 0.232
# - epoch 11/1000 - cost: 0.432, kl:                 0.235
# - epoch 12/1000 - cost: 0.440, kl:                 0.237
# - epoch 13/1000 - cost: 0.447, kl:                 0.238
# - epoch 14/1000 - cost: 0.349, kl:                 0.240
# - epoch 15/1000 - cost: 0.395, kl:                 0.240
# - epoch 16/1000 - cost: 0.270, kl:                 0.241
# - epoch 17/1000 - cost: 0.334, kl:                 0.241
# - epoch 18/1000 - cost: 0.466, kl:                 0.241
# - epoch 19/1000 - cost: 0.284, kl:                 0.242
# - epoch 20/1000 - cost: 0.243, kl:                 0.242
# - epoch 21/1000 - cost: 0.313, kl:                 0.242
# - epoch 22/1000 - cost: 0.286, kl:                 0.242
# - epoch 23/1000 - cost: 0.249, kl:                 0.242
# - epoch 24/1000 - cost: 0.247, kl:                 0.242
# - epoch 25/1000 - cost: 0.196, kl:                 0.242
# - epoch 26/1000 - cost: 0.279, kl:                 0.242
# - epoch 27/1000 - cost: 0.436, kl:                 0.242
# - epoch 28/1000 - cost: 0.254, kl:                 0.242
# - epoch 29/1000 - cost: 0.194, kl:                 0.243
# - epoch 30/1000 - cost: 0.280, kl:                 0.243
# - epoch 31/1000 - cost: 0.268, kl:                 0.243
# - epoch 32/1000 - cost: 0.192, kl:                 0.243
# - epoch 33/1000 - cost: 0.232, kl:                 0.243
# - epoch 34/1000 - cost: 0.208, kl:                 0.243
# - epoch 35/1000 - cost: 0.211, kl:                 0.243
# - epoch 36/1000 - cost: 0.284, kl:                 0.243
# - epoch 37/1000 - cost: 0.226, kl:                 0.242
# - epoch 38/1000 - cost: 0.166, kl:                 0.242
# - epoch 39/1000 - cost: 0.269, kl:                 0.242
# - epoch 40/1000 - cost: 0.210, kl:                 0.242
# - epoch 41/1000 - cost: 0.210, kl:                 0.242
# - epoch 42/1000 - cost: 0.369, kl:                 0.242
# - epoch 43/1000 - cost: 0.235, kl:                 0.242
# - epoch 44/1000 - cost: 0.167, kl:                 0.242
# - epoch 45/1000 - cost: 0.179, kl:                 0.242
# - epoch 46/1000 - cost: 0.199, kl:                 0.242
# - epoch 47/1000 - cost: 0.229, kl:                 0.242
# - epoch 48/1000 - cost: 0.261, kl:                 0.242
# - epoch 49/1000 - cost: 0.212, kl:                 0.242
# - epoch 50/1000 - cost: 0.199, kl:                 0.242
# - epoch 51/1000 - cost: 0.256, kl:                 0.242
# - epoch 52/1000 - cost: 0.248, kl:                 0.242
# - epoch 53/1000 - cost: 0.242, kl:                 0.242
# - epoch 54/1000 - cost: 0.283, kl:                 0.242
# - epoch 55/1000 - cost: 0.140, kl:                 0.242
# - epoch 56/1000 - cost: 0.187, kl:                 0.242
# - epoch 57/1000 - cost: 0.317, kl:                 0.242
# - epoch 58/1000 - cost: 0.195, kl:                 0.242
# - epoch 59/1000 - cost: 0.176, kl:                 0.242
# - epoch 60/1000 - cost: 0.295, kl:                 0.242
# - epoch 61/1000 - cost: 0.163, kl:                 0.242
# - epoch 62/1000 - cost: 0.282, kl:                 0.241
# - epoch 63/1000 - cost: 0.184, kl:                 0.241
# - epoch 64/1000 - cost: 0.212, kl:                 0.241
# - epoch 65/1000 - cost: 0.214, kl:                 0.241
# - epoch 66/1000 - cost: 0.260, kl:                 0.241
# - epoch 67/1000 - cost: 0.206, kl:                 0.241
# - epoch 68/1000 - cost: 0.144, kl:                 0.241
# - epoch 69/1000 - cost: 0.238, kl:                 0.241
# - epoch 70/1000 - cost: 0.149, kl:                 0.240
# - epoch 71/1000 - cost: 0.126, kl:                 0.240
# - epoch 72/1000 - cost: 0.127, kl:                 0.240
# - epoch 73/1000 - cost: 0.197, kl:                 0.240
# - epoch 74/1000 - cost: 0.331, kl:                 0.240
# - epoch 75/1000 - cost: 0.195, kl:                 0.240
# - epoch 76/1000 - cost: 0.354, kl:                 0.239
# - epoch 77/1000 - cost: 0.204, kl:                 0.239
# - epoch 78/1000 - cost: 0.198, kl:                 0.239
# - epoch 79/1000 - cost: 0.201, kl:                 0.239
# - epoch 80/1000 - cost: 0.191, kl:                 0.239
# - epoch 81/1000 - cost: 0.202, kl:                 0.239
# - epoch 82/1000 - cost: 0.149, kl:                 0.239
# - epoch 83/1000 - cost: 0.151, kl:                 0.239
# - epoch 84/1000 - cost: 0.222, kl:                 0.238
# - epoch 85/1000 - cost: 0.494, kl:                 0.238
# - epoch 86/1000 - cost: 0.196, kl:                 0.238
# - epoch 87/1000 - cost: 0.236, kl:                 0.238
# - epoch 88/1000 - cost: 0.264, kl:                 0.238
# - epoch 89/1000 - cost: 0.249, kl:                 0.238
# - epoch 90/1000 - cost: 0.230, kl:                 0.238
# - epoch 91/1000 - cost: 0.160, kl:                 0.237
# - epoch 92/1000 - cost: 0.269, kl:                 0.237
# - epoch 93/1000 - cost: 0.177, kl:                 0.237
# - epoch 94/1000 - cost: 0.174, kl:                 0.237
# - epoch 95/1000 - cost: 0.277, kl:                 0.237
# - epoch 96/1000 - cost: 0.141, kl:                 0.236
# - epoch 97/1000 - cost: 0.199, kl:                 0.236
# - epoch 98/1000 - cost: 0.170, kl:                 0.236
# - epoch 99/1000 - cost: 0.243, kl:                 0.236
# - epoch 100/1000 - cost: 0.210, kl:                 0.236
# - epoch 101/1000 - cost: 0.192, kl:                 0.235
# - epoch 102/1000 - cost: 0.261, kl:                 0.235
# - epoch 103/1000 - cost: 0.153, kl:                 0.235
# - epoch 104/1000 - cost: 0.152, kl:                 0.234
# - epoch 105/1000 - cost: 0.169, kl:                 0.234
# - epoch 106/1000 - cost: 0.207, kl:                 0.234
# - epoch 107/1000 - cost: 0.159, kl:                 0.234
# - epoch 108/1000 - cost: 0.132, kl:                 0.233
# - epoch 109/1000 - cost: 0.152, kl:                 0.233
# - epoch 110/1000 - cost: 0.147, kl:                 0.233
# - epoch 111/1000 - cost: 0.118, kl:                 0.233
# - epoch 112/1000 - cost: 0.183, kl:                 0.232
# - epoch 113/1000 - cost: 0.279, kl:                 0.232
# - epoch 114/1000 - cost: 0.162, kl:                 0.232
# - epoch 115/1000 - cost: 0.234, kl:                 0.231
# - epoch 116/1000 - cost: 0.182, kl:                 0.231
# - epoch 117/1000 - cost: 0.124, kl:                 0.231
# - epoch 118/1000 - cost: 0.176, kl:                 0.231
# - epoch 119/1000 - cost: 0.237, kl:                 0.230
# - epoch 120/1000 - cost: 0.148, kl:                 0.230
# - epoch 121/1000 - cost: 0.163, kl:                 0.230
# - epoch 122/1000 - cost: 0.237, kl:                 0.230
# - epoch 123/1000 - cost: 0.190, kl:                 0.230
# - epoch 124/1000 - cost: 0.210, kl:                 0.229
# - epoch 125/1000 - cost: 0.120, kl:                 0.229
# - epoch 126/1000 - cost: 0.200, kl:                 0.229
# - epoch 127/1000 - cost: 0.341, kl:                 0.229
# - epoch 128/1000 - cost: 0.167, kl:                 0.228
# - epoch 129/1000 - cost: 0.168, kl:                 0.228
# - epoch 130/1000 - cost: 0.188, kl:                 0.228
# - epoch 131/1000 - cost: 0.144, kl:                 0.227
# - epoch 132/1000 - cost: 0.135, kl:                 0.227
# - epoch 133/1000 - cost: 0.147, kl:                 0.227
# - epoch 134/1000 - cost: 0.208, kl:                 0.226
# - epoch 135/1000 - cost: 0.132, kl:                 0.226
# - epoch 136/1000 - cost: 0.146, kl:                 0.226
# - epoch 137/1000 - cost: 0.183, kl:                 0.225
# - epoch 138/1000 - cost: 0.215, kl:                 0.225
# - epoch 139/1000 - cost: 0.199, kl:                 0.225
# - epoch 140/1000 - cost: 0.176, kl:                 0.224
# - epoch 141/1000 - cost: 0.138, kl:                 0.224
# - epoch 142/1000 - cost: 0.154, kl:                 0.224
# - epoch 143/1000 - cost: 0.192, kl:                 0.223
# - epoch 144/1000 - cost: 0.144, kl:                 0.223
# - epoch 145/1000 - cost: 0.231, kl:                 0.222
# - epoch 146/1000 - cost: 0.135, kl:                 0.222
# - epoch 147/1000 - cost: 0.156, kl:                 0.222
# - epoch 148/1000 - cost: 0.203, kl:                 0.221
# - epoch 149/1000 - cost: 0.222, kl:                 0.221
# - epoch 150/1000 - cost: 0.217, kl:                 0.221
# - epoch 151/1000 - cost: 0.173, kl:                 0.220
# - epoch 152/1000 - cost: 0.270, kl:                 0.220
# - epoch 153/1000 - cost: 0.195, kl:                 0.220
# - epoch 154/1000 - cost: 0.131, kl:                 0.220
# - epoch 155/1000 - cost: 0.210, kl:                 0.219
# - epoch 156/1000 - cost: 0.170, kl:                 0.219
# - epoch 157/1000 - cost: 0.137, kl:                 0.219
# - epoch 158/1000 - cost: 0.245, kl:                 0.218
# - epoch 159/1000 - cost: 0.204, kl:                 0.218
# - epoch 160/1000 - cost: 0.126, kl:                 0.218
# - epoch 161/1000 - cost: 0.147, kl:                 0.217
# - epoch 162/1000 - cost: 0.141, kl:                 0.217
# - epoch 163/1000 - cost: 0.196, kl:                 0.216
# - epoch 164/1000 - cost: 0.198, kl:                 0.216
# - epoch 165/1000 - cost: 0.144, kl:                 0.216
# - epoch 166/1000 - cost: 0.131, kl:                 0.215
# - epoch 167/1000 - cost: 0.153, kl:                 0.215
# - epoch 168/1000 - cost: 0.155, kl:                 0.214
# - epoch 169/1000 - cost: 0.209, kl:                 0.214
# - epoch 170/1000 - cost: 0.178, kl:                 0.213
# - epoch 171/1000 - cost: 0.131, kl:                 0.213
# - epoch 172/1000 - cost: 0.235, kl:                 0.213
# - epoch 173/1000 - cost: 0.251, kl:                 0.212
# - epoch 174/1000 - cost: 0.223, kl:                 0.212
# - epoch 175/1000 - cost: 0.151, kl:                 0.212
# - epoch 176/1000 - cost: 0.149, kl:                 0.211
# - epoch 177/1000 - cost: 0.164, kl:                 0.211
# - epoch 178/1000 - cost: 0.108, kl:                 0.211
# - epoch 179/1000 - cost: 0.152, kl:                 0.211
# - epoch 180/1000 - cost: 0.200, kl:                 0.211
# - epoch 181/1000 - cost: 0.162, kl:                 0.210
# - epoch 182/1000 - cost: 0.110, kl:                 0.210
# - epoch 183/1000 - cost: 0.193, kl:                 0.210
# - epoch 184/1000 - cost: 0.163, kl:                 0.209
# - epoch 185/1000 - cost: 0.133, kl:                 0.209
# - epoch 186/1000 - cost: 0.155, kl:                 0.208
# - epoch 187/1000 - cost: 0.183, kl:                 0.208
# - epoch 188/1000 - cost: 0.141, kl:                 0.207
# - epoch 189/1000 - cost: 0.133, kl:                 0.207
# - epoch 190/1000 - cost: 0.177, kl:                 0.206
# - epoch 191/1000 - cost: 0.141, kl:                 0.206
# - epoch 192/1000 - cost: 0.143, kl:                 0.205
# - epoch 193/1000 - cost: 0.169, kl:                 0.205
# - epoch 194/1000 - cost: 0.155, kl:                 0.204
# - epoch 195/1000 - cost: 0.098, kl:                 0.204
# - epoch 196/1000 - cost: 0.114, kl:                 0.203
# - epoch 197/1000 - cost: 0.088, kl:                 0.203
# - epoch 198/1000 - cost: 0.246, kl:                 0.202
# - epoch 199/1000 - cost: 0.084, kl:                 0.202
# - epoch 200/1000 - cost: 0.147, kl:                 0.201
# - epoch 201/1000 - cost: 0.145, kl:                 0.201
# - epoch 202/1000 - cost: 0.145, kl:                 0.200
# - epoch 203/1000 - cost: 0.135, kl:                 0.200
# - epoch 204/1000 - cost: 0.135, kl:                 0.199
# - epoch 205/1000 - cost: 0.159, kl:                 0.199
# - epoch 206/1000 - cost: 0.169, kl:                 0.198
# - epoch 207/1000 - cost: 0.115, kl:                 0.198
# - epoch 208/1000 - cost: 0.153, kl:                 0.197
# - epoch 209/1000 - cost: 0.114, kl:                 0.197
# - epoch 210/1000 - cost: 0.163, kl:                 0.197
# - epoch 211/1000 - cost: 0.128, kl:                 0.196
# - epoch 212/1000 - cost: 0.198, kl:                 0.196
# - epoch 213/1000 - cost: 0.175, kl:                 0.195
# - epoch 214/1000 - cost: 0.132, kl:                 0.195
# - epoch 215/1000 - cost: 0.145, kl:                 0.194
# - epoch 216/1000 - cost: 0.172, kl:                 0.194
# - epoch 217/1000 - cost: 0.122, kl:                 0.194
# - epoch 218/1000 - cost: 0.175, kl:                 0.193
# - epoch 219/1000 - cost: 0.190, kl:                 0.193
# - epoch 220/1000 - cost: 0.134, kl:                 0.193
# - epoch 221/1000 - cost: 0.203, kl:                 0.192
# - epoch 222/1000 - cost: 0.157, kl:                 0.192
# - epoch 223/1000 - cost: 0.194, kl:                 0.191
# - epoch 224/1000 - cost: 0.132, kl:                 0.191
# - epoch 225/1000 - cost: 0.154, kl:                 0.191
# - epoch 226/1000 - cost: 0.142, kl:                 0.190
# - epoch 227/1000 - cost: 0.092, kl:                 0.190
# - epoch 228/1000 - cost: 0.155, kl:                 0.189
# - epoch 229/1000 - cost: 0.142, kl:                 0.189
# - epoch 230/1000 - cost: 0.143, kl:                 0.188
# - epoch 231/1000 - cost: 0.091, kl:                 0.188
# - epoch 232/1000 - cost: 0.125, kl:                 0.188
# - epoch 233/1000 - cost: 0.131, kl:                 0.187
# - epoch 234/1000 - cost: 0.119, kl:                 0.187
# - epoch 235/1000 - cost: 0.170, kl:                 0.187
# - epoch 236/1000 - cost: 0.144, kl:                 0.186
# - epoch 237/1000 - cost: 0.308, kl:                 0.186
# - epoch 238/1000 - cost: 0.273, kl:                 0.185
# - epoch 239/1000 - cost: 0.092, kl:                 0.185
# - epoch 240/1000 - cost: 0.089, kl:                 0.185
# - epoch 241/1000 - cost: 0.118, kl:                 0.185
# - epoch 242/1000 - cost: 0.127, kl:                 0.185
# - epoch 243/1000 - cost: 0.218, kl:                 0.184
# - epoch 244/1000 - cost: 0.140, kl:                 0.184
# - epoch 245/1000 - cost: 0.138, kl:                 0.184
# - epoch 246/1000 - cost: 0.192, kl:                 0.183
# - epoch 247/1000 - cost: 0.205, kl:                 0.183
# - epoch 248/1000 - cost: 0.153, kl:                 0.182
# - epoch 249/1000 - cost: 0.150, kl:                 0.182
# - epoch 250/1000 - cost: 0.164, kl:                 0.182
# - epoch 251/1000 - cost: 0.316, kl:                 0.181
# - epoch 252/1000 - cost: 0.117, kl:                 0.181
# - epoch 253/1000 - cost: 0.116, kl:                 0.181
# - epoch 254/1000 - cost: 0.150, kl:                 0.181
# - epoch 255/1000 - cost: 0.147, kl:                 0.180
# - epoch 256/1000 - cost: 0.169, kl:                 0.180
# - epoch 257/1000 - cost: 0.200, kl:                 0.180
# - epoch 258/1000 - cost: 0.097, kl:                 0.179
# - epoch 259/1000 - cost: 0.097, kl:                 0.179
# - epoch 260/1000 - cost: 0.120, kl:                 0.178
# - epoch 261/1000 - cost: 0.164, kl:                 0.178
# - epoch 262/1000 - cost: 0.156, kl:                 0.177
# - epoch 263/1000 - cost: 0.110, kl:                 0.177
# - epoch 264/1000 - cost: 0.177, kl:                 0.176
# - epoch 265/1000 - cost: 0.173, kl:                 0.176
# - epoch 266/1000 - cost: 0.102, kl:                 0.175
# - epoch 267/1000 - cost: 0.195, kl:                 0.175
# - epoch 268/1000 - cost: 0.133, kl:                 0.174
# - epoch 269/1000 - cost: 0.206, kl:                 0.174
# - epoch 270/1000 - cost: 0.176, kl:                 0.174
# - epoch 271/1000 - cost: 0.178, kl:                 0.173
# - epoch 272/1000 - cost: 0.098, kl:                 0.173
# - epoch 273/1000 - cost: 0.229, kl:                 0.172
# - epoch 274/1000 - cost: 0.112, kl:                 0.172
# - epoch 275/1000 - cost: 0.131, kl:                 0.172
# - epoch 276/1000 - cost: 0.107, kl:                 0.171
# - epoch 277/1000 - cost: 0.106, kl:                 0.171
# - epoch 278/1000 - cost: 0.185, kl:                 0.171
# - epoch 279/1000 - cost: 0.105, kl:                 0.170
# - epoch 280/1000 - cost: 0.075, kl:                 0.170
# - epoch 281/1000 - cost: 0.142, kl:                 0.170
# - epoch 282/1000 - cost: 0.115, kl:                 0.169
# - epoch 283/1000 - cost: 0.133, kl:                 0.169
# - epoch 284/1000 - cost: 0.174, kl:                 0.168
# - epoch 285/1000 - cost: 0.105, kl:                 0.168
# - epoch 286/1000 - cost: 0.127, kl:                 0.168
# - epoch 287/1000 - cost: 0.132, kl:                 0.167
# - epoch 288/1000 - cost: 0.109, kl:                 0.167
# - epoch 289/1000 - cost: 0.128, kl:                 0.166
# - epoch 290/1000 - cost: 0.124, kl:                 0.166
# - epoch 291/1000 - cost: 0.075, kl:                 0.165
# - epoch 292/1000 - cost: 0.145, kl:                 0.165
# - epoch 293/1000 - cost: 0.157, kl:                 0.165
# - epoch 294/1000 - cost: 0.145, kl:                 0.164
# - epoch 295/1000 - cost: 0.133, kl:                 0.164
# - epoch 296/1000 - cost: 0.111, kl:                 0.164
# - epoch 297/1000 - cost: 0.095, kl:                 0.164
# - epoch 298/1000 - cost: 0.254, kl:                 0.163
# - epoch 299/1000 - cost: 0.155, kl:                 0.163
# - epoch 300/1000 - cost: 0.122, kl:                 0.163
# - epoch 301/1000 - cost: 0.141, kl:                 0.163
# - epoch 302/1000 - cost: 0.142, kl:                 0.162
# - epoch 303/1000 - cost: 0.206, kl:                 0.162
# - epoch 304/1000 - cost: 0.139, kl:                 0.162
# - epoch 305/1000 - cost: 0.141, kl:                 0.162
# - epoch 306/1000 - cost: 0.071, kl:                 0.161
# - epoch 307/1000 - cost: 0.091, kl:                 0.161
# - epoch 308/1000 - cost: 0.108, kl:                 0.161
# - epoch 309/1000 - cost: 0.092, kl:                 0.160
# - epoch 310/1000 - cost: 0.123, kl:                 0.160
# - epoch 311/1000 - cost: 0.106, kl:                 0.160
# - epoch 312/1000 - cost: 0.124, kl:                 0.159
# - epoch 313/1000 - cost: 0.128, kl:                 0.159
# - epoch 314/1000 - cost: 0.119, kl:                 0.159
# - epoch 315/1000 - cost: 0.097, kl:                 0.158
# - epoch 316/1000 - cost: 0.086, kl:                 0.158
# - epoch 317/1000 - cost: 0.145, kl:                 0.158
# - epoch 318/1000 - cost: 0.131, kl:                 0.157
# - epoch 319/1000 - cost: 0.107, kl:                 0.157
# - epoch 320/1000 - cost: 0.106, kl:                 0.157
# - epoch 321/1000 - cost: 0.137, kl:                 0.156
# - epoch 322/1000 - cost: 0.104, kl:                 0.156
# - epoch 323/1000 - cost: 0.143, kl:                 0.156
# - epoch 324/1000 - cost: 0.154, kl:                 0.155
# - epoch 325/1000 - cost: 0.131, kl:                 0.155
# - epoch 326/1000 - cost: 0.115, kl:                 0.155
# - epoch 327/1000 - cost: 0.138, kl:                 0.154
# - epoch 328/1000 - cost: 0.257, kl:                 0.154
# - epoch 329/1000 - cost: 0.134, kl:                 0.154
# - epoch 330/1000 - cost: 0.146, kl:                 0.154
# - epoch 331/1000 - cost: 0.102, kl:                 0.154
# - epoch 332/1000 - cost: 0.170, kl:                 0.154
# - epoch 333/1000 - cost: 0.080, kl:                 0.153
# - epoch 334/1000 - cost: 0.203, kl:                 0.153
# - epoch 335/1000 - cost: 0.253, kl:                 0.153
# - epoch 336/1000 - cost: 0.110, kl:                 0.153
# - epoch 337/1000 - cost: 0.145, kl:                 0.153
# - epoch 338/1000 - cost: 0.125, kl:                 0.153
# - epoch 339/1000 - cost: 0.149, kl:                 0.152
# - epoch 340/1000 - cost: 0.129, kl:                 0.152
# - epoch 341/1000 - cost: 0.106, kl:                 0.152
# - epoch 342/1000 - cost: 0.143, kl:                 0.152
# - epoch 343/1000 - cost: 0.167, kl:                 0.152
# - epoch 344/1000 - cost: 0.156, kl:                 0.152
# - epoch 345/1000 - cost: 0.098, kl:                 0.152
# - epoch 346/1000 - cost: 0.128, kl:                 0.152
# - epoch 347/1000 - cost: 0.130, kl:                 0.151
# - epoch 348/1000 - cost: 0.096, kl:                 0.151
# - epoch 349/1000 - cost: 0.092, kl:                 0.151
# - epoch 350/1000 - cost: 0.144, kl:                 0.150
# - epoch 351/1000 - cost: 0.171, kl:                 0.150
# - epoch 352/1000 - cost: 0.094, kl:                 0.150
# - epoch 353/1000 - cost: 0.102, kl:                 0.149
# - epoch 354/1000 - cost: 0.068, kl:                 0.149
# - epoch 355/1000 - cost: 0.145, kl:                 0.148
# - epoch 356/1000 - cost: 0.103, kl:                 0.148
# - epoch 357/1000 - cost: 0.108, kl:                 0.148
# - epoch 358/1000 - cost: 0.157, kl:                 0.147
# - epoch 359/1000 - cost: 0.172, kl:                 0.147
# - epoch 360/1000 - cost: 0.162, kl:                 0.147
# - epoch 361/1000 - cost: 0.118, kl:                 0.146
# - epoch 362/1000 - cost: 0.140, kl:                 0.146
# - epoch 363/1000 - cost: 0.150, kl:                 0.146
# - epoch 364/1000 - cost: 0.187, kl:                 0.146
# - epoch 365/1000 - cost: 0.078, kl:                 0.146
# - epoch 366/1000 - cost: 0.198, kl:                 0.146
# - epoch 367/1000 - cost: 0.111, kl:                 0.146
# - epoch 368/1000 - cost: 0.077, kl:                 0.146
# - epoch 369/1000 - cost: 0.088, kl:                 0.145
# - epoch 370/1000 - cost: 0.134, kl:                 0.145
# - epoch 371/1000 - cost: 0.164, kl:                 0.145
# - epoch 372/1000 - cost: 0.105, kl:                 0.145
# - epoch 373/1000 - cost: 0.130, kl:                 0.144
# - epoch 374/1000 - cost: 0.100, kl:                 0.144
# - epoch 375/1000 - cost: 0.102, kl:                 0.144
# - epoch 376/1000 - cost: 0.137, kl:                 0.144
# - epoch 377/1000 - cost: 0.101, kl:                 0.143
# - epoch 378/1000 - cost: 0.129, kl:                 0.143
# - epoch 379/1000 - cost: 0.066, kl:                 0.143
# - epoch 380/1000 - cost: 0.062, kl:                 0.143
# - epoch 381/1000 - cost: 0.081, kl:                 0.142
# - epoch 382/1000 - cost: 0.141, kl:                 0.142
# - epoch 383/1000 - cost: 0.110, kl:                 0.142
# - epoch 384/1000 - cost: 0.171, kl:                 0.141
# - epoch 385/1000 - cost: 0.106, kl:                 0.141
# - epoch 386/1000 - cost: 0.091, kl:                 0.141
# - epoch 387/1000 - cost: 0.112, kl:                 0.140
# - epoch 388/1000 - cost: 0.100, kl:                 0.140
# - epoch 389/1000 - cost: 0.161, kl:                 0.140
# - epoch 390/1000 - cost: 0.076, kl:                 0.140
# - epoch 391/1000 - cost: 0.068, kl:                 0.139
# - epoch 392/1000 - cost: 0.144, kl:                 0.139
# - epoch 393/1000 - cost: 0.084, kl:                 0.139
# - epoch 394/1000 - cost: 0.114, kl:                 0.138
# - epoch 395/1000 - cost: 0.151, kl:                 0.138
# - epoch 396/1000 - cost: 0.134, kl:                 0.138
# - epoch 397/1000 - cost: 0.107, kl:                 0.138
# - epoch 398/1000 - cost: 0.078, kl:                 0.137
# - epoch 399/1000 - cost: 0.100, kl:                 0.137
# - epoch 400/1000 - cost: 0.106, kl:                 0.137
# - epoch 401/1000 - cost: 0.188, kl:                 0.137
# - epoch 402/1000 - cost: 0.174, kl:                 0.137
# - epoch 403/1000 - cost: 0.234, kl:                 0.137
# - epoch 404/1000 - cost: 0.107, kl:                 0.136
# - epoch 405/1000 - cost: 0.163, kl:                 0.137
# - epoch 406/1000 - cost: 0.102, kl:                 0.136
# - epoch 407/1000 - cost: 0.103, kl:                 0.136
# - epoch 408/1000 - cost: 0.131, kl:                 0.136
# - epoch 409/1000 - cost: 0.126, kl:                 0.136
# - epoch 410/1000 - cost: 0.145, kl:                 0.136
# - epoch 411/1000 - cost: 0.178, kl:                 0.136
# - epoch 412/1000 - cost: 0.223, kl:                 0.136
# - epoch 413/1000 - cost: 0.112, kl:                 0.136
# - epoch 414/1000 - cost: 0.159, kl:                 0.136
# - epoch 415/1000 - cost: 0.095, kl:                 0.136
# - epoch 416/1000 - cost: 0.093, kl:                 0.136
# - epoch 417/1000 - cost: 0.349, kl:                 0.136
# - epoch 418/1000 - cost: 0.155, kl:                 0.136
# - epoch 419/1000 - cost: 0.213, kl:                 0.136
# - epoch 420/1000 - cost: 0.068, kl:                 0.136
# - epoch 421/1000 - cost: 0.158, kl:                 0.136
# - epoch 422/1000 - cost: 0.165, kl:                 0.136
# - epoch 423/1000 - cost: 0.144, kl:                 0.136
# - epoch 424/1000 - cost: 0.153, kl:                 0.136
# - epoch 425/1000 - cost: 0.146, kl:                 0.136
# - epoch 426/1000 - cost: 0.180, kl:                 0.136
# - epoch 427/1000 - cost: 0.115, kl:                 0.136
# - epoch 428/1000 - cost: 0.183, kl:                 0.136
# - epoch 429/1000 - cost: 0.146, kl:                 0.136
# - epoch 430/1000 - cost: 0.181, kl:                 0.136
# - epoch 431/1000 - cost: 0.179, kl:                 0.136
# - epoch 432/1000 - cost: 0.154, kl:                 0.137
# - epoch 433/1000 - cost: 0.138, kl:                 0.137
# - epoch 434/1000 - cost: 0.092, kl:                 0.137
# - epoch 435/1000 - cost: 0.164, kl:                 0.136
# - epoch 436/1000 - cost: 0.074, kl:                 0.136
# - epoch 437/1000 - cost: 0.126, kl:                 0.136
# - epoch 438/1000 - cost: 0.140, kl:                 0.136
# - epoch 439/1000 - cost: 0.127, kl:                 0.136
# - epoch 440/1000 - cost: 0.105, kl:                 0.136
# - epoch 441/1000 - cost: 0.109, kl:                 0.135
# - epoch 442/1000 - cost: 0.101, kl:                 0.135
# - epoch 443/1000 - cost: 0.104, kl:                 0.135
# - epoch 444/1000 - cost: 0.087, kl:                 0.135
# - epoch 445/1000 - cost: 0.145, kl:                 0.134
# - epoch 446/1000 - cost: 0.143, kl:                 0.134
# - epoch 447/1000 - cost: 0.118, kl:                 0.134
# - epoch 448/1000 - cost: 0.118, kl:                 0.133
# - epoch 449/1000 - cost: 0.153, kl:                 0.133
# - epoch 450/1000 - cost: 0.066, kl:                 0.133
# - epoch 451/1000 - cost: 0.120, kl:                 0.133
# - epoch 452/1000 - cost: 0.153, kl:                 0.133
# - epoch 453/1000 - cost: 0.124, kl:                 0.132
# - epoch 454/1000 - cost: 0.109, kl:                 0.132
# - epoch 455/1000 - cost: 0.159, kl:                 0.132
# - epoch 456/1000 - cost: 0.119, kl:                 0.132
# - epoch 457/1000 - cost: 0.132, kl:                 0.131
# - epoch 458/1000 - cost: 0.183, kl:                 0.131
# - epoch 459/1000 - cost: 0.094, kl:                 0.131
# - epoch 460/1000 - cost: 0.077, kl:                 0.131
# - epoch 461/1000 - cost: 0.072, kl:                 0.131
# - epoch 462/1000 - cost: 0.088, kl:                 0.131
# - epoch 463/1000 - cost: 0.176, kl:                 0.131
# - epoch 464/1000 - cost: 0.177, kl:                 0.130
# - epoch 465/1000 - cost: 0.061, kl:                 0.130
# - epoch 466/1000 - cost: 0.113, kl:                 0.130
# - epoch 467/1000 - cost: 0.189, kl:                 0.130
# - epoch 468/1000 - cost: 0.093, kl:                 0.130
# - epoch 469/1000 - cost: 0.125, kl:                 0.130
# - epoch 470/1000 - cost: 0.108, kl:                 0.129
# - epoch 471/1000 - cost: 0.086, kl:                 0.129
# - epoch 472/1000 - cost: 0.129, kl:                 0.129
# - epoch 473/1000 - cost: 0.100, kl:                 0.129
# - epoch 474/1000 - cost: 0.154, kl:                 0.128
# - epoch 475/1000 - cost: 0.256, kl:                 0.128
# - epoch 476/1000 - cost: 0.108, kl:                 0.128
# - epoch 477/1000 - cost: 0.214, kl:                 0.128
# - epoch 478/1000 - cost: 0.148, kl:                 0.128
# - epoch 479/1000 - cost: 0.108, kl:                 0.128
# - epoch 480/1000 - cost: 0.108, kl:                 0.128
# - epoch 481/1000 - cost: 0.084, kl:                 0.128
# - epoch 482/1000 - cost: 0.143, kl:                 0.128
# - epoch 483/1000 - cost: 0.081, kl:                 0.128
# - epoch 484/1000 - cost: 0.144, kl:                 0.128
# - epoch 485/1000 - cost: 0.078, kl:                 0.127
# - epoch 486/1000 - cost: 0.097, kl:                 0.127
# - epoch 487/1000 - cost: 0.113, kl:                 0.127
# - epoch 488/1000 - cost: 0.128, kl:                 0.126
# - epoch 489/1000 - cost: 0.149, kl:                 0.126
# - epoch 490/1000 - cost: 0.114, kl:                 0.126
# - epoch 491/1000 - cost: 0.122, kl:                 0.126
# - epoch 492/1000 - cost: 0.150, kl:                 0.125
# - epoch 493/1000 - cost: 0.187, kl:                 0.125
# - epoch 494/1000 - cost: 0.097, kl:                 0.125
# - epoch 495/1000 - cost: 0.147, kl:                 0.125
# - epoch 496/1000 - cost: 0.181, kl:                 0.125
# - epoch 497/1000 - cost: 0.198, kl:                 0.126
# - epoch 498/1000 - cost: 0.142, kl:                 0.126
# - epoch 499/1000 - cost: 0.089, kl:                 0.126
# - epoch 500/1000 - cost: 0.105, kl:                 0.127
# - epoch 501/1000 - cost: 0.135, kl:                 0.127
# - epoch 502/1000 - cost: 0.073, kl:                 0.127
# - epoch 503/1000 - cost: 0.164, kl:                 0.127
# - epoch 504/1000 - cost: 0.071, kl:                 0.127
# - epoch 505/1000 - cost: 0.078, kl:                 0.126
# - epoch 506/1000 - cost: 0.082, kl:                 0.126
# - epoch 507/1000 - cost: 0.123, kl:                 0.126
# - epoch 508/1000 - cost: 0.175, kl:                 0.126
# - epoch 509/1000 - cost: 0.095, kl:                 0.126
# - epoch 510/1000 - cost: 0.097, kl:                 0.126
# - epoch 511/1000 - cost: 0.158, kl:                 0.126
# - epoch 512/1000 - cost: 0.104, kl:                 0.126
# - epoch 513/1000 - cost: 0.085, kl:                 0.126
# - epoch 514/1000 - cost: 0.087, kl:                 0.126
# - epoch 515/1000 - cost: 0.077, kl:                 0.126
# - epoch 516/1000 - cost: 0.108, kl:                 0.126
# - epoch 517/1000 - cost: 0.128, kl:                 0.126
# - epoch 518/1000 - cost: 0.137, kl:                 0.126
# - epoch 519/1000 - cost: 0.088, kl:                 0.125
# - epoch 520/1000 - cost: 0.106, kl:                 0.125
# - epoch 521/1000 - cost: 0.101, kl:                 0.125
# - epoch 522/1000 - cost: 0.120, kl:                 0.125
# - epoch 523/1000 - cost: 0.206, kl:                 0.125
# - epoch 524/1000 - cost: 0.140, kl:                 0.125
# - epoch 525/1000 - cost: 0.102, kl:                 0.126
# - epoch 526/1000 - cost: 0.131, kl:                 0.126
# - epoch 527/1000 - cost: 0.056, kl:                 0.126
# - epoch 528/1000 - cost: 0.110, kl:                 0.125
# - epoch 529/1000 - cost: 0.106, kl:                 0.125
# - epoch 530/1000 - cost: 0.189, kl:                 0.125
# - epoch 531/1000 - cost: 0.188, kl:                 0.125
# - epoch 532/1000 - cost: 0.138, kl:                 0.125
# - epoch 533/1000 - cost: 0.113, kl:                 0.125
# - epoch 534/1000 - cost: 0.094, kl:                 0.125
# - epoch 535/1000 - cost: 0.113, kl:                 0.125
# - epoch 536/1000 - cost: 0.098, kl:                 0.125
# - epoch 537/1000 - cost: 0.094, kl:                 0.125
# - epoch 538/1000 - cost: 0.143, kl:                 0.125
# - epoch 539/1000 - cost: 0.108, kl:                 0.125
# - epoch 540/1000 - cost: 0.097, kl:                 0.125
# - epoch 541/1000 - cost: 0.074, kl:                 0.124
# - epoch 542/1000 - cost: 0.130, kl:                 0.124
# - epoch 543/1000 - cost: 0.115, kl:                 0.124
# - epoch 544/1000 - cost: 0.154, kl:                 0.124
# - epoch 545/1000 - cost: 0.137, kl:                 0.124
# - epoch 546/1000 - cost: 0.069, kl:                 0.124
# - epoch 547/1000 - cost: 0.083, kl:                 0.124
# - epoch 548/1000 - cost: 0.058, kl:                 0.124
# - epoch 549/1000 - cost: 0.106, kl:                 0.124
# - epoch 550/1000 - cost: 0.099, kl:                 0.124
# - epoch 551/1000 - cost: 0.114, kl:                 0.124
# - epoch 552/1000 - cost: 0.088, kl:                 0.124
# - epoch 553/1000 - cost: 0.170, kl:                 0.124
# - epoch 554/1000 - cost: 0.055, kl:                 0.124
# - epoch 555/1000 - cost: 0.102, kl:                 0.124
# - epoch 556/1000 - cost: 0.148, kl:                 0.124
# - epoch 557/1000 - cost: 0.103, kl:                 0.125
# - epoch 558/1000 - cost: 0.193, kl:                 0.125
# - epoch 559/1000 - cost: 0.079, kl:                 0.125
# - epoch 560/1000 - cost: 0.078, kl:                 0.125
# - epoch 561/1000 - cost: 0.110, kl:                 0.125
# - epoch 562/1000 - cost: 0.141, kl:                 0.125
# - epoch 563/1000 - cost: 0.105, kl:                 0.125
# - epoch 564/1000 - cost: 0.112, kl:                 0.125
# - epoch 565/1000 - cost: 0.071, kl:                 0.125
# - epoch 566/1000 - cost: 0.101, kl:                 0.124
# - epoch 567/1000 - cost: 0.128, kl:                 0.124
# - epoch 568/1000 - cost: 0.167, kl:                 0.124
# - epoch 569/1000 - cost: 0.091, kl:                 0.124
# - epoch 570/1000 - cost: 0.168, kl:                 0.124
# - epoch 571/1000 - cost: 0.262, kl:                 0.124
# - epoch 572/1000 - cost: 0.096, kl:                 0.124
# - epoch 573/1000 - cost: 0.105, kl:                 0.124
# - epoch 574/1000 - cost: 0.125, kl:                 0.125
# - epoch 575/1000 - cost: 0.132, kl:                 0.125
# - epoch 576/1000 - cost: 0.114, kl:                 0.125
# - epoch 577/1000 - cost: 0.104, kl:                 0.125
# - epoch 578/1000 - cost: 0.118, kl:                 0.125
# - epoch 579/1000 - cost: 0.149, kl:                 0.125
# - epoch 580/1000 - cost: 0.112, kl:                 0.125
# - epoch 581/1000 - cost: 0.101, kl:                 0.125
# - epoch 582/1000 - cost: 0.135, kl:                 0.125
# - epoch 583/1000 - cost: 0.076, kl:                 0.124
# - epoch 584/1000 - cost: 0.098, kl:                 0.124
# - epoch 585/1000 - cost: 0.067, kl:                 0.124
# - epoch 586/1000 - cost: 0.122, kl:                 0.124
# - epoch 587/1000 - cost: 0.111, kl:                 0.124
# - epoch 588/1000 - cost: 0.127, kl:                 0.124
# - epoch 589/1000 - cost: 0.109, kl:                 0.124
# - epoch 590/1000 - cost: 0.107, kl:                 0.124
# - epoch 591/1000 - cost: 0.113, kl:                 0.124
# - epoch 592/1000 - cost: 0.122, kl:                 0.124
# - epoch 593/1000 - cost: 0.117, kl:                 0.124
# - epoch 594/1000 - cost: 0.113, kl:                 0.125
# - epoch 595/1000 - cost: 0.109, kl:                 0.125
# - epoch 596/1000 - cost: 0.084, kl:                 0.125
# - epoch 597/1000 - cost: 0.080, kl:                 0.125
# - epoch 598/1000 - cost: 0.086, kl:                 0.125
# - epoch 599/1000 - cost: 0.215, kl:                 0.125
# - epoch 600/1000 - cost: 0.087, kl:                 0.125
# - epoch 601/1000 - cost: 0.102, kl:                 0.125
# - epoch 602/1000 - cost: 0.071, kl:                 0.126
# - epoch 603/1000 - cost: 0.146, kl:                 0.126
# - epoch 604/1000 - cost: 0.242, kl:                 0.126
# - epoch 605/1000 - cost: 0.226, kl:                 0.127
# - epoch 606/1000 - cost: 0.187, kl:                 0.127
# - epoch 607/1000 - cost: 0.102, kl:                 0.128
# - epoch 608/1000 - cost: 0.086, kl:                 0.128
# - epoch 609/1000 - cost: 0.158, kl:                 0.128
# - epoch 610/1000 - cost: 0.111, kl:                 0.129
# - epoch 611/1000 - cost: 0.095, kl:                 0.129
# - epoch 612/1000 - cost: 0.116, kl:                 0.129
# - epoch 613/1000 - cost: 0.121, kl:                 0.129
# - epoch 614/1000 - cost: 0.134, kl:                 0.128
# - epoch 615/1000 - cost: 0.130, kl:                 0.128
# - epoch 616/1000 - cost: 0.125, kl:                 0.128
# - epoch 617/1000 - cost: 0.133, kl:                 0.128
# - epoch 618/1000 - cost: 0.093, kl:                 0.128
# - epoch 619/1000 - cost: 0.077, kl:                 0.128
# - epoch 620/1000 - cost: 0.090, kl:                 0.128
# - epoch 621/1000 - cost: 0.063, kl:                 0.128
# - epoch 622/1000 - cost: 0.151, kl:                 0.128
# - epoch 623/1000 - cost: 0.117, kl:                 0.127
# - epoch 624/1000 - cost: 0.070, kl:                 0.127
# - epoch 625/1000 - cost: 0.179, kl:                 0.127
# - epoch 626/1000 - cost: 0.128, kl:                 0.127
# - epoch 627/1000 - cost: 0.106, kl:                 0.128
# - epoch 628/1000 - cost: 0.128, kl:                 0.128
# - epoch 629/1000 - cost: 0.081, kl:                 0.128
# - epoch 630/1000 - cost: 0.074, kl:                 0.128
# - epoch 631/1000 - cost: 0.178, kl:                 0.128
# - epoch 632/1000 - cost: 0.078, kl:                 0.128
# - epoch 633/1000 - cost: 0.144, kl:                 0.129
# - epoch 634/1000 - cost: 0.132, kl:                 0.129
# - epoch 635/1000 - cost: 0.109, kl:                 0.129
# - epoch 636/1000 - cost: 0.112, kl:                 0.129
# - epoch 637/1000 - cost: 0.115, kl:                 0.130
# - epoch 638/1000 - cost: 0.160, kl:                 0.130
# - epoch 639/1000 - cost: 0.128, kl:                 0.130
# - epoch 640/1000 - cost: 0.099, kl:                 0.130
# - epoch 641/1000 - cost: 0.175, kl:                 0.131
# - epoch 642/1000 - cost: 0.115, kl:                 0.131
# - epoch 643/1000 - cost: 0.090, kl:                 0.131
# - epoch 644/1000 - cost: 0.099, kl:                 0.132
# - epoch 645/1000 - cost: 0.093, kl:                 0.132
# - epoch 646/1000 - cost: 0.108, kl:                 0.132
# - epoch 647/1000 - cost: 0.094, kl:                 0.133
# - epoch 648/1000 - cost: 0.140, kl:                 0.133
# - epoch 649/1000 - cost: 0.135, kl:                 0.133
# - epoch 650/1000 - cost: 0.101, kl:                 0.133
# - epoch 651/1000 - cost: 0.115, kl:                 0.133
# - epoch 652/1000 - cost: 0.114, kl:                 0.133
# - epoch 653/1000 - cost: 0.065, kl:                 0.133
# - epoch 654/1000 - cost: 0.083, kl:                 0.133
# - epoch 655/1000 - cost: 0.105, kl:                 0.133
# - epoch 656/1000 - cost: 0.124, kl:                 0.133
# - epoch 657/1000 - cost: 0.100, kl:                 0.133
# - epoch 658/1000 - cost: 0.098, kl:                 0.133
# - epoch 659/1000 - cost: 0.093, kl:                 0.133
# - epoch 660/1000 - cost: 0.095, kl:                 0.133
# - epoch 661/1000 - cost: 0.136, kl:                 0.133
# - epoch 662/1000 - cost: 0.108, kl:                 0.133
# - epoch 663/1000 - cost: 0.069, kl:                 0.133
# - epoch 664/1000 - cost: 0.094, kl:                 0.133
# - epoch 665/1000 - cost: 0.119, kl:                 0.133
# - epoch 666/1000 - cost: 0.187, kl:                 0.133
# - epoch 667/1000 - cost: 0.101, kl:                 0.134
# - epoch 668/1000 - cost: 0.157, kl:                 0.134
# - epoch 669/1000 - cost: 0.079, kl:                 0.134
# - epoch 670/1000 - cost: 0.091, kl:                 0.135
# - epoch 671/1000 - cost: 0.100, kl:                 0.135
# - epoch 672/1000 - cost: 0.110, kl:                 0.135
# - epoch 673/1000 - cost: 0.092, kl:                 0.135
# - epoch 674/1000 - cost: 0.122, kl:                 0.135
# - epoch 675/1000 - cost: 0.133, kl:                 0.135
# - epoch 676/1000 - cost: 0.116, kl:                 0.136
# - epoch 677/1000 - cost: 0.125, kl:                 0.136
# - epoch 678/1000 - cost: 0.114, kl:                 0.136
# - epoch 679/1000 - cost: 0.167, kl:                 0.136
# - epoch 680/1000 - cost: 0.122, kl:                 0.137
# - epoch 681/1000 - cost: 0.084, kl:                 0.137
# - epoch 682/1000 - cost: 0.143, kl:                 0.137
# - epoch 683/1000 - cost: 0.138, kl:                 0.138
# - epoch 684/1000 - cost: 0.131, kl:                 0.138
# - epoch 685/1000 - cost: 0.083, kl:                 0.139
# - epoch 686/1000 - cost: 0.145, kl:                 0.139
# - epoch 687/1000 - cost: 0.244, kl:                 0.139
# - epoch 688/1000 - cost: 0.168, kl:                 0.140
# - epoch 689/1000 - cost: 0.157, kl:                 0.140
# - epoch 690/1000 - cost: 0.134, kl:                 0.141
# - epoch 691/1000 - cost: 0.093, kl:                 0.141
# - epoch 692/1000 - cost: 0.233, kl:                 0.142
# - epoch 693/1000 - cost: 0.072, kl:                 0.142
# - epoch 694/1000 - cost: 0.144, kl:                 0.143
# - epoch 695/1000 - cost: 0.165, kl:                 0.143
# - epoch 696/1000 - cost: 0.150, kl:                 0.143
# - epoch 697/1000 - cost: 0.130, kl:                 0.143
# - epoch 698/1000 - cost: 0.140, kl:                 0.143
# - epoch 699/1000 - cost: 0.072, kl:                 0.143
# - epoch 700/1000 - cost: 0.090, kl:                 0.143
# - epoch 701/1000 - cost: 0.140, kl:                 0.142
# - epoch 702/1000 - cost: 0.169, kl:                 0.143
# - epoch 703/1000 - cost: 0.125, kl:                 0.142
# - epoch 704/1000 - cost: 0.114, kl:                 0.143
# - epoch 705/1000 - cost: 0.120, kl:                 0.143
# - epoch 706/1000 - cost: 0.100, kl:                 0.143
# - epoch 707/1000 - cost: 0.074, kl:                 0.144
# - epoch 708/1000 - cost: 0.159, kl:                 0.144
# - epoch 709/1000 - cost: 0.169, kl:                 0.144
# - epoch 710/1000 - cost: 0.139, kl:                 0.143
# - epoch 711/1000 - cost: 0.126, kl:                 0.143
# - epoch 712/1000 - cost: 0.201, kl:                 0.143
# - epoch 713/1000 - cost: 0.091, kl:                 0.143
# - epoch 714/1000 - cost: 0.125, kl:                 0.142
# - epoch 715/1000 - cost: 0.087, kl:                 0.142
# - epoch 716/1000 - cost: 0.088, kl:                 0.142
# - epoch 717/1000 - cost: 0.093, kl:                 0.142
# - epoch 718/1000 - cost: 0.084, kl:                 0.142
# - epoch 719/1000 - cost: 0.089, kl:                 0.141
# - epoch 720/1000 - cost: 0.188, kl:                 0.141
# - epoch 721/1000 - cost: 0.196, kl:                 0.141
# - epoch 722/1000 - cost: 0.071, kl:                 0.141
# - epoch 723/1000 - cost: 0.136, kl:                 0.141
# - epoch 724/1000 - cost: 0.162, kl:                 0.141
# - epoch 725/1000 - cost: 0.201, kl:                 0.141
# - epoch 726/1000 - cost: 0.112, kl:                 0.142
# - epoch 727/1000 - cost: 0.105, kl:                 0.142
# - epoch 728/1000 - cost: 0.142, kl:                 0.143
# - epoch 729/1000 - cost: 0.096, kl:                 0.144
# - epoch 730/1000 - cost: 0.195, kl:                 0.145
# - epoch 731/1000 - cost: 0.086, kl:                 0.145
# - epoch 732/1000 - cost: 0.160, kl:                 0.146
# - epoch 733/1000 - cost: 0.065, kl:                 0.146
# - epoch 734/1000 - cost: 0.090, kl:                 0.146
# - epoch 735/1000 - cost: 0.111, kl:                 0.145
# - epoch 736/1000 - cost: 0.079, kl:                 0.145
# - epoch 737/1000 - cost: 0.095, kl:                 0.145
# - epoch 738/1000 - cost: 0.138, kl:                 0.145
# - epoch 739/1000 - cost: 0.111, kl:                 0.145
# - epoch 740/1000 - cost: 0.104, kl:                 0.145
# - epoch 741/1000 - cost: 0.159, kl:                 0.145
# - epoch 742/1000 - cost: 0.120, kl:                 0.145
# - epoch 743/1000 - cost: 0.078, kl:                 0.145
# - epoch 744/1000 - cost: 0.115, kl:                 0.144
# - epoch 745/1000 - cost: 0.119, kl:                 0.144
# - epoch 746/1000 - cost: 0.175, kl:                 0.144
# - epoch 747/1000 - cost: 0.088, kl:                 0.144
# - epoch 748/1000 - cost: 0.144, kl:                 0.144
# - epoch 749/1000 - cost: 0.091, kl:                 0.144
# - epoch 750/1000 - cost: 0.117, kl:                 0.144
# - epoch 751/1000 - cost: 0.085, kl:                 0.144
# - epoch 752/1000 - cost: 0.084, kl:                 0.144
# - epoch 753/1000 - cost: 0.148, kl:                 0.144
# - epoch 754/1000 - cost: 0.070, kl:                 0.144
# - epoch 755/1000 - cost: 0.098, kl:                 0.144
# - epoch 756/1000 - cost: 0.132, kl:                 0.144
# - epoch 757/1000 - cost: 0.114, kl:                 0.144
# - epoch 758/1000 - cost: 0.100, kl:                 0.144
# - epoch 759/1000 - cost: 0.197, kl:                 0.144
# - epoch 760/1000 - cost: 0.142, kl:                 0.144
# - epoch 761/1000 - cost: 0.130, kl:                 0.144
# - epoch 762/1000 - cost: 0.091, kl:                 0.144
# - epoch 763/1000 - cost: 0.082, kl:                 0.144
# - epoch 764/1000 - cost: 0.114, kl:                 0.144
# - epoch 765/1000 - cost: 0.126, kl:                 0.144
# - epoch 766/1000 - cost: 0.096, kl:                 0.144
# - epoch 767/1000 - cost: 0.104, kl:                 0.144
# - epoch 768/1000 - cost: 0.177, kl:                 0.144
# - epoch 769/1000 - cost: 0.082, kl:                 0.144
# - epoch 770/1000 - cost: 0.077, kl:                 0.144
# - epoch 771/1000 - cost: 0.110, kl:                 0.144
# - epoch 772/1000 - cost: 0.115, kl:                 0.145
# - epoch 773/1000 - cost: 0.134, kl:                 0.145
# - epoch 774/1000 - cost: 0.126, kl:                 0.145
# - epoch 775/1000 - cost: 0.112, kl:                 0.145
# - epoch 776/1000 - cost: 0.109, kl:                 0.145
# - epoch 777/1000 - cost: 0.103, kl:                 0.146
# - epoch 778/1000 - cost: 0.090, kl:                 0.147
# - epoch 779/1000 - cost: 0.122, kl:                 0.147
# - epoch 780/1000 - cost: 0.101, kl:                 0.147
# - epoch 781/1000 - cost: 0.175, kl:                 0.148
# - epoch 782/1000 - cost: 0.161, kl:                 0.148
# - epoch 783/1000 - cost: 0.185, kl:                 0.149
# - epoch 784/1000 - cost: 0.112, kl:                 0.150
# - epoch 785/1000 - cost: 0.135, kl:                 0.151
# - epoch 786/1000 - cost: 0.088, kl:                 0.152
# - epoch 787/1000 - cost: 0.086, kl:                 0.152
# - epoch 788/1000 - cost: 0.115, kl:                 0.152
# - epoch 789/1000 - cost: 0.108, kl:                 0.152
# - epoch 790/1000 - cost: 0.096, kl:                 0.151
# - epoch 791/1000 - cost: 0.076, kl:                 0.150
# - epoch 792/1000 - cost: 0.299, kl:                 0.150
# - epoch 793/1000 - cost: 0.112, kl:                 0.149
# - epoch 794/1000 - cost: 0.141, kl:                 0.149
# - epoch 795/1000 - cost: 0.147, kl:                 0.149
# - epoch 796/1000 - cost: 0.077, kl:                 0.149
# - epoch 797/1000 - cost: 0.085, kl:                 0.149
# - epoch 798/1000 - cost: 0.170, kl:                 0.150
# - epoch 799/1000 - cost: 0.078, kl:                 0.149
# - epoch 800/1000 - cost: 0.133, kl:                 0.149
# - epoch 801/1000 - cost: 0.111, kl:                 0.149
# - epoch 802/1000 - cost: 0.117, kl:                 0.149
# - epoch 803/1000 - cost: 0.124, kl:                 0.148
# - epoch 804/1000 - cost: 0.176, kl:                 0.148
# - epoch 805/1000 - cost: 0.167, kl:                 0.148
# - epoch 806/1000 - cost: 0.127, kl:                 0.148
# - epoch 807/1000 - cost: 0.245, kl:                 0.149
# - epoch 808/1000 - cost: 0.111, kl:                 0.149
# - epoch 809/1000 - cost: 0.098, kl:                 0.150
# - epoch 810/1000 - cost: 0.101, kl:                 0.151
# - epoch 811/1000 - cost: 0.079, kl:                 0.151
# - epoch 812/1000 - cost: 0.126, kl:                 0.151
# - epoch 813/1000 - cost: 0.208, kl:                 0.151
# - epoch 814/1000 - cost: 0.119, kl:                 0.151
# - epoch 815/1000 - cost: 0.170, kl:                 0.151
# - epoch 816/1000 - cost: 0.156, kl:                 0.152
# - epoch 817/1000 - cost: 0.087, kl:                 0.152
# - epoch 818/1000 - cost: 0.114, kl:                 0.153
# - epoch 819/1000 - cost: 0.107, kl:                 0.153
# - epoch 820/1000 - cost: 0.099, kl:                 0.153
# - epoch 821/1000 - cost: 0.086, kl:                 0.153
# - epoch 822/1000 - cost: 0.110, kl:                 0.153
# - epoch 823/1000 - cost: 0.142, kl:                 0.153
# - epoch 824/1000 - cost: 0.079, kl:                 0.153
# - epoch 825/1000 - cost: 0.119, kl:                 0.153
# - epoch 826/1000 - cost: 0.110, kl:                 0.154
# - epoch 827/1000 - cost: 0.085, kl:                 0.154
# - epoch 828/1000 - cost: 0.113, kl:                 0.154
# - epoch 829/1000 - cost: 0.159, kl:                 0.154
# - epoch 830/1000 - cost: 0.120, kl:                 0.154
# - epoch 831/1000 - cost: 0.162, kl:                 0.154
# - epoch 832/1000 - cost: 0.080, kl:                 0.154
# - epoch 833/1000 - cost: 0.107, kl:                 0.154
# - epoch 834/1000 - cost: 0.065, kl:                 0.154
# - epoch 835/1000 - cost: 0.082, kl:                 0.154
# - epoch 836/1000 - cost: 0.142, kl:                 0.154
# - epoch 837/1000 - cost: 0.101, kl:                 0.153
# - epoch 838/1000 - cost: 0.124, kl:                 0.153
# - epoch 839/1000 - cost: 0.103, kl:                 0.153
# - epoch 840/1000 - cost: 0.236, kl:                 0.153
# - epoch 841/1000 - cost: 0.110, kl:                 0.153
# - epoch 842/1000 - cost: 0.119, kl:                 0.154
# - epoch 843/1000 - cost: 0.132, kl:                 0.154
# - epoch 844/1000 - cost: 0.163, kl:                 0.154
# - epoch 845/1000 - cost: 0.096, kl:                 0.155
# - epoch 846/1000 - cost: 0.103, kl:                 0.155
# - epoch 847/1000 - cost: 0.139, kl:                 0.155
# - epoch 848/1000 - cost: 0.104, kl:                 0.155
# - epoch 849/1000 - cost: 0.083, kl:                 0.155
# - epoch 850/1000 - cost: 0.096, kl:                 0.155
# - epoch 851/1000 - cost: 0.138, kl:                 0.155
# - epoch 852/1000 - cost: 0.101, kl:                 0.155
# - epoch 853/1000 - cost: 0.161, kl:                 0.155
# - epoch 854/1000 - cost: 0.142, kl:                 0.155
# - epoch 855/1000 - cost: 0.167, kl:                 0.155
# - epoch 856/1000 - cost: 0.114, kl:                 0.155
# - epoch 857/1000 - cost: 0.155, kl:                 0.155
# - epoch 858/1000 - cost: 0.167, kl:                 0.155
# - epoch 859/1000 - cost: 0.106, kl:                 0.156
# - epoch 860/1000 - cost: 0.070, kl:                 0.156
# - epoch 861/1000 - cost: 0.134, kl:                 0.156
# - epoch 862/1000 - cost: 0.123, kl:                 0.156
# - epoch 863/1000 - cost: 0.080, kl:                 0.156
# - epoch 864/1000 - cost: 0.109, kl:                 0.156
# - epoch 865/1000 - cost: 0.098, kl:                 0.156
# - epoch 866/1000 - cost: 0.102, kl:                 0.157
# - epoch 867/1000 - cost: 0.119, kl:                 0.157
# - epoch 868/1000 - cost: 0.157, kl:                 0.157
# - epoch 869/1000 - cost: 0.167, kl:                 0.157
# - epoch 870/1000 - cost: 0.140, kl:                 0.157
# - epoch 871/1000 - cost: 0.079, kl:                 0.157
# - epoch 872/1000 - cost: 0.105, kl:                 0.157
# - epoch 873/1000 - cost: 0.052, kl:                 0.157
# - epoch 874/1000 - cost: 0.091, kl:                 0.157
# - epoch 875/1000 - cost: 0.143, kl:                 0.157
# - epoch 876/1000 - cost: 0.131, kl:                 0.157
# - epoch 877/1000 - cost: 0.156, kl:                 0.158
# - epoch 878/1000 - cost: 0.108, kl:                 0.158
# - epoch 879/1000 - cost: 0.119, kl:                 0.159
# - epoch 880/1000 - cost: 0.089, kl:                 0.159
# - epoch 881/1000 - cost: 0.105, kl:                 0.160
# - epoch 882/1000 - cost: 0.137, kl:                 0.160
# - epoch 883/1000 - cost: 0.171, kl:                 0.160
# - epoch 884/1000 - cost: 0.121, kl:                 0.160
# - epoch 885/1000 - cost: 0.143, kl:                 0.160
# - epoch 886/1000 - cost: 0.145, kl:                 0.160
# - epoch 887/1000 - cost: 0.099, kl:                 0.160
# - epoch 888/1000 - cost: 0.139, kl:                 0.161
# - epoch 889/1000 - cost: 0.088, kl:                 0.161
# - epoch 890/1000 - cost: 0.201, kl:                 0.160
# - epoch 891/1000 - cost: 0.097, kl:                 0.160
# - epoch 892/1000 - cost: 0.104, kl:                 0.160
# - epoch 893/1000 - cost: 0.125, kl:                 0.160
# - epoch 894/1000 - cost: 0.174, kl:                 0.159
# - epoch 895/1000 - cost: 0.095, kl:                 0.160
# - epoch 896/1000 - cost: 0.144, kl:                 0.160
# - epoch 897/1000 - cost: 0.111, kl:                 0.161
# - epoch 898/1000 - cost: 0.185, kl:                 0.161
# - epoch 899/1000 - cost: 0.121, kl:                 0.161
# - epoch 900/1000 - cost: 0.090, kl:                 0.162
# - epoch 901/1000 - cost: 0.288, kl:                 0.162
# - epoch 902/1000 - cost: 0.185, kl:                 0.163
# - epoch 903/1000 - cost: 0.227, kl:                 0.165
# - epoch 904/1000 - cost: 0.133, kl:                 0.166
# - epoch 905/1000 - cost: 0.099, kl:                 0.167
# - epoch 906/1000 - cost: 0.134, kl:                 0.167
# - epoch 907/1000 - cost: 0.104, kl:                 0.166
# - epoch 908/1000 - cost: 0.093, kl:                 0.166
# - epoch 909/1000 - cost: 0.148, kl:                 0.165
# - epoch 910/1000 - cost: 0.078, kl:                 0.164
# - epoch 911/1000 - cost: 0.083, kl:                 0.163
# - epoch 912/1000 - cost: 0.071, kl:                 0.163
# - epoch 913/1000 - cost: 0.134, kl:                 0.162
# - epoch 914/1000 - cost: 0.150, kl:                 0.161
# - epoch 915/1000 - cost: 0.196, kl:                 0.161
# - epoch 916/1000 - cost: 0.198, kl:                 0.162
# - epoch 917/1000 - cost: 0.153, kl:                 0.162
# - epoch 918/1000 - cost: 0.105, kl:                 0.163
# - epoch 919/1000 - cost: 0.103, kl:                 0.165
# - epoch 920/1000 - cost: 0.134, kl:                 0.165
# - epoch 921/1000 - cost: 0.125, kl:                 0.165
# - epoch 922/1000 - cost: 0.130, kl:                 0.165
# - epoch 923/1000 - cost: 0.110, kl:                 0.165
# - epoch 924/1000 - cost: 0.157, kl:                 0.165
# - epoch 925/1000 - cost: 0.080, kl:                 0.164
# - epoch 926/1000 - cost: 0.119, kl:                 0.164
# - epoch 927/1000 - cost: 0.129, kl:                 0.164
# - epoch 928/1000 - cost: 0.075, kl:                 0.164
# - epoch 929/1000 - cost: 0.124, kl:                 0.164
# - epoch 930/1000 - cost: 0.143, kl:                 0.164
# - epoch 931/1000 - cost: 0.100, kl:                 0.165
# - epoch 932/1000 - cost: 0.172, kl:                 0.165
# - epoch 933/1000 - cost: 0.152, kl:                 0.166
# - epoch 934/1000 - cost: 0.126, kl:                 0.166
# - epoch 935/1000 - cost: 0.226, kl:                 0.166
# - epoch 936/1000 - cost: 0.119, kl:                 0.167
# - epoch 937/1000 - cost: 0.138, kl:                 0.167
# - epoch 938/1000 - cost: 0.088, kl:                 0.168
# - epoch 939/1000 - cost: 0.117, kl:                 0.167
# - epoch 940/1000 - cost: 0.086, kl:                 0.167
# - epoch 941/1000 - cost: 0.124, kl:                 0.166
# - epoch 942/1000 - cost: 0.156, kl:                 0.166
# - epoch 943/1000 - cost: 0.235, kl:                 0.166
# - epoch 944/1000 - cost: 0.142, kl:                 0.166
# - epoch 945/1000 - cost: 0.151, kl:                 0.167
# - epoch 946/1000 - cost: 0.100, kl:                 0.167
# - epoch 947/1000 - cost: 0.110, kl:                 0.168
# - epoch 948/1000 - cost: 0.127, kl:                 0.168
# - epoch 949/1000 - cost: 0.149, kl:                 0.168
# - epoch 950/1000 - cost: 0.122, kl:                 0.168
# - epoch 951/1000 - cost: 0.176, kl:                 0.168
# - epoch 952/1000 - cost: 0.098, kl:                 0.168
# - epoch 953/1000 - cost: 0.059, kl:                 0.168
# - epoch 954/1000 - cost: 0.125, kl:                 0.169
# - epoch 955/1000 - cost: 0.087, kl:                 0.168
# - epoch 956/1000 - cost: 0.088, kl:                 0.168
# - epoch 957/1000 - cost: 0.082, kl:                 0.168
# - epoch 958/1000 - cost: 0.146, kl:                 0.168
# - epoch 959/1000 - cost: 0.164, kl:                 0.168
# - epoch 960/1000 - cost: 0.104, kl:                 0.168
# - epoch 961/1000 - cost: 0.098, kl:                 0.167
# - epoch 962/1000 - cost: 0.119, kl:                 0.167
# - epoch 963/1000 - cost: 0.086, kl:                 0.167
# - epoch 964/1000 - cost: 0.102, kl:                 0.167
# - epoch 965/1000 - cost: 0.067, kl:                 0.167
# - epoch 966/1000 - cost: 0.081, kl:                 0.167
# - epoch 967/1000 - cost: 0.122, kl:                 0.167
# - epoch 968/1000 - cost: 0.096, kl:                 0.167
# - epoch 969/1000 - cost: 0.093, kl:                 0.167
# - epoch 970/1000 - cost: 0.116, kl:                 0.167
# - epoch 971/1000 - cost: 0.151, kl:                 0.166
# - epoch 972/1000 - cost: 0.103, kl:                 0.166
# - epoch 973/1000 - cost: 0.168, kl:                 0.167
# - epoch 974/1000 - cost: 0.067, kl:                 0.167
# - epoch 975/1000 - cost: 0.111, kl:                 0.167
# - epoch 976/1000 - cost: 0.093, kl:                 0.168
# - epoch 977/1000 - cost: 0.113, kl:                 0.168
# - epoch 978/1000 - cost: 0.145, kl:                 0.169
# - epoch 979/1000 - cost: 0.103, kl:                 0.170
# - epoch 980/1000 - cost: 0.123, kl:                 0.170
# - epoch 981/1000 - cost: 0.080, kl:                 0.171
# - epoch 982/1000 - cost: 0.109, kl:                 0.171
# - epoch 983/1000 - cost: 0.190, kl:                 0.172
# - epoch 984/1000 - cost: 0.104, kl:                 0.171
# - epoch 985/1000 - cost: 0.097, kl:                 0.172
# - epoch 986/1000 - cost: 0.148, kl:                 0.172
# - epoch 987/1000 - cost: 0.121, kl:                 0.171
# - epoch 988/1000 - cost: 0.125, kl:                 0.172
# - epoch 989/1000 - cost: 0.089, kl:                 0.171
# - epoch 990/1000 - cost: 0.116, kl:                 0.171
# - epoch 991/1000 - cost: 0.113, kl:                 0.170
# - epoch 992/1000 - cost: 0.217, kl:                 0.170
# - epoch 993/1000 - cost: 0.087, kl:                 0.169
# - epoch 994/1000 - cost: 0.142, kl:                 0.169
# - epoch 995/1000 - cost: 0.083, kl:                 0.168
# - epoch 996/1000 - cost: 0.171, kl:                 0.169
# - epoch 997/1000 - cost: 0.184, kl:                 0.168
# - epoch 998/1000 - cost: 0.138, kl:                 0.169
# - epoch 999/1000 - cost: 0.141, kl:                 0.169
# - epoch 1000/1000 - cost: 0.236, kl:                 0.169
# - this took 273.88 seconds

# %%
mean_pred_results, std_pred_results = model.test_model()
# Out:
# Testing the model...
# - cost: 0.090
# - this took 10.55 seconds

# %%
for i in range(0, 200, 10):
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(111)
    ax.plot(model.wavelength, mean_pred_results[i, :], label="Predicted")
    ax.fill_between(model.wavelength, mean_pred_results[i, :] - std_pred_results[i, :], mean_pred_results[i, :] + std_pred_results[i, :], alpha=0.3, label="1$\\sigma$")
    ax.plot(model.wavelength, model.y_test[i, :], label=f"True, params = {model.X_test[i]}")

    ax.set_xscale("log")
    ax.set_xlabel("Wavelength / $\\mu$m")
    ax.set_ylabel("Sersic Index")
    ax.legend()
    fig.tight_layout()
    plt.show()
    plt.close()

# %%
# Generate some random parameters for model
# rng = np.random.default_rng(seed=30)
# artificial_parameters = torch.empty(10, 3, dtype=torch.float32)

# for i in range(10):
#     log_mstar = rng.uniform(9.5, 11.5)
#     log_mdust = rng.uniform(5.5, 9.5)

#     while log_mdust - log_mstar < -4:
#         log_mdust = rng.uniform(5.5, 9.5)

#     log_mdust_over_mstar = log_mdust - log_mstar

#     theta = rng.uniform(0, 1)

#     # add to artificial_parameters matrix as a row
#     parameters_row = torch.tensor([log_mstar, log_mdust_over_mstar, theta], dtype=torch.float32).reshape(1, 3)
#     artificial_parameters[i] = parameters_row

star_mass = torch.linspace(9.5, 11.5, 20)
dust_mass = torch.linspace(5.5, 5.5, 20)
theta = torch.linspace(90, 90, 20)
x_pred = model.create_predict_tensor(star_mass, dust_mass, theta)
print(x_pred.shape)
mean_pred_results, std_pred_results = model.predict(x_pred)


# df = model.df
# x_test = model.X_test

# print(artificial_parameters.shape)
# Out:
# torch.Size([20, 3])

# %%
#plotter.plot_single(150, "grey", "salmon")
#plotter.plot_group_same(100, 120, "grey", "salmon")
plotter.plot_same_ax(1,20,5,'cool')
#plotter.save_figure("test.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 #plotter.plot_single(150, "grey", "salmon")
#       2 #plotter.plot_group_same(100, 120, "grey", "salmon")
# ----> 3 plotter.plot_same_ax(1,20,5,'cool')
#       4 #plotter.save_figure("test.png")
#
# NameError: name 'plotter' is not defined

# %%
# artificial_predictions_mean, artificial_parameters_std = model.predict(artificial_parameters)
# for i in range(0, 10, 1):
#     fig = plt.figure(figsize=(10, 5))
#     ax = fig.add_subplot(111)
#     ax.plot(model.wavelength, artificial_predictions_mean[i, :], label=f"Predicted, params = {artificial_parameters[i]}")
#     ax.fill_between(model.wavelength, artificial_predictions_mean[i, :] - artificial_parameters_std[i, :], artificial_predictions_mean[i, :] + artificial_parameters_std[i, :], alpha=0.3, label="1$\\sigma$")
#     # ax.plot(model.wavelength, model.y_test[i, :], label=f"True, params = {model.X_test[i]}")
#     ax.set_xscale("log")
#     ax.set_xlabel("Wavelength / $\\mu$m")
#     ax.set_ylabel("Sersic Index")
#     ax.legend()
#     fig.tight_layout()
#     plt.show()
#     plt.close()

# %%
input_mean = model.input_mean
input_std = model.input_std
output_mean = model.output_mean
output_std = model.output_std
