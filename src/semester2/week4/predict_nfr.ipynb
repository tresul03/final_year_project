# %% [markdown]
# # Corrections to Last Week's Notebook
# This notebook'll do things a little differently. I made quite a few mistakes in the last one; I'll address them all.
#
# To begin, I was normalising my output arrays alone, and not my inputs, which may be one of the reasons why the model's accuracy suffered.
#
# Further, I was normalising my output arrays with respect to the inclination parameter; as in, I normalised each sub-run of a SKIRT output file individually. What I should have done was generate the entire dataset, and *then* normalise it. Dimensionally, for each output type ($n, f$, or $r$), I'd normalise 1,000 arrays at a time, instead of 1.
#
# Secondly, I'm going to use separate models to predict each output array, as opposed to using one model to predict all three simultaneously. The reason for this is that in the compact model, since the backwarded cost is the sum of the costs of all three outputs, the cost of one output affects the cost of another, independent output, which is sub-optimal. We need costs to be independent of each other, since their outputs are independent.
#
# I'm going to use logarithmic scales to display my output arrays. I can't remember the reasoning behind this, but I'll do it anyway.
#
# Since I'm using separate models for all three outputs, the question of whether or not normalisation is necessary remains. I won't implement it in the library that stores the model.
#
# From here onwards, I'm no longer going to define the model every time I make a new notebook; I'll just have a separate python script that stores the model class for me: makes debugging a *lot* easier.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from plotter import Plotter
from radiative_transfer_bnn import RadiativeTransferBNN

# %%
model = RadiativeTransferBNN(1000, 0.3, 0.01, "flux")
# model.preprocess_data()
model.train_model(1000, 200)
# Out:
# c:\Users\resul\OneDrive\Physics\Final Year\PH30036\project_script\src\semester2\week4\radiative_transfer_bnn.py:299: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([
# Training the model...
# - epoch 1/1000 - cost: 9.121, kl:                 0.053
# - epoch 2/1000 - cost: 6.010, kl:                 0.093
# - epoch 3/1000 - cost: 5.357, kl:                 0.129
# - epoch 4/1000 - cost: 3.275, kl:                 0.159
# - epoch 5/1000 - cost: 2.052, kl:                 0.182
# - epoch 6/1000 - cost: 1.514, kl:                 0.200
# - epoch 7/1000 - cost: 0.916, kl:                 0.213
# - epoch 8/1000 - cost: 1.110, kl:                 0.222
# - epoch 9/1000 - cost: 0.798, kl:                 0.229
# - epoch 10/1000 - cost: 0.868, kl:                 0.233
# - epoch 11/1000 - cost: 0.530, kl:                 0.236
# - epoch 12/1000 - cost: 0.546, kl:                 0.238
# - epoch 13/1000 - cost: 0.518, kl:                 0.240
# - epoch 14/1000 - cost: 0.472, kl:                 0.241
# - epoch 15/1000 - cost: 0.272, kl:                 0.242
# - epoch 16/1000 - cost: 0.460, kl:                 0.242
# - epoch 17/1000 - cost: 0.405, kl:                 0.243
# - epoch 18/1000 - cost: 0.437, kl:                 0.243
# - epoch 19/1000 - cost: 0.337, kl:                 0.243
# - epoch 20/1000 - cost: 0.368, kl:                 0.243
# - epoch 21/1000 - cost: 0.437, kl:                 0.243
# - epoch 22/1000 - cost: 0.355, kl:                 0.244
# - epoch 23/1000 - cost: 0.376, kl:                 0.244
# - epoch 24/1000 - cost: 0.366, kl:                 0.244
# - epoch 25/1000 - cost: 0.271, kl:                 0.244
# - epoch 26/1000 - cost: 0.360, kl:                 0.244
# - epoch 27/1000 - cost: 0.343, kl:                 0.244
# - epoch 28/1000 - cost: 0.250, kl:                 0.244
# - epoch 29/1000 - cost: 0.223, kl:                 0.244
# - epoch 30/1000 - cost: 0.315, kl:                 0.244
# - epoch 31/1000 - cost: 0.373, kl:                 0.244
# - epoch 32/1000 - cost: 0.288, kl:                 0.244
# - epoch 33/1000 - cost: 0.238, kl:                 0.244
# - epoch 34/1000 - cost: 0.303, kl:                 0.244
# - epoch 35/1000 - cost: 0.283, kl:                 0.244
# - epoch 36/1000 - cost: 0.370, kl:                 0.244
# - epoch 37/1000 - cost: 0.225, kl:                 0.244
# - epoch 38/1000 - cost: 0.269, kl:                 0.244
# - epoch 39/1000 - cost: 0.350, kl:                 0.244
# - epoch 40/1000 - cost: 0.291, kl:                 0.244
# - epoch 41/1000 - cost: 0.575, kl:                 0.244
# - epoch 42/1000 - cost: 0.237, kl:                 0.244
# - epoch 43/1000 - cost: 0.214, kl:                 0.244
# - epoch 44/1000 - cost: 0.278, kl:                 0.244
# - epoch 45/1000 - cost: 0.240, kl:                 0.244
# - epoch 46/1000 - cost: 0.311, kl:                 0.244
# - epoch 47/1000 - cost: 0.355, kl:                 0.244
# - epoch 48/1000 - cost: 0.169, kl:                 0.244
# - epoch 49/1000 - cost: 0.329, kl:                 0.244
# - epoch 50/1000 - cost: 0.319, kl:                 0.244
# - epoch 51/1000 - cost: 0.347, kl:                 0.244
# - epoch 52/1000 - cost: 0.282, kl:                 0.244
# - epoch 53/1000 - cost: 0.218, kl:                 0.244
# - epoch 54/1000 - cost: 0.222, kl:                 0.244
# - epoch 55/1000 - cost: 0.281, kl:                 0.244
# - epoch 56/1000 - cost: 0.251, kl:                 0.245
# - epoch 57/1000 - cost: 0.328, kl:                 0.244
# - epoch 58/1000 - cost: 0.234, kl:                 0.244
# - epoch 59/1000 - cost: 0.214, kl:                 0.244
# - epoch 60/1000 - cost: 0.296, kl:                 0.244
# - epoch 61/1000 - cost: 0.248, kl:                 0.244
# - epoch 62/1000 - cost: 0.276, kl:                 0.244
# - epoch 63/1000 - cost: 0.239, kl:                 0.244
# - epoch 64/1000 - cost: 0.179, kl:                 0.244
# - epoch 65/1000 - cost: 0.275, kl:                 0.244
# - epoch 66/1000 - cost: 0.261, kl:                 0.243
# - epoch 67/1000 - cost: 0.160, kl:                 0.243
# - epoch 68/1000 - cost: 0.298, kl:                 0.243
# - epoch 69/1000 - cost: 0.329, kl:                 0.243
# - epoch 70/1000 - cost: 0.243, kl:                 0.243
# - epoch 71/1000 - cost: 0.286, kl:                 0.243
# - epoch 72/1000 - cost: 0.335, kl:                 0.243
# - epoch 73/1000 - cost: 0.227, kl:                 0.243
# - epoch 74/1000 - cost: 0.247, kl:                 0.243
# - epoch 75/1000 - cost: 0.315, kl:                 0.243
# - epoch 76/1000 - cost: 0.218, kl:                 0.243
# - epoch 77/1000 - cost: 0.239, kl:                 0.243
# - epoch 78/1000 - cost: 0.147, kl:                 0.243
# - epoch 79/1000 - cost: 0.232, kl:                 0.243
# - epoch 80/1000 - cost: 0.215, kl:                 0.243
# - epoch 81/1000 - cost: 0.253, kl:                 0.242
# - epoch 82/1000 - cost: 0.180, kl:                 0.242
# - epoch 83/1000 - cost: 0.190, kl:                 0.242
# - epoch 84/1000 - cost: 0.238, kl:                 0.242
# - epoch 85/1000 - cost: 0.264, kl:                 0.242
# - epoch 86/1000 - cost: 0.214, kl:                 0.241
# - epoch 87/1000 - cost: 0.223, kl:                 0.241
# - epoch 88/1000 - cost: 0.238, kl:                 0.241
# - epoch 89/1000 - cost: 0.284, kl:                 0.241
# - epoch 90/1000 - cost: 0.204, kl:                 0.241
# - epoch 91/1000 - cost: 0.264, kl:                 0.241
# - epoch 92/1000 - cost: 0.213, kl:                 0.241
# - epoch 93/1000 - cost: 0.248, kl:                 0.241
# - epoch 94/1000 - cost: 0.201, kl:                 0.240
# - epoch 95/1000 - cost: 0.220, kl:                 0.240
# - epoch 96/1000 - cost: 0.182, kl:                 0.240
# - epoch 97/1000 - cost: 0.211, kl:                 0.240
# - epoch 98/1000 - cost: 0.255, kl:                 0.240
# - epoch 99/1000 - cost: 0.187, kl:                 0.240
# - epoch 100/1000 - cost: 0.232, kl:                 0.239
# - epoch 101/1000 - cost: 0.285, kl:                 0.239
# - epoch 102/1000 - cost: 0.204, kl:                 0.239
# - epoch 103/1000 - cost: 0.325, kl:                 0.239
# - epoch 104/1000 - cost: 0.222, kl:                 0.239
# - epoch 105/1000 - cost: 0.178, kl:                 0.238
# - epoch 106/1000 - cost: 0.216, kl:                 0.238
# - epoch 107/1000 - cost: 0.215, kl:                 0.238
# - epoch 108/1000 - cost: 0.231, kl:                 0.238
# - epoch 109/1000 - cost: 0.215, kl:                 0.238
# - epoch 110/1000 - cost: 0.159, kl:                 0.237
# - epoch 111/1000 - cost: 0.206, kl:                 0.237
# - epoch 112/1000 - cost: 0.264, kl:                 0.237
# - epoch 113/1000 - cost: 0.256, kl:                 0.237
# - epoch 114/1000 - cost: 0.192, kl:                 0.237
# - epoch 115/1000 - cost: 0.236, kl:                 0.236
# - epoch 116/1000 - cost: 0.248, kl:                 0.236
# - epoch 117/1000 - cost: 0.248, kl:                 0.236
# - epoch 118/1000 - cost: 0.287, kl:                 0.236
# - epoch 119/1000 - cost: 0.267, kl:                 0.236
# - epoch 120/1000 - cost: 0.302, kl:                 0.235
# - epoch 121/1000 - cost: 0.222, kl:                 0.235
# - epoch 122/1000 - cost: 0.261, kl:                 0.235
# - epoch 123/1000 - cost: 0.222, kl:                 0.235
# - epoch 124/1000 - cost: 0.243, kl:                 0.235
# - epoch 125/1000 - cost: 0.219, kl:                 0.234
# - epoch 126/1000 - cost: 0.225, kl:                 0.234
# - epoch 127/1000 - cost: 0.275, kl:                 0.234
# - epoch 128/1000 - cost: 0.169, kl:                 0.234
# - epoch 129/1000 - cost: 0.149, kl:                 0.234
# - epoch 130/1000 - cost: 0.211, kl:                 0.233
# - epoch 131/1000 - cost: 0.320, kl:                 0.233
# - epoch 132/1000 - cost: 0.322, kl:                 0.233
# - epoch 133/1000 - cost: 0.185, kl:                 0.233
# - epoch 134/1000 - cost: 0.298, kl:                 0.233
# - epoch 135/1000 - cost: 0.245, kl:                 0.232
# - epoch 136/1000 - cost: 0.157, kl:                 0.232
# - epoch 137/1000 - cost: 0.346, kl:                 0.232
# - epoch 138/1000 - cost: 0.339, kl:                 0.232
# - epoch 139/1000 - cost: 0.218, kl:                 0.232
# - epoch 140/1000 - cost: 0.201, kl:                 0.232
# - epoch 141/1000 - cost: 0.292, kl:                 0.231
# - epoch 142/1000 - cost: 0.270, kl:                 0.231
# - epoch 143/1000 - cost: 0.227, kl:                 0.231
# - epoch 144/1000 - cost: 0.218, kl:                 0.231
# - epoch 145/1000 - cost: 0.203, kl:                 0.230
# - epoch 146/1000 - cost: 0.187, kl:                 0.230
# - epoch 147/1000 - cost: 0.309, kl:                 0.230
# - epoch 148/1000 - cost: 0.257, kl:                 0.229
# - epoch 149/1000 - cost: 0.246, kl:                 0.229
# - epoch 150/1000 - cost: 0.270, kl:                 0.229
# - epoch 151/1000 - cost: 0.194, kl:                 0.229
# - epoch 152/1000 - cost: 0.171, kl:                 0.229
# - epoch 153/1000 - cost: 0.291, kl:                 0.229
# - epoch 154/1000 - cost: 0.160, kl:                 0.229
# - epoch 155/1000 - cost: 0.214, kl:                 0.229
# - epoch 156/1000 - cost: 0.186, kl:                 0.229
# - epoch 157/1000 - cost: 0.221, kl:                 0.229
# - epoch 158/1000 - cost: 0.229, kl:                 0.228
# - epoch 159/1000 - cost: 0.166, kl:                 0.228
# - epoch 160/1000 - cost: 0.204, kl:                 0.228
# - epoch 161/1000 - cost: 0.288, kl:                 0.227
# - epoch 162/1000 - cost: 0.214, kl:                 0.227
# - epoch 163/1000 - cost: 0.135, kl:                 0.226
# - epoch 164/1000 - cost: 0.211, kl:                 0.226
# - epoch 165/1000 - cost: 0.176, kl:                 0.226
# - epoch 166/1000 - cost: 0.188, kl:                 0.225
# - epoch 167/1000 - cost: 0.149, kl:                 0.225
# - epoch 168/1000 - cost: 0.269, kl:                 0.225
# - epoch 169/1000 - cost: 0.227, kl:                 0.224
# - epoch 170/1000 - cost: 0.439, kl:                 0.224
# - epoch 171/1000 - cost: 0.271, kl:                 0.224
# - epoch 172/1000 - cost: 0.156, kl:                 0.224
# - epoch 173/1000 - cost: 0.210, kl:                 0.224
# - epoch 174/1000 - cost: 0.256, kl:                 0.223
# - epoch 175/1000 - cost: 0.137, kl:                 0.223
# - epoch 176/1000 - cost: 0.239, kl:                 0.223
# - epoch 177/1000 - cost: 0.225, kl:                 0.222
# - epoch 178/1000 - cost: 0.182, kl:                 0.222
# - epoch 179/1000 - cost: 0.235, kl:                 0.222
# - epoch 180/1000 - cost: 0.242, kl:                 0.221
# - epoch 181/1000 - cost: 0.237, kl:                 0.221
# - epoch 182/1000 - cost: 0.235, kl:                 0.221
# - epoch 183/1000 - cost: 0.174, kl:                 0.220
# - epoch 184/1000 - cost: 0.151, kl:                 0.220
# - epoch 185/1000 - cost: 0.211, kl:                 0.220
# - epoch 186/1000 - cost: 0.189, kl:                 0.219
# - epoch 187/1000 - cost: 0.281, kl:                 0.219
# - epoch 188/1000 - cost: 0.191, kl:                 0.219
# - epoch 189/1000 - cost: 0.195, kl:                 0.219
# - epoch 190/1000 - cost: 0.206, kl:                 0.219
# - epoch 191/1000 - cost: 0.266, kl:                 0.219
# - epoch 192/1000 - cost: 0.179, kl:                 0.218
# - epoch 193/1000 - cost: 0.331, kl:                 0.218
# - epoch 194/1000 - cost: 0.187, kl:                 0.218
# - epoch 195/1000 - cost: 0.240, kl:                 0.218
# - epoch 196/1000 - cost: 0.302, kl:                 0.218
# - epoch 197/1000 - cost: 0.244, kl:                 0.217
# - epoch 198/1000 - cost: 0.255, kl:                 0.217
# - epoch 199/1000 - cost: 0.234, kl:                 0.217
# - epoch 200/1000 - cost: 0.128, kl:                 0.216
# - epoch 201/1000 - cost: 0.139, kl:                 0.216
# - epoch 202/1000 - cost: 0.190, kl:                 0.216
# - epoch 203/1000 - cost: 0.201, kl:                 0.215
# - epoch 204/1000 - cost: 0.234, kl:                 0.215
# - epoch 205/1000 - cost: 0.283, kl:                 0.215
# - epoch 206/1000 - cost: 0.192, kl:                 0.214
# - epoch 207/1000 - cost: 0.171, kl:                 0.214
# - epoch 208/1000 - cost: 0.108, kl:                 0.214
# - epoch 209/1000 - cost: 0.152, kl:                 0.214
# - epoch 210/1000 - cost: 0.190, kl:                 0.213
# - epoch 211/1000 - cost: 0.189, kl:                 0.213
# - epoch 212/1000 - cost: 0.232, kl:                 0.212
# - epoch 213/1000 - cost: 0.150, kl:                 0.212
# - epoch 214/1000 - cost: 0.327, kl:                 0.212
# - epoch 215/1000 - cost: 0.212, kl:                 0.212
# - epoch 216/1000 - cost: 0.179, kl:                 0.211
# - epoch 217/1000 - cost: 0.212, kl:                 0.211
# - epoch 218/1000 - cost: 0.160, kl:                 0.211
# - epoch 219/1000 - cost: 0.128, kl:                 0.210
# - epoch 220/1000 - cost: 0.245, kl:                 0.210
# - epoch 221/1000 - cost: 0.260, kl:                 0.209
# - epoch 222/1000 - cost: 0.231, kl:                 0.209
# - epoch 223/1000 - cost: 0.238, kl:                 0.209
# - epoch 224/1000 - cost: 0.205, kl:                 0.208
# - epoch 225/1000 - cost: 0.262, kl:                 0.208
# - epoch 226/1000 - cost: 0.230, kl:                 0.208
# - epoch 227/1000 - cost: 0.227, kl:                 0.208
# - epoch 228/1000 - cost: 0.114, kl:                 0.207
# - epoch 229/1000 - cost: 0.119, kl:                 0.207
# - epoch 230/1000 - cost: 0.237, kl:                 0.207
# - epoch 231/1000 - cost: 0.227, kl:                 0.206
# - epoch 232/1000 - cost: 0.242, kl:                 0.206
# - epoch 233/1000 - cost: 0.190, kl:                 0.206
# - epoch 234/1000 - cost: 0.147, kl:                 0.206
# - epoch 235/1000 - cost: 0.183, kl:                 0.205
# - epoch 236/1000 - cost: 0.320, kl:                 0.205
# - epoch 237/1000 - cost: 0.265, kl:                 0.205
# - epoch 238/1000 - cost: 0.263, kl:                 0.204
# - epoch 239/1000 - cost: 0.138, kl:                 0.204
# - epoch 240/1000 - cost: 0.254, kl:                 0.204
# - epoch 241/1000 - cost: 0.173, kl:                 0.204
# - epoch 242/1000 - cost: 0.135, kl:                 0.204
# - epoch 243/1000 - cost: 0.167, kl:                 0.204
# - epoch 244/1000 - cost: 0.118, kl:                 0.204
# - epoch 245/1000 - cost: 0.179, kl:                 0.204
# - epoch 246/1000 - cost: 0.149, kl:                 0.203
# - epoch 247/1000 - cost: 0.182, kl:                 0.203
# - epoch 248/1000 - cost: 0.134, kl:                 0.203
# - epoch 249/1000 - cost: 0.166, kl:                 0.202
# - epoch 250/1000 - cost: 0.169, kl:                 0.202
# - epoch 251/1000 - cost: 0.141, kl:                 0.202
# - epoch 252/1000 - cost: 0.210, kl:                 0.202
# - epoch 253/1000 - cost: 0.152, kl:                 0.202
# - epoch 254/1000 - cost: 0.270, kl:                 0.202
# - epoch 255/1000 - cost: 0.193, kl:                 0.202
# - epoch 256/1000 - cost: 0.157, kl:                 0.201
# - epoch 257/1000 - cost: 0.149, kl:                 0.201
# - epoch 258/1000 - cost: 0.286, kl:                 0.201
# - epoch 259/1000 - cost: 0.188, kl:                 0.201
# - epoch 260/1000 - cost: 0.197, kl:                 0.200
# - epoch 261/1000 - cost: 0.122, kl:                 0.200
# - epoch 262/1000 - cost: 0.171, kl:                 0.200
# - epoch 263/1000 - cost: 0.163, kl:                 0.199
# - epoch 264/1000 - cost: 0.222, kl:                 0.199
# - epoch 265/1000 - cost: 0.356, kl:                 0.199
# - epoch 266/1000 - cost: 0.199, kl:                 0.198
# - epoch 267/1000 - cost: 0.156, kl:                 0.198
# - epoch 268/1000 - cost: 0.281, kl:                 0.198
# - epoch 269/1000 - cost: 0.347, kl:                 0.198
# - epoch 270/1000 - cost: 0.144, kl:                 0.198
# - epoch 271/1000 - cost: 0.173, kl:                 0.198
# - epoch 272/1000 - cost: 0.202, kl:                 0.197
# - epoch 273/1000 - cost: 0.120, kl:                 0.197
# - epoch 274/1000 - cost: 0.209, kl:                 0.197
# - epoch 275/1000 - cost: 0.186, kl:                 0.196
# - epoch 276/1000 - cost: 0.133, kl:                 0.196
# - epoch 277/1000 - cost: 0.220, kl:                 0.196
# - epoch 278/1000 - cost: 0.315, kl:                 0.196
# - epoch 279/1000 - cost: 0.165, kl:                 0.196
# - epoch 280/1000 - cost: 0.256, kl:                 0.195
# - epoch 281/1000 - cost: 0.163, kl:                 0.195
# - epoch 282/1000 - cost: 0.102, kl:                 0.195
# - epoch 283/1000 - cost: 0.158, kl:                 0.195
# - epoch 284/1000 - cost: 0.199, kl:                 0.195
# - epoch 285/1000 - cost: 0.292, kl:                 0.195
# - epoch 286/1000 - cost: 0.209, kl:                 0.195
# - epoch 287/1000 - cost: 0.206, kl:                 0.195
# - epoch 288/1000 - cost: 0.118, kl:                 0.195
# - epoch 289/1000 - cost: 0.216, kl:                 0.195
# - epoch 290/1000 - cost: 0.191, kl:                 0.194
# - epoch 291/1000 - cost: 0.150, kl:                 0.194
# - epoch 292/1000 - cost: 0.173, kl:                 0.194
# - epoch 293/1000 - cost: 0.247, kl:                 0.194
# - epoch 294/1000 - cost: 0.289, kl:                 0.193
# - epoch 295/1000 - cost: 0.150, kl:                 0.193
# - epoch 296/1000 - cost: 0.161, kl:                 0.193
# - epoch 297/1000 - cost: 0.189, kl:                 0.193
# - epoch 298/1000 - cost: 0.187, kl:                 0.193
# - epoch 299/1000 - cost: 0.209, kl:                 0.193
# - epoch 300/1000 - cost: 0.264, kl:                 0.193
# - epoch 301/1000 - cost: 0.124, kl:                 0.192
# - epoch 302/1000 - cost: 0.200, kl:                 0.192
# - epoch 303/1000 - cost: 0.286, kl:                 0.192
# - epoch 304/1000 - cost: 0.140, kl:                 0.192
# - epoch 305/1000 - cost: 0.179, kl:                 0.191
# - epoch 306/1000 - cost: 0.225, kl:                 0.191
# - epoch 307/1000 - cost: 0.203, kl:                 0.191
# - epoch 308/1000 - cost: 0.142, kl:                 0.191
# - epoch 309/1000 - cost: 0.238, kl:                 0.191
# - epoch 310/1000 - cost: 0.142, kl:                 0.191
# - epoch 311/1000 - cost: 0.139, kl:                 0.191
# - epoch 312/1000 - cost: 0.160, kl:                 0.190
# - epoch 313/1000 - cost: 0.116, kl:                 0.190
# - epoch 314/1000 - cost: 0.240, kl:                 0.190
# - epoch 315/1000 - cost: 0.213, kl:                 0.190
# - epoch 316/1000 - cost: 0.188, kl:                 0.190
# - epoch 317/1000 - cost: 0.128, kl:                 0.190
# - epoch 318/1000 - cost: 0.223, kl:                 0.190
# - epoch 319/1000 - cost: 0.156, kl:                 0.189
# - epoch 320/1000 - cost: 0.142, kl:                 0.189
# - epoch 321/1000 - cost: 0.189, kl:                 0.189
# - epoch 322/1000 - cost: 0.186, kl:                 0.189
# - epoch 323/1000 - cost: 0.161, kl:                 0.189
# - epoch 324/1000 - cost: 0.262, kl:                 0.189
# - epoch 325/1000 - cost: 0.128, kl:                 0.189
# - epoch 326/1000 - cost: 0.196, kl:                 0.188
# - epoch 327/1000 - cost: 0.305, kl:                 0.188
# - epoch 328/1000 - cost: 0.124, kl:                 0.188
# - epoch 329/1000 - cost: 0.170, kl:                 0.188
# - epoch 330/1000 - cost: 0.205, kl:                 0.188
# - epoch 331/1000 - cost: 0.199, kl:                 0.188
# - epoch 332/1000 - cost: 0.189, kl:                 0.188
# - epoch 333/1000 - cost: 0.119, kl:                 0.188
# - epoch 334/1000 - cost: 0.175, kl:                 0.187
# - epoch 335/1000 - cost: 0.151, kl:                 0.187
# - epoch 336/1000 - cost: 0.153, kl:                 0.187
# - epoch 337/1000 - cost: 0.239, kl:                 0.187
# - epoch 338/1000 - cost: 0.146, kl:                 0.187
# - epoch 339/1000 - cost: 0.167, kl:                 0.187
# - epoch 340/1000 - cost: 0.123, kl:                 0.187
# - epoch 341/1000 - cost: 0.240, kl:                 0.187
# - epoch 342/1000 - cost: 0.202, kl:                 0.187
# - epoch 343/1000 - cost: 0.212, kl:                 0.188
# - epoch 344/1000 - cost: 0.204, kl:                 0.188
# - epoch 345/1000 - cost: 0.233, kl:                 0.188
# - epoch 346/1000 - cost: 0.202, kl:                 0.189
# - epoch 347/1000 - cost: 0.168, kl:                 0.189
# - epoch 348/1000 - cost: 0.104, kl:                 0.189
# - epoch 349/1000 - cost: 0.150, kl:                 0.189
# - epoch 350/1000 - cost: 0.218, kl:                 0.189
# - epoch 351/1000 - cost: 0.148, kl:                 0.188
# - epoch 352/1000 - cost: 0.261, kl:                 0.188
# - epoch 353/1000 - cost: 0.217, kl:                 0.188
# - epoch 354/1000 - cost: 0.299, kl:                 0.188
# - epoch 355/1000 - cost: 0.158, kl:                 0.188
# - epoch 356/1000 - cost: 0.166, kl:                 0.187
# - epoch 357/1000 - cost: 0.185, kl:                 0.188
# - epoch 358/1000 - cost: 0.171, kl:                 0.188
# - epoch 359/1000 - cost: 0.117, kl:                 0.188
# - epoch 360/1000 - cost: 0.231, kl:                 0.187
# - epoch 361/1000 - cost: 0.257, kl:                 0.187
# - epoch 362/1000 - cost: 0.160, kl:                 0.187
# - epoch 363/1000 - cost: 0.117, kl:                 0.187
# - epoch 364/1000 - cost: 0.147, kl:                 0.187
# - epoch 365/1000 - cost: 0.138, kl:                 0.187
# - epoch 366/1000 - cost: 0.241, kl:                 0.186
# - epoch 367/1000 - cost: 0.165, kl:                 0.186
# - epoch 368/1000 - cost: 0.200, kl:                 0.186
# - epoch 369/1000 - cost: 0.149, kl:                 0.186
# - epoch 370/1000 - cost: 0.163, kl:                 0.186
# - epoch 371/1000 - cost: 0.246, kl:                 0.186
# - epoch 372/1000 - cost: 0.170, kl:                 0.187
# - epoch 373/1000 - cost: 0.254, kl:                 0.187
# - epoch 374/1000 - cost: 0.152, kl:                 0.187
# - epoch 375/1000 - cost: 0.135, kl:                 0.188
# - epoch 376/1000 - cost: 0.145, kl:                 0.188
# - epoch 377/1000 - cost: 0.156, kl:                 0.188
# - epoch 378/1000 - cost: 0.165, kl:                 0.187
# - epoch 379/1000 - cost: 0.165, kl:                 0.187
# - epoch 380/1000 - cost: 0.154, kl:                 0.187
# - epoch 381/1000 - cost: 0.133, kl:                 0.187
# - epoch 382/1000 - cost: 0.127, kl:                 0.187
# - epoch 383/1000 - cost: 0.209, kl:                 0.187
# - epoch 384/1000 - cost: 0.183, kl:                 0.186
# - epoch 385/1000 - cost: 0.196, kl:                 0.186
# - epoch 386/1000 - cost: 0.137, kl:                 0.186
# - epoch 387/1000 - cost: 0.173, kl:                 0.186
# - epoch 388/1000 - cost: 0.162, kl:                 0.186
# - epoch 389/1000 - cost: 0.140, kl:                 0.186
# - epoch 390/1000 - cost: 0.260, kl:                 0.186
# - epoch 391/1000 - cost: 0.207, kl:                 0.186
# - epoch 392/1000 - cost: 0.140, kl:                 0.187
# - epoch 393/1000 - cost: 0.104, kl:                 0.187
# - epoch 394/1000 - cost: 0.320, kl:                 0.187
# - epoch 395/1000 - cost: 0.224, kl:                 0.187
# - epoch 396/1000 - cost: 0.079, kl:                 0.187
# - epoch 397/1000 - cost: 0.129, kl:                 0.187
# - epoch 398/1000 - cost: 0.111, kl:                 0.186
# - epoch 399/1000 - cost: 0.176, kl:                 0.186
# - epoch 400/1000 - cost: 0.191, kl:                 0.186
# - epoch 401/1000 - cost: 0.214, kl:                 0.186
# - epoch 402/1000 - cost: 0.180, kl:                 0.186
# - epoch 403/1000 - cost: 0.148, kl:                 0.186
# - epoch 404/1000 - cost: 0.167, kl:                 0.186
# - epoch 405/1000 - cost: 0.141, kl:                 0.186
# - epoch 406/1000 - cost: 0.294, kl:                 0.186
# - epoch 407/1000 - cost: 0.179, kl:                 0.186
# - epoch 408/1000 - cost: 0.129, kl:                 0.186
# - epoch 409/1000 - cost: 0.180, kl:                 0.186
# - epoch 410/1000 - cost: 0.123, kl:                 0.185
# - epoch 411/1000 - cost: 0.119, kl:                 0.185
# - epoch 412/1000 - cost: 0.209, kl:                 0.185
# - epoch 413/1000 - cost: 0.106, kl:                 0.185
# - epoch 414/1000 - cost: 0.218, kl:                 0.185
# - epoch 415/1000 - cost: 0.136, kl:                 0.185
# - epoch 416/1000 - cost: 0.247, kl:                 0.185
# - epoch 417/1000 - cost: 0.207, kl:                 0.184
# - epoch 418/1000 - cost: 0.140, kl:                 0.185
# - epoch 419/1000 - cost: 0.159, kl:                 0.185
# - epoch 420/1000 - cost: 0.164, kl:                 0.184
# - epoch 421/1000 - cost: 0.148, kl:                 0.184
# - epoch 422/1000 - cost: 0.220, kl:                 0.184
# - epoch 423/1000 - cost: 0.155, kl:                 0.184
# - epoch 424/1000 - cost: 0.102, kl:                 0.184
# - epoch 425/1000 - cost: 0.286, kl:                 0.184
# - epoch 426/1000 - cost: 0.204, kl:                 0.184
# - epoch 427/1000 - cost: 0.110, kl:                 0.185
# - epoch 428/1000 - cost: 0.259, kl:                 0.185
# - epoch 429/1000 - cost: 0.136, kl:                 0.185
# - epoch 430/1000 - cost: 0.129, kl:                 0.186
# - epoch 431/1000 - cost: 0.182, kl:                 0.186
# - epoch 432/1000 - cost: 0.142, kl:                 0.186
# - epoch 433/1000 - cost: 0.215, kl:                 0.186
# - epoch 434/1000 - cost: 0.222, kl:                 0.186
# - epoch 435/1000 - cost: 0.182, kl:                 0.186
# - epoch 436/1000 - cost: 0.161, kl:                 0.186
# - epoch 437/1000 - cost: 0.179, kl:                 0.186
# - epoch 438/1000 - cost: 0.122, kl:                 0.185
# - epoch 439/1000 - cost: 0.180, kl:                 0.185
# - epoch 440/1000 - cost: 0.197, kl:                 0.185
# - epoch 441/1000 - cost: 0.132, kl:                 0.185
# - epoch 442/1000 - cost: 0.128, kl:                 0.184
# - epoch 443/1000 - cost: 0.075, kl:                 0.184
# - epoch 444/1000 - cost: 0.122, kl:                 0.184
# - epoch 445/1000 - cost: 0.161, kl:                 0.184
# - epoch 446/1000 - cost: 0.169, kl:                 0.184
# - epoch 447/1000 - cost: 0.234, kl:                 0.183
# - epoch 448/1000 - cost: 0.137, kl:                 0.183
# - epoch 449/1000 - cost: 0.154, kl:                 0.183
# - epoch 450/1000 - cost: 0.175, kl:                 0.184
# - epoch 451/1000 - cost: 0.115, kl:                 0.184
# - epoch 452/1000 - cost: 0.239, kl:                 0.184
# - epoch 453/1000 - cost: 0.168, kl:                 0.184
# - epoch 454/1000 - cost: 0.145, kl:                 0.185
# - epoch 455/1000 - cost: 0.145, kl:                 0.185
# - epoch 456/1000 - cost: 0.154, kl:                 0.185
# - epoch 457/1000 - cost: 0.147, kl:                 0.186
# - epoch 458/1000 - cost: 0.257, kl:                 0.186
# - epoch 459/1000 - cost: 0.139, kl:                 0.186
# - epoch 460/1000 - cost: 0.237, kl:                 0.186
# - epoch 461/1000 - cost: 0.216, kl:                 0.186
# - epoch 462/1000 - cost: 0.114, kl:                 0.186
# - epoch 463/1000 - cost: 0.079, kl:                 0.186
# - epoch 464/1000 - cost: 0.184, kl:                 0.186
# - epoch 465/1000 - cost: 0.169, kl:                 0.186
# - epoch 466/1000 - cost: 0.083, kl:                 0.186
# - epoch 467/1000 - cost: 0.174, kl:                 0.185
# - epoch 468/1000 - cost: 0.274, kl:                 0.185
# - epoch 469/1000 - cost: 0.171, kl:                 0.185
# - epoch 470/1000 - cost: 0.209, kl:                 0.185
# - epoch 471/1000 - cost: 0.168, kl:                 0.185
# - epoch 472/1000 - cost: 0.147, kl:                 0.185
# - epoch 473/1000 - cost: 0.130, kl:                 0.185
# - epoch 474/1000 - cost: 0.185, kl:                 0.185
# - epoch 475/1000 - cost: 0.142, kl:                 0.185
# - epoch 476/1000 - cost: 0.224, kl:                 0.185
# - epoch 477/1000 - cost: 0.190, kl:                 0.185
# - epoch 478/1000 - cost: 0.152, kl:                 0.185
# - epoch 479/1000 - cost: 0.140, kl:                 0.186
# - epoch 480/1000 - cost: 0.147, kl:                 0.186
# - epoch 481/1000 - cost: 0.216, kl:                 0.186
# - epoch 482/1000 - cost: 0.241, kl:                 0.186
# - epoch 483/1000 - cost: 0.154, kl:                 0.186
# - epoch 484/1000 - cost: 0.197, kl:                 0.187
# - epoch 485/1000 - cost: 0.307, kl:                 0.186
# - epoch 486/1000 - cost: 0.236, kl:                 0.187
# - epoch 487/1000 - cost: 0.235, kl:                 0.187
# - epoch 488/1000 - cost: 0.222, kl:                 0.187
# - epoch 489/1000 - cost: 0.217, kl:                 0.187
# - epoch 490/1000 - cost: 0.188, kl:                 0.187
# - epoch 491/1000 - cost: 0.188, kl:                 0.187
# - epoch 492/1000 - cost: 0.193, kl:                 0.187
# - epoch 493/1000 - cost: 0.162, kl:                 0.187
# - epoch 494/1000 - cost: 0.131, kl:                 0.188
# - epoch 495/1000 - cost: 0.156, kl:                 0.188
# - epoch 496/1000 - cost: 0.150, kl:                 0.188
# - epoch 497/1000 - cost: 0.197, kl:                 0.188
# - epoch 498/1000 - cost: 0.133, kl:                 0.188
# - epoch 499/1000 - cost: 0.129, kl:                 0.188
# - epoch 500/1000 - cost: 0.170, kl:                 0.188
# - epoch 501/1000 - cost: 0.191, kl:                 0.188
# - epoch 502/1000 - cost: 0.230, kl:                 0.189
# - epoch 503/1000 - cost: 0.209, kl:                 0.189
# - epoch 504/1000 - cost: 0.143, kl:                 0.189
# - epoch 505/1000 - cost: 0.186, kl:                 0.189
# - epoch 506/1000 - cost: 0.202, kl:                 0.190
# - epoch 507/1000 - cost: 0.181, kl:                 0.190
# - epoch 508/1000 - cost: 0.182, kl:                 0.190
# - epoch 509/1000 - cost: 0.176, kl:                 0.190
# - epoch 510/1000 - cost: 0.236, kl:                 0.190
# - epoch 511/1000 - cost: 0.135, kl:                 0.190
# - epoch 512/1000 - cost: 0.135, kl:                 0.190
# - epoch 513/1000 - cost: 0.147, kl:                 0.190
# - epoch 514/1000 - cost: 0.143, kl:                 0.190
# - epoch 515/1000 - cost: 0.182, kl:                 0.190
# - epoch 516/1000 - cost: 0.273, kl:                 0.189
# - epoch 517/1000 - cost: 0.213, kl:                 0.189
# - epoch 518/1000 - cost: 0.118, kl:                 0.189
# - epoch 519/1000 - cost: 0.135, kl:                 0.189
# - epoch 520/1000 - cost: 0.174, kl:                 0.190
# - epoch 521/1000 - cost: 0.203, kl:                 0.190
# - epoch 522/1000 - cost: 0.272, kl:                 0.190
# - epoch 523/1000 - cost: 0.258, kl:                 0.190
# - epoch 524/1000 - cost: 0.212, kl:                 0.190
# - epoch 525/1000 - cost: 0.156, kl:                 0.190
# - epoch 526/1000 - cost: 0.243, kl:                 0.190
# - epoch 527/1000 - cost: 0.199, kl:                 0.190
# - epoch 528/1000 - cost: 0.123, kl:                 0.190
# - epoch 529/1000 - cost: 0.118, kl:                 0.190
# - epoch 530/1000 - cost: 0.125, kl:                 0.190
# - epoch 531/1000 - cost: 0.156, kl:                 0.190
# - epoch 532/1000 - cost: 0.190, kl:                 0.190
# - epoch 533/1000 - cost: 0.150, kl:                 0.190
# - epoch 534/1000 - cost: 0.194, kl:                 0.190
# - epoch 535/1000 - cost: 0.127, kl:                 0.190
# - epoch 536/1000 - cost: 0.150, kl:                 0.190
# - epoch 537/1000 - cost: 0.137, kl:                 0.190
# - epoch 538/1000 - cost: 0.139, kl:                 0.190
# - epoch 539/1000 - cost: 0.108, kl:                 0.189
# - epoch 540/1000 - cost: 0.185, kl:                 0.189
# - epoch 541/1000 - cost: 0.127, kl:                 0.189
# - epoch 542/1000 - cost: 0.122, kl:                 0.189
# - epoch 543/1000 - cost: 0.243, kl:                 0.188
# - epoch 544/1000 - cost: 0.115, kl:                 0.189
# - epoch 545/1000 - cost: 0.188, kl:                 0.189
# - epoch 546/1000 - cost: 0.192, kl:                 0.189
# - epoch 547/1000 - cost: 0.187, kl:                 0.190
# - epoch 548/1000 - cost: 0.214, kl:                 0.190
# - epoch 549/1000 - cost: 0.184, kl:                 0.190
# - epoch 550/1000 - cost: 0.187, kl:                 0.190
# - epoch 551/1000 - cost: 0.201, kl:                 0.190
# - epoch 552/1000 - cost: 0.077, kl:                 0.191
# - epoch 553/1000 - cost: 0.175, kl:                 0.191
# - epoch 554/1000 - cost: 0.171, kl:                 0.191
# - epoch 555/1000 - cost: 0.108, kl:                 0.191
# - epoch 556/1000 - cost: 0.314, kl:                 0.191
# - epoch 557/1000 - cost: 0.181, kl:                 0.191
# - epoch 558/1000 - cost: 0.257, kl:                 0.191
# - epoch 559/1000 - cost: 0.163, kl:                 0.192
# - epoch 560/1000 - cost: 0.151, kl:                 0.192
# - epoch 561/1000 - cost: 0.250, kl:                 0.193
# - epoch 562/1000 - cost: 0.129, kl:                 0.193
# - epoch 563/1000 - cost: 0.185, kl:                 0.193
# - epoch 564/1000 - cost: 0.203, kl:                 0.193
# - epoch 565/1000 - cost: 0.175, kl:                 0.193
# - epoch 566/1000 - cost: 0.152, kl:                 0.193
# - epoch 567/1000 - cost: 0.149, kl:                 0.193
# - epoch 568/1000 - cost: 0.143, kl:                 0.193
# - epoch 569/1000 - cost: 0.111, kl:                 0.193
# - epoch 570/1000 - cost: 0.219, kl:                 0.193
# - epoch 571/1000 - cost: 0.112, kl:                 0.193
# - epoch 572/1000 - cost: 0.164, kl:                 0.193
# - epoch 573/1000 - cost: 0.178, kl:                 0.193
# - epoch 574/1000 - cost: 0.159, kl:                 0.193
# - epoch 575/1000 - cost: 0.213, kl:                 0.193
# - epoch 576/1000 - cost: 0.131, kl:                 0.194
# - epoch 577/1000 - cost: 0.167, kl:                 0.194
# - epoch 578/1000 - cost: 0.126, kl:                 0.195
# - epoch 579/1000 - cost: 0.159, kl:                 0.195
# - epoch 580/1000 - cost: 0.334, kl:                 0.195
# - epoch 581/1000 - cost: 0.174, kl:                 0.194
# - epoch 582/1000 - cost: 0.130, kl:                 0.195
# - epoch 583/1000 - cost: 0.253, kl:                 0.195
# - epoch 584/1000 - cost: 0.131, kl:                 0.194
# - epoch 585/1000 - cost: 0.130, kl:                 0.194
# - epoch 586/1000 - cost: 0.131, kl:                 0.194
# - epoch 587/1000 - cost: 0.136, kl:                 0.193
# - epoch 588/1000 - cost: 0.089, kl:                 0.193
# - epoch 589/1000 - cost: 0.086, kl:                 0.193
# - epoch 590/1000 - cost: 0.281, kl:                 0.192
# - epoch 591/1000 - cost: 0.156, kl:                 0.192
# - epoch 592/1000 - cost: 0.213, kl:                 0.192
# - epoch 593/1000 - cost: 0.142, kl:                 0.192
# - epoch 594/1000 - cost: 0.199, kl:                 0.191
# - epoch 595/1000 - cost: 0.135, kl:                 0.191
# - epoch 596/1000 - cost: 0.134, kl:                 0.191
# - epoch 597/1000 - cost: 0.169, kl:                 0.191
# - epoch 598/1000 - cost: 0.119, kl:                 0.191
# - epoch 599/1000 - cost: 0.160, kl:                 0.191
# - epoch 600/1000 - cost: 0.124, kl:                 0.191
# - epoch 601/1000 - cost: 0.110, kl:                 0.191
# - epoch 602/1000 - cost: 0.157, kl:                 0.191
# - epoch 603/1000 - cost: 0.236, kl:                 0.191
# - epoch 604/1000 - cost: 0.105, kl:                 0.191
# - epoch 605/1000 - cost: 0.160, kl:                 0.192
# - epoch 606/1000 - cost: 0.213, kl:                 0.192
# - epoch 607/1000 - cost: 0.123, kl:                 0.192
# - epoch 608/1000 - cost: 0.099, kl:                 0.193
# - epoch 609/1000 - cost: 0.142, kl:                 0.193
# - epoch 610/1000 - cost: 0.121, kl:                 0.193
# - epoch 611/1000 - cost: 0.160, kl:                 0.193
# - epoch 612/1000 - cost: 0.133, kl:                 0.193
# - epoch 613/1000 - cost: 0.201, kl:                 0.193
# - epoch 614/1000 - cost: 0.121, kl:                 0.193
# - epoch 615/1000 - cost: 0.219, kl:                 0.193
# - epoch 616/1000 - cost: 0.187, kl:                 0.194
# - epoch 617/1000 - cost: 0.242, kl:                 0.194
# - epoch 618/1000 - cost: 0.139, kl:                 0.194
# - epoch 619/1000 - cost: 0.226, kl:                 0.195
# - epoch 620/1000 - cost: 0.206, kl:                 0.195
# - epoch 621/1000 - cost: 0.204, kl:                 0.195
# - epoch 622/1000 - cost: 0.098, kl:                 0.196
# - epoch 623/1000 - cost: 0.167, kl:                 0.196
# - epoch 624/1000 - cost: 0.119, kl:                 0.196
# - epoch 625/1000 - cost: 0.164, kl:                 0.196
# - epoch 626/1000 - cost: 0.184, kl:                 0.196
# - epoch 627/1000 - cost: 0.123, kl:                 0.196
# - epoch 628/1000 - cost: 0.162, kl:                 0.196
# - epoch 629/1000 - cost: 0.145, kl:                 0.196
# - epoch 630/1000 - cost: 0.132, kl:                 0.196
# - epoch 631/1000 - cost: 0.207, kl:                 0.196
# - epoch 632/1000 - cost: 0.116, kl:                 0.196
# - epoch 633/1000 - cost: 0.176, kl:                 0.196
# - epoch 634/1000 - cost: 0.193, kl:                 0.197
# - epoch 635/1000 - cost: 0.115, kl:                 0.197
# - epoch 636/1000 - cost: 0.130, kl:                 0.197
# - epoch 637/1000 - cost: 0.151, kl:                 0.197
# - epoch 638/1000 - cost: 0.188, kl:                 0.197
# - epoch 639/1000 - cost: 0.157, kl:                 0.197
# - epoch 640/1000 - cost: 0.164, kl:                 0.197
# - epoch 641/1000 - cost: 0.133, kl:                 0.197
# - epoch 642/1000 - cost: 0.165, kl:                 0.197
# - epoch 643/1000 - cost: 0.189, kl:                 0.197
# - epoch 644/1000 - cost: 0.126, kl:                 0.197
# - epoch 645/1000 - cost: 0.201, kl:                 0.198
# - epoch 646/1000 - cost: 0.122, kl:                 0.198
# - epoch 647/1000 - cost: 0.205, kl:                 0.198
# - epoch 648/1000 - cost: 0.175, kl:                 0.198
# - epoch 649/1000 - cost: 0.149, kl:                 0.198
# - epoch 650/1000 - cost: 0.168, kl:                 0.199
# - epoch 651/1000 - cost: 0.207, kl:                 0.199
# - epoch 652/1000 - cost: 0.182, kl:                 0.199
# - epoch 653/1000 - cost: 0.180, kl:                 0.200
# - epoch 654/1000 - cost: 0.224, kl:                 0.200
# - epoch 655/1000 - cost: 0.153, kl:                 0.201
# - epoch 656/1000 - cost: 0.190, kl:                 0.201
# - epoch 657/1000 - cost: 0.157, kl:                 0.202
# - epoch 658/1000 - cost: 0.100, kl:                 0.202
# - epoch 659/1000 - cost: 0.198, kl:                 0.201
# - epoch 660/1000 - cost: 0.156, kl:                 0.201
# - epoch 661/1000 - cost: 0.128, kl:                 0.201
# - epoch 662/1000 - cost: 0.173, kl:                 0.201
# - epoch 663/1000 - cost: 0.208, kl:                 0.201
# - epoch 664/1000 - cost: 0.174, kl:                 0.201
# - epoch 665/1000 - cost: 0.215, kl:                 0.202
# - epoch 666/1000 - cost: 0.128, kl:                 0.202
# - epoch 667/1000 - cost: 0.236, kl:                 0.203
# - epoch 668/1000 - cost: 0.175, kl:                 0.204
# - epoch 669/1000 - cost: 0.160, kl:                 0.205
# - epoch 670/1000 - cost: 0.218, kl:                 0.205
# - epoch 671/1000 - cost: 0.348, kl:                 0.206
# - epoch 672/1000 - cost: 0.198, kl:                 0.206
# - epoch 673/1000 - cost: 0.123, kl:                 0.206
# - epoch 674/1000 - cost: 0.206, kl:                 0.206
# - epoch 675/1000 - cost: 0.225, kl:                 0.206
# - epoch 676/1000 - cost: 0.213, kl:                 0.206
# - epoch 677/1000 - cost: 0.133, kl:                 0.206
# - epoch 678/1000 - cost: 0.188, kl:                 0.206
# - epoch 679/1000 - cost: 0.168, kl:                 0.206
# - epoch 680/1000 - cost: 0.175, kl:                 0.205
# - epoch 681/1000 - cost: 0.204, kl:                 0.206
# - epoch 682/1000 - cost: 0.140, kl:                 0.206
# - epoch 683/1000 - cost: 0.173, kl:                 0.206
# - epoch 684/1000 - cost: 0.408, kl:                 0.205
# - epoch 685/1000 - cost: 0.117, kl:                 0.205
# - epoch 686/1000 - cost: 0.173, kl:                 0.205
# - epoch 687/1000 - cost: 0.187, kl:                 0.205
# - epoch 688/1000 - cost: 0.190, kl:                 0.205
# - epoch 689/1000 - cost: 0.167, kl:                 0.205
# - epoch 690/1000 - cost: 0.223, kl:                 0.205
# - epoch 691/1000 - cost: 0.240, kl:                 0.205
# - epoch 692/1000 - cost: 0.149, kl:                 0.205
# - epoch 693/1000 - cost: 0.182, kl:                 0.205
# - epoch 694/1000 - cost: 0.141, kl:                 0.206
# - epoch 695/1000 - cost: 0.152, kl:                 0.207
# - epoch 696/1000 - cost: 0.227, kl:                 0.207
# - epoch 697/1000 - cost: 0.130, kl:                 0.207
# - epoch 698/1000 - cost: 0.205, kl:                 0.208
# - epoch 699/1000 - cost: 0.173, kl:                 0.207
# - epoch 700/1000 - cost: 0.165, kl:                 0.208
# - epoch 701/1000 - cost: 0.133, kl:                 0.208
# - epoch 702/1000 - cost: 0.114, kl:                 0.208
# - epoch 703/1000 - cost: 0.203, kl:                 0.208
# - epoch 704/1000 - cost: 0.181, kl:                 0.208
# - epoch 705/1000 - cost: 0.084, kl:                 0.208
# - epoch 706/1000 - cost: 0.187, kl:                 0.208
# - epoch 707/1000 - cost: 0.267, kl:                 0.208
# - epoch 708/1000 - cost: 0.178, kl:                 0.208
# - epoch 709/1000 - cost: 0.288, kl:                 0.207
# - epoch 710/1000 - cost: 0.168, kl:                 0.207
# - epoch 711/1000 - cost: 0.183, kl:                 0.207
# - epoch 712/1000 - cost: 0.139, kl:                 0.207
# - epoch 713/1000 - cost: 0.135, kl:                 0.207
# - epoch 714/1000 - cost: 0.172, kl:                 0.207
# - epoch 715/1000 - cost: 0.179, kl:                 0.207
# - epoch 716/1000 - cost: 0.121, kl:                 0.207
# - epoch 717/1000 - cost: 0.146, kl:                 0.207
# - epoch 718/1000 - cost: 0.096, kl:                 0.207
# - epoch 719/1000 - cost: 0.147, kl:                 0.207
# - epoch 720/1000 - cost: 0.137, kl:                 0.206
# - epoch 721/1000 - cost: 0.142, kl:                 0.206
# - epoch 722/1000 - cost: 0.147, kl:                 0.206
# - epoch 723/1000 - cost: 0.134, kl:                 0.206
# - epoch 724/1000 - cost: 0.131, kl:                 0.206
# - epoch 725/1000 - cost: 0.182, kl:                 0.205
# - epoch 726/1000 - cost: 0.128, kl:                 0.205
# - epoch 727/1000 - cost: 0.146, kl:                 0.205
# - epoch 728/1000 - cost: 0.175, kl:                 0.205
# - epoch 729/1000 - cost: 0.139, kl:                 0.205
# - epoch 730/1000 - cost: 0.102, kl:                 0.205
# - epoch 731/1000 - cost: 0.207, kl:                 0.205
# - epoch 732/1000 - cost: 0.135, kl:                 0.206
# - epoch 733/1000 - cost: 0.156, kl:                 0.206
# - epoch 734/1000 - cost: 0.201, kl:                 0.207
# - epoch 735/1000 - cost: 0.137, kl:                 0.207
# - epoch 736/1000 - cost: 0.158, kl:                 0.207
# - epoch 737/1000 - cost: 0.093, kl:                 0.208
# - epoch 738/1000 - cost: 0.158, kl:                 0.208
# - epoch 739/1000 - cost: 0.147, kl:                 0.208
# - epoch 740/1000 - cost: 0.121, kl:                 0.208
# - epoch 741/1000 - cost: 0.203, kl:                 0.208
# - epoch 742/1000 - cost: 0.126, kl:                 0.208
# - epoch 743/1000 - cost: 0.297, kl:                 0.208
# - epoch 744/1000 - cost: 0.126, kl:                 0.209
# - epoch 745/1000 - cost: 0.245, kl:                 0.210
# - epoch 746/1000 - cost: 0.176, kl:                 0.211
# - epoch 747/1000 - cost: 0.169, kl:                 0.212
# - epoch 748/1000 - cost: 0.190, kl:                 0.212
# - epoch 749/1000 - cost: 0.113, kl:                 0.212
# - epoch 750/1000 - cost: 0.131, kl:                 0.213
# - epoch 751/1000 - cost: 0.171, kl:                 0.213
# - epoch 752/1000 - cost: 0.197, kl:                 0.212
# - epoch 753/1000 - cost: 0.090, kl:                 0.212
# - epoch 754/1000 - cost: 0.220, kl:                 0.212
# - epoch 755/1000 - cost: 0.121, kl:                 0.212
# - epoch 756/1000 - cost: 0.087, kl:                 0.211
# - epoch 757/1000 - cost: 0.210, kl:                 0.211
# - epoch 758/1000 - cost: 0.210, kl:                 0.210
# - epoch 759/1000 - cost: 0.169, kl:                 0.210
# - epoch 760/1000 - cost: 0.218, kl:                 0.210
# - epoch 761/1000 - cost: 0.269, kl:                 0.211
# - epoch 762/1000 - cost: 0.203, kl:                 0.211
# - epoch 763/1000 - cost: 0.202, kl:                 0.211
# - epoch 764/1000 - cost: 0.185, kl:                 0.211
# - epoch 765/1000 - cost: 0.133, kl:                 0.211
# - epoch 766/1000 - cost: 0.212, kl:                 0.211
# - epoch 767/1000 - cost: 0.103, kl:                 0.212
# - epoch 768/1000 - cost: 0.178, kl:                 0.212
# - epoch 769/1000 - cost: 0.187, kl:                 0.212
# - epoch 770/1000 - cost: 0.119, kl:                 0.212
# - epoch 771/1000 - cost: 0.085, kl:                 0.211
# - epoch 772/1000 - cost: 0.090, kl:                 0.211
# - epoch 773/1000 - cost: 0.210, kl:                 0.210
# - epoch 774/1000 - cost: 0.186, kl:                 0.210
# - epoch 775/1000 - cost: 0.151, kl:                 0.210
# - epoch 776/1000 - cost: 0.116, kl:                 0.210
# - epoch 777/1000 - cost: 0.105, kl:                 0.210
# - epoch 778/1000 - cost: 0.170, kl:                 0.210
# - epoch 779/1000 - cost: 0.218, kl:                 0.210
# - epoch 780/1000 - cost: 0.166, kl:                 0.210
# - epoch 781/1000 - cost: 0.258, kl:                 0.209
# - epoch 782/1000 - cost: 0.133, kl:                 0.209
# - epoch 783/1000 - cost: 0.204, kl:                 0.209
# - epoch 784/1000 - cost: 0.093, kl:                 0.209
# - epoch 785/1000 - cost: 0.255, kl:                 0.209
# - epoch 786/1000 - cost: 0.159, kl:                 0.209
# - epoch 787/1000 - cost: 0.113, kl:                 0.209
# - epoch 788/1000 - cost: 0.114, kl:                 0.209
# - epoch 789/1000 - cost: 0.178, kl:                 0.209
# - epoch 790/1000 - cost: 0.152, kl:                 0.209
# - epoch 791/1000 - cost: 0.202, kl:                 0.209
# - epoch 792/1000 - cost: 0.162, kl:                 0.208
# - epoch 793/1000 - cost: 0.157, kl:                 0.208
# - epoch 794/1000 - cost: 0.101, kl:                 0.208
# - epoch 795/1000 - cost: 0.205, kl:                 0.208
# - epoch 796/1000 - cost: 0.358, kl:                 0.208
# - epoch 797/1000 - cost: 0.068, kl:                 0.208
# - epoch 798/1000 - cost: 0.192, kl:                 0.209
# - epoch 799/1000 - cost: 0.176, kl:                 0.209
# - epoch 800/1000 - cost: 0.115, kl:                 0.209
# - epoch 801/1000 - cost: 0.143, kl:                 0.209
# - epoch 802/1000 - cost: 0.177, kl:                 0.210
# - epoch 803/1000 - cost: 0.133, kl:                 0.210
# - epoch 804/1000 - cost: 0.120, kl:                 0.209
# - epoch 805/1000 - cost: 0.182, kl:                 0.209
# - epoch 806/1000 - cost: 0.125, kl:                 0.208
# - epoch 807/1000 - cost: 0.162, kl:                 0.208
# - epoch 808/1000 - cost: 0.118, kl:                 0.207
# - epoch 809/1000 - cost: 0.144, kl:                 0.207
# - epoch 810/1000 - cost: 0.121, kl:                 0.207
# - epoch 811/1000 - cost: 0.176, kl:                 0.207
# - epoch 812/1000 - cost: 0.114, kl:                 0.208
# - epoch 813/1000 - cost: 0.101, kl:                 0.207
# - epoch 814/1000 - cost: 0.243, kl:                 0.207
# - epoch 815/1000 - cost: 0.157, kl:                 0.207
# - epoch 816/1000 - cost: 0.154, kl:                 0.208
# - epoch 817/1000 - cost: 0.140, kl:                 0.209
# - epoch 818/1000 - cost: 0.080, kl:                 0.210
# - epoch 819/1000 - cost: 0.184, kl:                 0.211
# - epoch 820/1000 - cost: 0.205, kl:                 0.211
# - epoch 821/1000 - cost: 0.286, kl:                 0.211
# - epoch 822/1000 - cost: 0.115, kl:                 0.212
# - epoch 823/1000 - cost: 0.092, kl:                 0.212
# - epoch 824/1000 - cost: 0.114, kl:                 0.212
# - epoch 825/1000 - cost: 0.236, kl:                 0.212
# - epoch 826/1000 - cost: 0.225, kl:                 0.212
# - epoch 827/1000 - cost: 0.200, kl:                 0.213
# - epoch 828/1000 - cost: 0.190, kl:                 0.213
# - epoch 829/1000 - cost: 0.154, kl:                 0.214
# - epoch 830/1000 - cost: 0.178, kl:                 0.214
# - epoch 831/1000 - cost: 0.121, kl:                 0.214
# - epoch 832/1000 - cost: 0.202, kl:                 0.214
# - epoch 833/1000 - cost: 0.102, kl:                 0.214
# - epoch 834/1000 - cost: 0.198, kl:                 0.214
# - epoch 835/1000 - cost: 0.100, kl:                 0.213
# - epoch 836/1000 - cost: 0.266, kl:                 0.213
# - epoch 837/1000 - cost: 0.112, kl:                 0.213
# - epoch 838/1000 - cost: 0.203, kl:                 0.213
# - epoch 839/1000 - cost: 0.165, kl:                 0.213
# - epoch 840/1000 - cost: 0.153, kl:                 0.213
# - epoch 841/1000 - cost: 0.169, kl:                 0.213
# - epoch 842/1000 - cost: 0.141, kl:                 0.213
# - epoch 843/1000 - cost: 0.136, kl:                 0.212
# - epoch 844/1000 - cost: 0.126, kl:                 0.212
# - epoch 845/1000 - cost: 0.120, kl:                 0.211
# - epoch 846/1000 - cost: 0.246, kl:                 0.211
# - epoch 847/1000 - cost: 0.191, kl:                 0.210
# - epoch 848/1000 - cost: 0.091, kl:                 0.210
# - epoch 849/1000 - cost: 0.128, kl:                 0.210
# - epoch 850/1000 - cost: 0.206, kl:                 0.210
# - epoch 851/1000 - cost: 0.124, kl:                 0.210
# - epoch 852/1000 - cost: 0.168, kl:                 0.211
# - epoch 853/1000 - cost: 0.100, kl:                 0.211
# - epoch 854/1000 - cost: 0.096, kl:                 0.211
# - epoch 855/1000 - cost: 0.157, kl:                 0.211
# - epoch 856/1000 - cost: 0.171, kl:                 0.211
# - epoch 857/1000 - cost: 0.105, kl:                 0.211
# - epoch 858/1000 - cost: 0.175, kl:                 0.212
# - epoch 859/1000 - cost: 0.239, kl:                 0.212
# - epoch 860/1000 - cost: 0.218, kl:                 0.213
# - epoch 861/1000 - cost: 0.225, kl:                 0.214
# - epoch 862/1000 - cost: 0.189, kl:                 0.215
# - epoch 863/1000 - cost: 0.160, kl:                 0.215
# - epoch 864/1000 - cost: 0.208, kl:                 0.216
# - epoch 865/1000 - cost: 0.171, kl:                 0.217
# - epoch 866/1000 - cost: 0.199, kl:                 0.218
# - epoch 867/1000 - cost: 0.155, kl:                 0.219
# - epoch 868/1000 - cost: 0.152, kl:                 0.219
# - epoch 869/1000 - cost: 0.127, kl:                 0.219
# - epoch 870/1000 - cost: 0.115, kl:                 0.219
# - epoch 871/1000 - cost: 0.230, kl:                 0.219
# - epoch 872/1000 - cost: 0.118, kl:                 0.218
# - epoch 873/1000 - cost: 0.103, kl:                 0.218
# - epoch 874/1000 - cost: 0.159, kl:                 0.217
# - epoch 875/1000 - cost: 0.161, kl:                 0.217
# - epoch 876/1000 - cost: 0.174, kl:                 0.217
# - epoch 877/1000 - cost: 0.169, kl:                 0.216
# - epoch 878/1000 - cost: 0.193, kl:                 0.216
# - epoch 879/1000 - cost: 0.097, kl:                 0.215
# - epoch 880/1000 - cost: 0.096, kl:                 0.215
# - epoch 881/1000 - cost: 0.152, kl:                 0.215
# - epoch 882/1000 - cost: 0.214, kl:                 0.215
# - epoch 883/1000 - cost: 0.158, kl:                 0.215
# - epoch 884/1000 - cost: 0.124, kl:                 0.216
# - epoch 885/1000 - cost: 0.164, kl:                 0.217
# - epoch 886/1000 - cost: 0.110, kl:                 0.218
# - epoch 887/1000 - cost: 0.190, kl:                 0.218
# - epoch 888/1000 - cost: 0.140, kl:                 0.218
# - epoch 889/1000 - cost: 0.177, kl:                 0.218
# - epoch 890/1000 - cost: 0.202, kl:                 0.218
# - epoch 891/1000 - cost: 0.186, kl:                 0.219
# - epoch 892/1000 - cost: 0.196, kl:                 0.220
# - epoch 893/1000 - cost: 0.117, kl:                 0.221
# - epoch 894/1000 - cost: 0.177, kl:                 0.221
# - epoch 895/1000 - cost: 0.158, kl:                 0.221
# - epoch 896/1000 - cost: 0.165, kl:                 0.221
# - epoch 897/1000 - cost: 0.181, kl:                 0.221
# - epoch 898/1000 - cost: 0.312, kl:                 0.220
# - epoch 899/1000 - cost: 0.201, kl:                 0.220
# - epoch 900/1000 - cost: 0.197, kl:                 0.220
# - epoch 901/1000 - cost: 0.232, kl:                 0.221
# - epoch 902/1000 - cost: 0.218, kl:                 0.221
# - epoch 903/1000 - cost: 0.135, kl:                 0.221
# - epoch 904/1000 - cost: 0.156, kl:                 0.221
# - epoch 905/1000 - cost: 0.176, kl:                 0.221
# - epoch 906/1000 - cost: 0.190, kl:                 0.220
# - epoch 907/1000 - cost: 0.255, kl:                 0.220
# - epoch 908/1000 - cost: 0.148, kl:                 0.219
# - epoch 909/1000 - cost: 0.121, kl:                 0.219
# - epoch 910/1000 - cost: 0.222, kl:                 0.219
# - epoch 911/1000 - cost: 0.181, kl:                 0.219
# - epoch 912/1000 - cost: 0.139, kl:                 0.219
# - epoch 913/1000 - cost: 0.200, kl:                 0.219
# - epoch 914/1000 - cost: 0.238, kl:                 0.219
# - epoch 915/1000 - cost: 0.121, kl:                 0.218
# - epoch 916/1000 - cost: 0.208, kl:                 0.218
# - epoch 917/1000 - cost: 0.184, kl:                 0.217
# - epoch 918/1000 - cost: 0.145, kl:                 0.216
# - epoch 919/1000 - cost: 0.176, kl:                 0.215
# - epoch 920/1000 - cost: 0.153, kl:                 0.215
# - epoch 921/1000 - cost: 0.217, kl:                 0.214
# - epoch 922/1000 - cost: 0.208, kl:                 0.214
# - epoch 923/1000 - cost: 0.166, kl:                 0.213
# - epoch 924/1000 - cost: 0.098, kl:                 0.214
# - epoch 925/1000 - cost: 0.092, kl:                 0.215
# - epoch 926/1000 - cost: 0.199, kl:                 0.215
# - epoch 927/1000 - cost: 0.202, kl:                 0.215
# - epoch 928/1000 - cost: 0.183, kl:                 0.215
# - epoch 929/1000 - cost: 0.150, kl:                 0.215
# - epoch 930/1000 - cost: 0.303, kl:                 0.215
# - epoch 931/1000 - cost: 0.136, kl:                 0.215
# - epoch 932/1000 - cost: 0.116, kl:                 0.216
# - epoch 933/1000 - cost: 0.156, kl:                 0.216
# - epoch 934/1000 - cost: 0.309, kl:                 0.216
# - epoch 935/1000 - cost: 0.178, kl:                 0.217
# - epoch 936/1000 - cost: 0.161, kl:                 0.218
# - epoch 937/1000 - cost: 0.147, kl:                 0.218
# - epoch 938/1000 - cost: 0.137, kl:                 0.218
# - epoch 939/1000 - cost: 0.117, kl:                 0.218
# - epoch 940/1000 - cost: 0.197, kl:                 0.218
# - epoch 941/1000 - cost: 0.108, kl:                 0.218
# - epoch 942/1000 - cost: 0.215, kl:                 0.217
# - epoch 943/1000 - cost: 0.225, kl:                 0.217
# - epoch 944/1000 - cost: 0.295, kl:                 0.217
# - epoch 945/1000 - cost: 0.119, kl:                 0.216
# - epoch 946/1000 - cost: 0.097, kl:                 0.217
# - epoch 947/1000 - cost: 0.139, kl:                 0.217
# - epoch 948/1000 - cost: 0.098, kl:                 0.217
# - epoch 949/1000 - cost: 0.156, kl:                 0.217
# - epoch 950/1000 - cost: 0.183, kl:                 0.217
# - epoch 951/1000 - cost: 0.131, kl:                 0.217
# - epoch 952/1000 - cost: 0.132, kl:                 0.218
# - epoch 953/1000 - cost: 0.182, kl:                 0.218
# - epoch 954/1000 - cost: 0.098, kl:                 0.218
# - epoch 955/1000 - cost: 0.155, kl:                 0.219
# - epoch 956/1000 - cost: 0.139, kl:                 0.219
# - epoch 957/1000 - cost: 0.153, kl:                 0.220
# - epoch 958/1000 - cost: 0.307, kl:                 0.220
# - epoch 959/1000 - cost: 0.105, kl:                 0.221
# - epoch 960/1000 - cost: 0.168, kl:                 0.221
# - epoch 961/1000 - cost: 0.176, kl:                 0.221
# - epoch 962/1000 - cost: 0.237, kl:                 0.221
# - epoch 963/1000 - cost: 0.103, kl:                 0.221
# - epoch 964/1000 - cost: 0.185, kl:                 0.221
# - epoch 965/1000 - cost: 0.179, kl:                 0.221
# - epoch 966/1000 - cost: 0.160, kl:                 0.221
# - epoch 967/1000 - cost: 0.133, kl:                 0.221
# - epoch 968/1000 - cost: 0.263, kl:                 0.220
# - epoch 969/1000 - cost: 0.170, kl:                 0.219
# - epoch 970/1000 - cost: 0.115, kl:                 0.219
# - epoch 971/1000 - cost: 0.157, kl:                 0.218
# - epoch 972/1000 - cost: 0.107, kl:                 0.217
# - epoch 973/1000 - cost: 0.220, kl:                 0.217
# - epoch 974/1000 - cost: 0.096, kl:                 0.217
# - epoch 975/1000 - cost: 0.193, kl:                 0.217
# - epoch 976/1000 - cost: 0.133, kl:                 0.217
# - epoch 977/1000 - cost: 0.139, kl:                 0.217
# - epoch 978/1000 - cost: 0.215, kl:                 0.216
# - epoch 979/1000 - cost: 0.097, kl:                 0.216
# - epoch 980/1000 - cost: 0.125, kl:                 0.215
# - epoch 981/1000 - cost: 0.154, kl:                 0.215
# - epoch 982/1000 - cost: 0.129, kl:                 0.215
# - epoch 983/1000 - cost: 0.286, kl:                 0.215
# - epoch 984/1000 - cost: 0.147, kl:                 0.215
# - epoch 985/1000 - cost: 0.167, kl:                 0.215
# - epoch 986/1000 - cost: 0.127, kl:                 0.215
# - epoch 987/1000 - cost: 0.114, kl:                 0.215
# - epoch 988/1000 - cost: 0.244, kl:                 0.215
# - epoch 989/1000 - cost: 0.165, kl:                 0.215
# - epoch 990/1000 - cost: 0.185, kl:                 0.215
# - epoch 991/1000 - cost: 0.147, kl:                 0.215
# - epoch 992/1000 - cost: 0.141, kl:                 0.215
# - epoch 993/1000 - cost: 0.198, kl:                 0.215
# - epoch 994/1000 - cost: 0.164, kl:                 0.215
# - epoch 995/1000 - cost: 0.210, kl:                 0.215
# - epoch 996/1000 - cost: 0.091, kl:                 0.215
# - epoch 997/1000 - cost: 0.115, kl:                 0.215
# - epoch 998/1000 - cost: 0.193, kl:                 0.215
# - epoch 999/1000 - cost: 0.113, kl:                 0.215
# - epoch 1000/1000 - cost: 0.143, kl:                 0.215
# - this took 296.72 seconds

# %%
mean_pred_results, std_pred_results = model.test_model()
# Out:
# Testing the model...
# - cost: 0.031
# - this took 11.02 seconds

# %%
for i in range(0, 200, 10):
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(111)
    ax.plot(model.wavelength, mean_pred_results[i, :], label="Predicted")
    ax.fill_between(model.wavelength, mean_pred_results[i, :] - std_pred_results[i, :], mean_pred_results[i, :] + std_pred_results[i, :], alpha=0.3, label="1$\\sigma$")
    ax.plot(model.wavelength, model.y_test[i, :], label=f"True, params = {model.X_test[i]}")

    ax.set_xscale("log")
    ax.set_xlabel("Wavelength / $\\mu$m")
    ax.set_ylabel("Sersic Index")
    ax.legend()
    fig.tight_layout()
    plt.show()
    plt.close()

# %%
# Generate some random parameters for model
# rng = np.random.default_rng(seed=30)
# artificial_parameters = torch.empty(10, 3, dtype=torch.float32)

# for i in range(10):
#     log_mstar = rng.uniform(9.5, 11.5)
#     log_mdust = rng.uniform(5.5, 9.5)

#     while log_mdust - log_mstar < -4:
#         log_mdust = rng.uniform(5.5, 9.5)

#     log_mdust_over_mstar = log_mdust - log_mstar

#     theta = rng.uniform(0, 1)

#     # add to artificial_parameters matrix as a row
#     parameters_row = torch.tensor([log_mstar, log_mdust_over_mstar, theta], dtype=torch.float32).reshape(1, 3)
#     artificial_parameters[i] = parameters_row

star_mass = torch.linspace(10.5, 10.5, 20)
dust_mass = torch.linspace(5.5, 9.5, 20)
theta = torch.linspace(90, 90, 20)
x_pred = model.create_predict_tensor(star_mass, dust_mass, theta)
print(x_pred.shape)
mean_pred_results, std_pred_results = model.predict(x_pred)


# df = model.df
# x_test = model.X_test

# print(artificial_parameters.shape)
# Out:
# torch.Size([20, 3])

# %%
fig = plt.figure(figsize=(15, 9))
ax = fig.add_subplot(111)

for i in range(1, 20, 1):
    ax.plot(model.wavelength, mean_pred_results[i, :], label=f"Predicted, params = {x_pred[i]}")
    ax.fill_between(model.wavelength, mean_pred_results[i, :] - std_pred_results[i, :], mean_pred_results[i, :] + std_pred_results[i, :], alpha=0.3, label="1$\\sigma$")
    # ax.plot(model.wavelength, model.y_test[i, :], label=f"True, params = {model.X_test[i]}")

ax.set_xscale("log")
ax.set_xlabel("Wavelength / $\\mu$m")
ax.set_ylabel("Flux / W m$^{-2}$")
# ax.legend()
fig.tight_layout()


# plotter = Plotter(model.wavelength, mean_pred_results, model.X_test, model.y_test, "n")
# plotter.plot_same_ax(1, 20, 1)

# %%
# artificial_predictions_mean, artificial_parameters_std = model.predict(artificial_parameters)
# for i in range(0, 10, 1):
#     fig = plt.figure(figsize=(10, 5))
#     ax = fig.add_subplot(111)
#     ax.plot(model.wavelength, artificial_predictions_mean[i, :], label=f"Predicted, params = {artificial_parameters[i]}")
#     ax.fill_between(model.wavelength, artificial_predictions_mean[i, :] - artificial_parameters_std[i, :], artificial_predictions_mean[i, :] + artificial_parameters_std[i, :], alpha=0.3, label="1$\\sigma$")
#     # ax.plot(model.wavelength, model.y_test[i, :], label=f"True, params = {model.X_test[i]}")
#     ax.set_xscale("log")
#     ax.set_xlabel("Wavelength / $\\mu$m")
#     ax.set_ylabel("Sersic Index")
#     ax.legend()
#     fig.tight_layout()
#     plt.show()
#     plt.close()

# %%
input_mean = model.input_mean
input_std = model.input_std
output_mean = model.output_mean
output_std = model.output_std
